# %%
from tkinter import *
from tkinter import ttk, filedialog
from tkinter.filedialog import askopenfilename
import csv
from pathlib import Path
import pymongo
# Use sentinel for missing values
from numpy import nan as NA
import pandas as pd

# connect to mongodb
client = pymongo.MongoClient("mongodb://localhost:27017")
# create db
db_formative = client["formative"]
# create collection
collection_vendors = db_formative["test-80"]

# %%
# Global variables
fileButtons = ["inspections", "inventory", "violations"]
fileRoutes = {fileButtons[0]:"", fileButtons[1]:"", fileButtons[2]:""}

# %%
class Parser(object):
    def __init__(self, collection, csvFile):
        self.collection = collection
        self.csvFile = csvFile
        self.dataList = []
        self.dataObj = {}
        
    def parseData(self):
        print(self.csvFile['inspections'])
#         with open(self.csvFile['inspections'], newline="", encoding='utf-8-sig') as inFile: 
#             dataReader = csv.DictReader(inFile)
        self.readInspections()
#         with open(self.csvFile['inventory'], newline="", encoding='utf-8-sig') as inFile: 
#             dataReader = csv.DictReader(inFile)
        self.readInventory()
#         with open(self.csvFile['violations'], newline="", encoding='utf-8-sig') as inFile: 
#             dataReader = csv.DictReader(inFile)
        self.readViolations()
                
    def readInspections(self):
        with open(self.csvFile['inspections'], newline="", encoding='utf-8-sig') as inFile: 
            dataReader = csv.DictReader(inFile)
            for row in dataReader:
                # Do not add inactive programs
                if row['PROGRAM STATUS'] == 'INACTIVE':
                    continue
                # Add Mongo ID as Serial Number with INS- prefix
                print(row['SERIAL NUMBER'])
                row['_id'] = "INS-"+row['SERIAL NUMBER']
                # Split PE Description and create new row with seating
                try:
                    start,mid = row["PE DESCRIPTION"].split(' (')
                    mid,end = mid.split(')')
                    row["PE DESCRIPTION"] = start+end
                    row["SEATING DETAILS"] = mid
                except:
                    print('no seating desc')
                # NEW: remove second half of zip (e.g. 90001-1234 remove '1234')
                try:
                    zipStart = row["FACILITY ZIP"].split('-')
                    row["FACILITY ZIP"] = zipStart[0]
                except:
                    print('no zip')
                self.dataList.append(row)
            print(f'Inspection first doc: \n{self.dataList[0]}')
            ins = self.collection.insert_many(self.dataList)
            print('=> Inspections inserted into DB')
            self.dataList = []

    def readInventory(self):
         with open(self.csvFile['inventory'], newline="", encoding='utf-8-sig') as inFile: 
            dataReader = csv.DictReader(inFile)
            for row in dataReader:
                # Add Mongo ID as Facility ID with F_ID- prefix
                print(row['FACILITY ID'])
                row['_id'] = 'F_ID-'+row['FACILITY ID']
                # Split PE Description and create new row with seating
                start,mid = row["PE DESCRIPTION"].split(' (')
                mid,end = mid.split(')')
                row["PE DESCRIPTION"] = start+end
                row["SEATING DETAILS"] = mid
                self.dataList.append(row)
            print(f'Inventory first doc: \n{self.dataList[0]}')
            ins = self.collection.insert_many(self.dataList)
            print('=> Inventory inserted into DB')
            self.dataList = []
            
    def readViolations(self):
        with open(self.csvFile['violations'], newline="", encoding='utf-8-sig') as inFile: 
            dataReader = csv.DictReader(inFile)
            # Group the rows by serial number so they can be added to the corresponding inspection
            for row in dataReader:
                print(row)
                if row['SERIAL NUMBER'] in self.dataObj:
                    self.dataObj[row['SERIAL NUMBER']].append(row)
                else:
                    self.dataObj[row['SERIAL NUMBER']] = [row]
            self.dataList.append(self.dataObj)
            print(f'Violations first doc: \n{self.dataList[0]}')
            ins = collection_vendors.insert_many(self.dataList)
            print('=> Violations inserted into DB')
            self.dataList = []
        
        
    def formatViolations(self):
        for violation in self.dataObj:
            collection_vendors.update_one({'_id': 'INS-'+violation}, {'$set': {'VIOLATIONS': self.dataObj[violation]}})

# %%
class ButtonUpload(object):
    def __init__(self, fileButtons, fileLabels, counter, mainframe):
        self.fileButtons = fileButtons
        self.fileLabels = fileLabels
        self.counter = counter
        self.mainframe = mainframe
        self.filePath = ''
        self.uploadLabel = StringVar()

    def browseFile(self):
        self.filePath = askopenfilename(filetypes=[("CSV files", ".csv")])
        fileName = Path(self.filePath)
        self.uploadLabel.set(fileName.name)
        print(self.filePath)
        self.setFileRoutes()
    
    def setFileRoutes(self):
        fileRoutes[self.fileButtons] = self.filePath
        print(fileRoutes)
        
    def createButton(self):
        ttk.Label(self.mainframe, text=f"Upload data: {self.fileButtons}", anchor="w").grid(row=self.counter+1, column=0, sticky="w")
        Button(self.mainframe, text="Upload file", command=self.browseFile).grid(row=self.counter+1, column=1, sticky="w")
        ttk.Label(self.mainframe, textvariable=self.uploadLabel).grid(row=self.counter+1, column=2, sticky="w")

# %%
class AveragesCalculator(object):
    def __init__(self, year, category):
        self.year = year
        self.category = category
        
    def zipScores(self):
        # ******* TO DO: ERROR IF YEAR NOT FOUND ********
        print(f'Calculating stats for: \n- Year = {self.year} \n- Category = {self.category}')
        # Find inspection documents - look in ispections (INS-) with year
        resultsInspections = collection_vendors.find({'_id':{'$regex':'INS-'},'ACTIVITY DATE':{'$regex':self.year}})

        # Create dict of facility zips with lists of their scores
        zipScoresDict = {}  
        for r in resultsInspections:
            key = str(r[self.category])
            if(r['SCORE'] == ''):
                value = NA
            else:
                value = int(r['SCORE'])
            if key in zipScoresDict:
                zipScoresDict[r[self.category]].append(value)
            else:
                zipScoresDict[key] = [value]
        return self.calcZipStats(zipScoresDict)


    def calcZipStats(self, zipScoresDict):
        zipScoresMean = {}
        zipScoresMean = {self.category:[],'mean':[],'median':[],'mode':[]}
        for x in zipScoresDict:
            # Create Series to calc mean, mode, median
            tempSeries = pd.Series(zipScoresDict[x])
            mean = tempSeries.mean()
            mode = tempSeries.mode().tolist()
            median = tempSeries.median()

            # mean, mode, median as columns
            zipScoresMean[self.category].append(x)
            zipScoresMean['mean'].append(mean)
            zipScoresMean['median'].append(median)
            zipScoresMean['mode'].append(mode)

        # Create DataFrame
        zipScoresDF = pd.DataFrame(zipScoresMean)
        # sort by ascending cat - easier to find for user (esp. zip)
        zipScoresDF.sort_values(by=[self.category],inplace=True)
        # set cat as index
        zipScores_noIndex = zipScoresDF.set_index(self.category)
        
        return zipScores_noIndex

# %%
class UserInterface(object):
    def __init__(self, title):
        self.title = title
        self.mainframe = None
        self.window = Tk()
        self.window.title(self.title)
        self.window.geometry("600x400")
        self.window.columnconfigure(0, weight=1)
        self.window.rowconfigure(0, weight=1)
        self.calcCategory = StringVar()
        self.calcYear = StringVar()
        
    def createWindow(self):
        self.createInitialFrame()
        self.window.mainloop()
        
    def createInitialFrame(self):
         # variables
        labelTextOne = StringVar()
        labelTextTwo = StringVar()
        labelTextThree = StringVar()
        fileLabels = [labelTextOne, labelTextTwo, labelTextThree]
        # Config layout
        self.mainframe = ttk.Frame(self.window, padding="16 16 16 16")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        self.mainframe.grid_rowconfigure(4, weight=1)
        self.mainframe.grid_columnconfigure(2, weight=1)
        heading = ttk.Label(self.mainframe, text="Load your dataset", anchor="w").grid(row=0, sticky="nw")
        # Create buttons for file uploads
        for i in range(0, len(fileButtons)): 
            newButton = ButtonUpload(fileButtons[i], fileLabels[i], i, self.mainframe)
            newButton.createButton()
        # Buttons for Cancel and Clean & Save
        footer = ttk.Frame(self.window, padding="16 0 0 0").grid(row=5, column=1)
        cancelButton = Button(self.mainframe, text="Cancel & exit", bg="red").grid(row=4, column=0, sticky="sw")
        saveButton = Button(self.mainframe, text="Save", command=self.handleSave).grid(row=4, column=2,sticky="se")
        
    def handleSave(self):
        self.loadingFrame('Your data is being parsed and loaded into MongoDB...')
        parser = Parser(collection_vendors, fileRoutes)
        parser.parseData()
#         parser.formatViolations()
        self.createNotebook()
    
    def loadingFrame(self, text):
        self.mainframe.destroy()
        self.mainframe = ttk.Frame(self.window, padding="16 16 16 16")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        heading = ttk.Label(self.mainframe, text="Please wait:", anchor="w").grid(row=0, sticky="nw")
        subheading = ttk.Label(self.mainframe, text=text, anchor="w").grid(row=1, sticky="nw")
        
    def createNotebook(self):
        print('here')
        self.mainframe.destroy()
        self.mainframe = ttk.Notebook(self.window)
        f1 = ttk.Frame(self.mainframe)  
        f2 = ttk.Frame(self.mainframe)  
        f3 = ttk.Frame(self.mainframe) 
        self.mainframe.add(f1, text='Averages')
        self.mainframe.add(f2, text='Violations per Establishment')
        self.mainframe.add(f3, text='Correlations')
        # ====== Widget for tab 1
        heading_one = ttk.Label(f1, text="Mean, Mode and Median", anchor="w").grid(row=0, sticky="nw")
        # Radio - Type
        radioHeadingOne = ttk.Label(f1, text="Calculate by seating type or zip codes:", anchor="w").grid(row=0, sticky="nw")
        Radiobutton(f1, text="Vendor seating type", padx = 20, variable=self.calcCategory, value='SEATING DETAILS').grid(row=1, column=0, sticky='w')
        Radiobutton(f1, text="Zip Code", padx = 20, variable=self.calcCategory, value='FACILITY ZIP').grid(row=2, column=0, sticky='w')
        # Radio - Years
        radioHeadingTwo = ttk.Label(f1, text="Select Year", anchor="w").grid(row=3, sticky="nw")
        yearsArr = ['2016', '2017', '2018', '2019']
        for i in range(len(yearsArr)):
            Radiobutton(f1, text=yearsArr[i], padx = 20, variable=self.calcYear, value=yearsArr[i]).grid(row=i+4, column=0, sticky='w')
        # Calc button
        calcButton = Button(f1, text="Calculate", command=self.calcAverages).grid(row=8, column=0, sticky="sw")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        
        
        # ====== Widget for tab 2
        heading_two = ttk.Label(f2, text="Violations per Establishment", anchor="w").grid(row=0, sticky="nw")
    
    def calcAverages(self):
        calcCatVal = self.calcCategory.get()
        calcYearVal = self.calcYear.get()
        calcAv = AveragesCalculator(calcYearVal, calcCatVal)
        avResults = calcAv.zipScores()
        self.averagesResultsFrame(avResults, calcYearVal, calcCatVal)
        
    def averagesResultsFrame(self, resultsAv, calcYearVal, calcCatVal):
        avResultsWindow = Tk()
        avResultsWindow.title(f'Averages Results for {calcCatVal} in {calcYearVal}')
        avResultsWindow.geometry("600x400")
        avResultsWindow.columnconfigure(0, weight=1)
        avResultsWindow.rowconfigure(0, weight=1)
        mainframe = ttk.Frame(avResultsWindow, padding="16 16 16 16")
        mainframe.place(relheight=1, relwidth=1)

        tree = ttk.Treeview(mainframe)
        tree.place(relheight=1, relwidth=1)
        treescrolly = Scrollbar(mainframe, orient='vertical', command=tree.yview)
        treescrollx = Scrollbar(mainframe, orient='horizontal', command=tree.xview)
        tree.configure(xscrollcommand=treescrollx.set, yscrollcommand=treescrolly.set)
        treescrolly.pack(side='right', fill='y')
        treescrollx.pack(side='bottom', fill='x')

        tree["columns"]=("one","two","three")
        tree.column("#0", width=75, minwidth=75)
        tree.column("one", width=75, minwidth=75)
        tree.column("two", width=75, minwidth=75)
        tree.column("three", width=75, minwidth=75)

        tree.heading("#0",text="Seating")
        tree.heading("one", text="Mean")
        tree.heading("two", text="Median")
        tree.heading("three", text="Mode")

#         data = resultsAv.to_numpy()

        for index, row in resultsAv.iterrows(): 
            tree.insert('','end', text=index, values=[row['mean'],row['median'],row['mode']])
        print(f'This is resultsAv: \n{resultsAv}')

# %%
ui = UserInterface('summative')
ui.createWindow()
# Out:
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv', 'inventory': '', 'violations': ''}
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv', 'inventory': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv', 'violations': ''}
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/violations_md.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv', 'inventory': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv', 'violations': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/violations_md.csv'}
# DA04UTASX
# DA04UTQ4S
# DA04UYKXO
# DA04UZMSN
# DA04VYJKW
# DA04W2SVV
# DA04WG22P
# DA04WK5MZ
# DA04WRH0O
# DA04WS0EZ
# DA04WSQXS
# DA04WX8WQ
# DA04WZOVC
# DA04XAACX
# DA04XR18C
# Inspection first doc:
# {'ACTIVITY DATE': '02/07/2019', 'OWNER ID': 'OW0099597', 'OWNER NAME': 'ZARE INVESTMENTS INC', 'FACILITY ID': 'FA0067946', 'FACILITY NAME': 'ONE STOP SHOP MART', 'RECORD ID': 'PR0040362', 'PROGRAM NAME': 'ONE STOP SHOP MART', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': '1610', 'PE DESCRIPTION': 'FOOD MKT RETAIL LOW RISK', 'FACILITY ADDRESS': '314 SANTA&#160;MONICA BLVD', 'FACILITY CITY': 'SANTA&#160;MONICA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90401', 'SERVICE CODE': '1', 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': '93', 'GRADE': 'A', 'SERIAL NUMBER': 'DA0004KIJ', 'EMPLOYEE ID': 'EE0001005', 'Location': 'POINT (-118.495685 34.015986)', '2011 Supervisorial District Boundaries (Official)': '3', 'Census Tracts 2010': '372', 'Board Approved Statistical Areas': '93', 'Zip Codes': '25426', '_id': 'INS-DA0004KIJ', 'SEATING DETAILS': '1-1,999 SF'}
# => Inspections inserted into DB
# FA0019645
# FA0056432
# FA0241857
# FA0262822
# FA0158893
# FA0244948
# FA0244950
# FA0136876
# FA0136877
# Inventory first doc:
# {'FACILITY ID': 'FA0019645', 'FACILITY NAME': 'DREAM DINNERS', 'RECORD ID': 'PR0045642', ' PROGRAM NAME': 'DREAM DINNERS', 'PROGRAM ELEMENT (PE)': '1631', 'PE DESCRIPTION': 'RESTAURANT SEATS MODERATE RISK', 'FACILITY ADDRESS': '22226 PALOS VERDES BLVD', 'FACILITY CITY': 'TORRANCE', 'FACILITY  STATE': 'CA', 'FACILITY ZIP': '90505', 'FACILITY LATITUDE': '33.82615195', 'FACILITY LONGITUDE': '-118.368832', 'OWNER ID': 'OW0000809', 'OWNER NAME': '31', 'OWNER ADDRESS': '22226   PALOS VERDES BL', 'OWNER CITY': 'TORRANCE', 'OWNER STATE': 'CA', 'OWNER ZIP': '90505', 'Location': '(33.8261519457, -118.3688319755)', 'Census Tracts 2010': '820', '2011 Supervisorial District Boundaries (Official)': '4', 'Board Approved Statistical Areas': '102', 'Zip Codes': '25719', '_id': 'F_ID-FA0019645', 'SEATING DETAILS': '0-30'}
# => Inventory inserted into DB
# {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': '0'}
# {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F015', 'VIOLATION DESCRIPTION': '# 15. Food obtained from approved source', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA0007NP7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0007NP7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F013', 'VIOLATION DESCRIPTION': '# 13. Food in good condition, safe and unadulterated', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000ADVG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000ADVG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000H5QF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000H5QF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': '0'}
# {'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F038', 'VIOLATION DESCRIPTION': '# 38. Thermometers provided and accurate', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F029', 'VIOLATION DESCRIPTION': '# 29. Toxic substances properly identified, stored, used', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F009', 'VIOLATION DESCRIPTION': '# 09. Proper cooling methods', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': '0'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F029', 'VIOLATION DESCRIPTION': '# 29. Toxic substances properly identified, stored, used', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000PKSL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000PKSL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000PKSL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000UBD4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000UBD4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000UBD4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA000X7NB', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000X7NB', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F004', 'VIOLATION DESCRIPTION': '# 04. Proper eating, drinking, or tobacco use', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F027', 'VIOLATION DESCRIPTION': '# 27. Food separated and protected', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F026', 'VIOLATION DESCRIPTION': '# 26. Approved thawing methods used, frozen food maintained frozen', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F025', 'VIOLATION DESCRIPTION': '# 25. Personal cleanliness and hair restraints', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F009', 'VIOLATION DESCRIPTION': '# 09. Proper cooling methods', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA001KKC8', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA001KKC8', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F053', 'VIOLATION DESCRIPTION': '# 21a. Hot Water Available', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F005', 'VIOLATION DESCRIPTION': '# 05. Hands clean and properly washed; gloves used properly', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F021', 'VIOLATION DESCRIPTION': '# 21b. Water available', 'POINTS': '0'}
# {'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0024TXM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0024TXM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0024TXM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0027HDL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F052', 'VIOLATION DESCRIPTION': '# 01b. Food safety certification', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0027HDL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': '0'}
# {'SERIAL NUMBER': 'DA0027HDL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0027HDL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0027HDL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0027HDL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F027', 'VIOLATION DESCRIPTION': '# 27. Food separated and protected', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0027HDL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F009', 'VIOLATION DESCRIPTION': '# 09. Proper cooling methods', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA002AQHD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002AQHD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002AQHD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002AQHD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002AQHD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002AQHD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F027', 'VIOLATION DESCRIPTION': '# 27. Food separated and protected', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA002S00V', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA002Y9D4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F052', 'VIOLATION DESCRIPTION': '# 01b. Food safety certification', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA002Y9D4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002Y9D4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002Y9D4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002Y9D4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA002Y9D4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA002ZCBF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002ZCBF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002ZCBF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002ZCBF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002ZCBF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002ZCBF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA002ZCBF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00302GG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F055', 'VIOLATION DESCRIPTION': '# 01a. Demonstration of knowledge', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00302GG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00302GG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00302GG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00302GG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA0031FQQ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0031FQQ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA0031FQQ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA003BRRK', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003BRRK', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003BRRK', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003I28R', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003I28R', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003I28R', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003I28R', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F053', 'VIOLATION DESCRIPTION': '# 21a. Hot Water Available', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F029', 'VIOLATION DESCRIPTION': '# 29. Toxic substances properly identified, stored, used', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F026', 'VIOLATION DESCRIPTION': '# 26. Approved thawing methods used, frozen food maintained frozen', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F025', 'VIOLATION DESCRIPTION': '# 25. Personal cleanliness and hair restraints', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA003N7S4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA003SHHO', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA003SHHO', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': '1'}
# ...
# {'SERIAL NUMBER': 'DA00JUDXG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00JUDXG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F025', 'VIOLATION DESCRIPTION': '# 25. Personal cleanliness and hair restraints', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00JVCIO', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00JVCIO', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00JVCIO', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00JVCIO', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F009', 'VIOLATION DESCRIPTION': '# 09. Proper cooling methods', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00JXLNS', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00JXLNS', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00JXLNS', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00JXLNS', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00K0WAP', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': '0'}
# {'SERIAL NUMBER': 'DA00K0WAP', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00K0WAP', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00K0WAP', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F029', 'VIOLATION DESCRIPTION': '# 29. Toxic substances properly identified, stored, used', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00K0WAP', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA00K0WAP', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KCHS1', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KCHS1', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA00KCVDM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': '0'}
# {'SERIAL NUMBER': 'DA00KCVDM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KCVDM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KCVDM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KCVDM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KCVDM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F013', 'VIOLATION DESCRIPTION': '# 13. Food in good condition, safe and unadulterated', 'POINTS': '4'}
# {'SERIAL NUMBER': 'DA00KCVDM', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F005', 'VIOLATION DESCRIPTION': '# 05. Hands clean and properly washed; gloves used properly', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KFD3Q', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F052', 'VIOLATION DESCRIPTION': '# 01b. Food safety certification', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KFD3Q', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KFD3Q', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KFD3Q', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KFD3Q', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KFD3Q', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F026', 'VIOLATION DESCRIPTION': '# 26. Approved thawing methods used, frozen food maintained frozen', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KGHW0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KGHW0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KH0VL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KH0VL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F045', 'VIOLATION DESCRIPTION': '# 45. Sleeping quarters', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KH0VL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KH0VL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KH0VL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KHYTH', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KHYTH', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KIIPS', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KIIPS', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KIIPS', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F029', 'VIOLATION DESCRIPTION': '# 29. Toxic substances properly identified, stored, used', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KJDRD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F004', 'VIOLATION DESCRIPTION': '# 04. Proper eating, drinking, or tobacco use', 'POINTS': '2'}
# {'SERIAL NUMBER': 'DA00KOHT0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': '1'}
# {'SERIAL NUMBER': 'DA00KOHT0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': '1'}
# Violations first doc:
# {'DA0004KIJ': [{'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': '0'}, {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F015', 'VIOLATION DESCRIPTION': '# 15. Food obtained from approved source', 'POINTS': '2'}, {'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}], 'DA0004YWJ': [{'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': '2'}], 'DA0007F08': [{'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': '1'}, {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': '2'}, {'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': '4'}], 'DA0007NP7': [{'SERIAL NUMB ...
# => Violations inserted into DB
# here
# Calculating stats for:
# - Year = 2016
# - Category = FACILITY ZIP
# This is resultsAv:
#                mean  median   mode
# FACILITY ZIP
# 90004          98.0    98.0   [98]
# 90005          84.0    84.0   [84]
# 90007          96.0    96.0   [96]
# 90012          95.0    95.0   [95]
# 90013          83.0    83.0   [83]
# ...             ...     ...    ...
# 91789          98.0    98.0   [98]
# 91791         100.0   100.0  [100]
# 91792          90.0    90.0   [90]
# 93534          98.0    98.0   [98]
# 93536          96.0    96.0   [96]
#
# [75 rows x 3 columns]
# Calculating stats for:
# - Year = 2017
# - Category = SEATING DETAILS
# This is resultsAv:
#                       mean  median              mode
# SEATING DETAILS
# 0-30             93.682353    94.0            [90.0]
# 1-1,999 SF       95.966667    96.5            [99.0]
# 151 +            94.833333    95.0  [93, 95, 97, 98]
# 2,000+ SF        94.230769    96.0            [99.0]
# 31-60            93.619718    94.0            [90.0]
# 61-150           92.890909    93.0            [90.0]

# %%
avResultsWindow = Tk()
avResultsWindow.title('Averages Results')
avResultsWindow.geometry("600x400")
avResultsWindow.columnconfigure(0, weight=1)
avResultsWindow.rowconfigure(0, weight=1)
mainframe = ttk.Frame(avResultsWindow, padding="16 16 16 16")
mainframe.place(relheight=1, relwidth=1)

tree = ttk.Treeview(mainframe)
tree.place(relheight=1, relwidth=1)
treescrolly = Scrollbar(mainframe, orient='vertical', command=tree.yview)
treescrollx = Scrollbar(mainframe, orient='horizontal', command=tree.xview)
tree.configure(xscrollcommand=treescrollx.set, yscrollcommand=treescrolly.set)
treescrolly.pack(side='right', fill='y')
treescrollx.pack(side='bottom', fill='x')

# headings = ['1','2','3']
data = [['mode',1,2,3], ['mode',1,2,3], ['mode',1,2,3]]

# for h in headings:
#     tree.heading(h, text=h)
tree["columns"]=("one","two","three")
# tree.column("#0", width=270, minwidth=270)
tree.column("one", width=150, minwidth=150)
tree.column("two", width=400, minwidth=200)
tree.column("three", width=80, minwidth=50)

# tree.heading("#0",text="Name")
tree.heading("one", text="Date modified")
tree.heading("two", text="Type")
tree.heading("three", text="Size")
for d in data:
    tree.insert('','end', text=d[0], values=d[1:])
#     tree.insert('', 'end', text=d)
#     print(d)
# tree.heading(column, text='1')
# tree.insert('', 'end', text='Tutorial')
# tree.insert('','end',values='1')

# Level 1
# folder1=tree.insert("", 1, "", text="Folder 1", values=("23-Jun-17 11:05","File folder",""))
# tree.insert("", 2, "", text="text_file.txt", values=("23-Jun-17 11:25","TXT file","1 KB"))
# Level 2
# tree.insert('', "end", text="photo1.png", values=("22-Jun-17 11:28","PNG file","2.6 KB"))
# tree.insert('', "end", text="photo2.png", values=("24-Jun-17 11:29","o file","3.2 KB"))
# tree.insert('', "end", text="photo3.png", values=("25-Jun-17 11:30","p file","3.1 KB"))
avResultsWindow.mainloop()

# %%
calcAv = AveragesCalculator('2018', 'SEATING DETAILS')
df = calcAv.zipScores()

headings = df.columns

for h in headings:
    print(h)
# Out:
# Calculating stats for:
# - Year = 2018
# - Category = SEATING DETAILS
# mean
# median
# mode

# %%
df
# Out:
#                       mean  median          mode
# SEATING DETAILS
# 0-30             94.318841    95.0        [98.0]
# 1-1,999 SF       94.829787    96.0        [99.0]
# 151 +            94.562500    93.5        [93.0]
# 2,000+ SF        94.700000    95.0          [95]
# 31-60            93.375000    93.5  [90.0, 94.0]
# 61-150           92.673077    93.0  [92.0, 96.0]

# %%
nparr = df.to_numpy()
nparrIndex = df.index.to_numpy()
nparr
nparrIndex
# Out:
# array(['0-30', '1-1,999 SF', '151 + ', '2,000+ SF', '31-60', '61-150'],
#       dtype=object)

# %%
npa[0]
# Out:
# array([94.31884057971014, 95.0, list([98.0])], dtype=object)

# %%
for index, row in df.iterrows(): 
    print(index, row['mean'], row['mode'])
    break
# Out:
# 0-30 94.31884057971014 [98.0]

# %%
avResultsWindow = Tk()
avResultsWindow.title('Averages Results')
avResultsWindow.geometry("600x400")
avResultsWindow.columnconfigure(0, weight=1)
avResultsWindow.rowconfigure(0, weight=1)
mainframe = ttk.Frame(avResultsWindow, padding="16 16 16 16")
mainframe.place(relheight=1, relwidth=1)

tree = ttk.Treeview(mainframe)
tree.place(relheight=1, relwidth=1)
treescrolly = Scrollbar(mainframe, orient='vertical', command=tree.yview)
treescrollx = Scrollbar(mainframe, orient='horizontal', command=tree.xview)
tree.configure(xscrollcommand=treescrollx.set, yscrollcommand=treescrolly.set)
treescrolly.pack(side='right', fill='y')
treescrollx.pack(side='bottom', fill='x')

tree["columns"]=("one","two","three")
tree.column("#0", width=75, minwidth=75)
tree.column("one", width=75, minwidth=75)
tree.column("two", width=75, minwidth=75)
tree.column("three", width=75, minwidth=75)

tree.heading("#0",text="Seating")
tree.heading("one", text="Mean")
tree.heading("two", text="Median")
tree.heading("three", text="Mode")

data = df.to_numpy()

for index, row in df.iterrows(): 
    tree.insert('','end', text=index, values=[row['mean'],row['median'],row['mode']])
    
avResultsWindow.mainloop()
