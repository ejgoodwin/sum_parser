# %%
from tkinter import *
from tkinter import ttk, filedialog
from tkinter.filedialog import askopenfilename
import csv
from pathlib import Path
import pymongo
import numpy as np
# Use sentinel for missing values
from numpy import nan as NA
import pandas as pd
# For showing plots in tkinter
import matplotlib.pyplot as plt
from matplotlib.figure import Figure 
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,  
NavigationToolbar2Tk) 
import seaborn as sns
import tkinter.constants as Tkconstants

# connect to mongodb
client = pymongo.MongoClient("mongodb://localhost:27017")
# create db
db_formative = client["summative"]
# create collection
collection_vendors = db_formative["test-113"]

# %%
fileButtons = ["inspections", "inventory", "violations"]
fileRoutes = {fileButtons[0]:"", fileButtons[1]:"", fileButtons[2]:""}

# %%
class Parser(object):
    def __init__(self, collection, csvFile):
        self.collection = collection
        self.csvFile = csvFile
        self.inspectionsDF = None
        self.inventoryDF = None
        self.violationsDF = None
        
    def parseData(self):
        # Read CSV files and convert to Pandas DataFrames
        self.inspectionsDF = pd.read_csv(self.csvFile['inspections'])
        self.inventoryDF = pd.read_csv(self.csvFile['inventory'])
        self.violationsDF = pd.read_csv(self.csvFile['violations'])
        
        return self.inspectionsDF, self.inventoryDF, self.violationsDF

# %%
class DataCleaner(object):
    def __init__(self, inspections, inventory, violations):
        self.inspectionsDF = inspections
        self.inventoryDF = inventory
        self.violationsDF = violations
        
    def clean(self):
        print('cleaning')
        self.cleanInspections()
        return self.inspectionsDF, self.inventoryDF, self.violationsDF
        
    def cleanInspections(self):
        # Extract info from PE DESC column and create new col for SEATING DETAILS
        self.inspectionsDF['SEATING DETAILS'] = self.inspectionsDF['PE DESCRIPTION'].str.extract(r"\(([\S ]+)\)")
        print(f'seating deats \n{self.inspectionsDF["SEATING DETAILS"]}')
        print(f'pe desc \n{self.inspectionsDF["PE DESCRIPTION"]}')
        # Extract first part of Zip Code (e.g. '90001-1234', becomes '90001')
        self.inspectionsDF['FACILITY ZIP'] = self.inspectionsDF['FACILITY ZIP'].str.extract(r"([0-9]+)") 
        # Add '_id' for MongoDB      
        self.inspectionsDF['_id'] = 'INS_' + self.inspectionsDF['SERIAL NUMBER']

# %%
class DataLoader():
    def __init__(self, inspections, inventory, violations):
        self.inspectionsDF = inspections
        self.inventoryDF = inventory
        self.violationsDF = violations
        
    def loadToMongo(self):
        # use to_dict to format correctly for MongoDB
        inspectionsDict = self.inspectionsDF.to_dict(orient='records')
        inventoryDict = self.inventoryDF.to_dict(orient='records')
        violationsDict = self.violationsDF.to_dict(orient='records')
        # Insert into Mongo
        collection_vendors.insert_many(inspectionsDict)
        collection_vendors.insert_many(inventoryDict)
        collection_vendors.insert_many(violationsDict)
        # Embed violations
        self.formatViolations()
        # Test db
        test = collection_vendors.find({'_id':{'$regex':'INS_'}})
        for t in test:
            print(f'testing inspections: \n{t}')
            break
        print('inserted into Mongo')
        
    def formatViolations(self):
        # Add violations as embedded docs to inspections
        print('start cleaning violations')
        # Find all inspections
        resultsViolations = collection_vendors.find({'VIOLATION DESCRIPTION':{'$regex':'#'}})
        for result in resultsViolations:
            collection_vendors.update_one({'_id':{'$regex':'INS_'},'SERIAL NUMBER': result['SERIAL NUMBER']}, {'$addToSet': {'VIOLATIONS': result}})
        print('finish cleaning violations')

# %%
class ButtonUpload(object):
    def __init__(self, fileButtons, fileLabels, counter, mainframe):
        self.fileButtons = fileButtons
        self.fileLabels = fileLabels
        self.counter = counter
        self.mainframe = mainframe
        self.filePath = ''
        self.uploadLabel = StringVar()

    def browseFile(self):
        self.filePath = askopenfilename(filetypes=[("CSV files", ".csv")])
        fileName = Path(self.filePath)
        self.uploadLabel.set(fileName.name)
        print(self.filePath)
        self.setFileRoutes()
    
    def setFileRoutes(self):
        fileRoutes[self.fileButtons] = self.filePath
        print(fileRoutes)
        
    def createButton(self):
        ttk.Label(self.mainframe, text=f"Upload data: {self.fileButtons}", anchor="w").grid(row=self.counter+1, column=0, sticky="w")
        Button(self.mainframe, text="Upload file", command=self.browseFile).grid(row=self.counter+1, column=1, sticky="w")
        ttk.Label(self.mainframe, textvariable=self.uploadLabel).grid(row=self.counter+1, column=2, sticky="w")

# %%
class AveragesCalculator(object):
    def __init__(self, year, category):
        self.year = year
        self.category = category
        
    def zipScores(self):
        print(f'Calculating stats for: \n- Year = {self.year} \n- Category = {self.category}')
        # Find inspection documents - look in ispections (INS_) with year
        resultsInspections = collection_vendors.find({'_id':{'$regex':'INS_'},'ACTIVITY DATE':{'$regex':self.year}, 'PROGRAM STATUS': 'ACTIVE'})

        # Create dict of facility zips with lists of their scores
        zipScoresDict = {}  
        for r in resultsInspections:
            key = r[self.category]
            if key in zipScoresDict:
                zipScoresDict[r[self.category]].append(r['SCORE'])
            else:
                zipScoresDict[key] = [r['SCORE']]
        return self.calcZipStats(zipScoresDict)


    def calcZipStats(self, zipScoresDict):
        zipScoresMean = {}
        zipScoresMean = {self.category:[],'mean':[],'median':[],'mode':[]}
        for x in zipScoresDict:
            # Create Series to calc mean, mode, median
            tempSeries = pd.Series(zipScoresDict[x])
            mean = tempSeries.mean()
            mode = tempSeries.mode().tolist()
            median = tempSeries.median()

            # mean, mode, median as columns
            zipScoresMean[self.category].append(x)
            zipScoresMean['mean'].append(mean)
            zipScoresMean['median'].append(median)
            zipScoresMean['mode'].append(mode)

        # Create DataFrame
        zipScoresDF = pd.DataFrame(zipScoresMean)
        # sort by ascending cat - easier to find for user (esp. zip)
        zipScoresDF.sort_values(by=[self.category],inplace=True)
        # set cat as index
        zipScores_noIndex = zipScoresDF.set_index(self.category)
        
        return zipScores_noIndex

# %%
class UserInterface(object):
    def __init__(self, title):
        self.title = title
        self.mainframe = None
        self.window = Tk()
        self.window.title(self.title)
        self.window.geometry("1200x800")
        self.window.columnconfigure(0, weight=1)
        self.window.rowconfigure(0, weight=1)
        self.calcCategory = StringVar()
        self.calcYear = StringVar()
        self.dataDict = None
        self.violationsDF = None
        self.window.rowconfigure( 0, weight=1 )     # You need to add this. 
        self.window.columnconfigure( 0, weight=1 )  # You need to add this.
        
    def createWindow(self):
        self.createInitialFrame()
        self.window.mainloop()
        
    def createInitialFrame(self):
         # variables
        labelTextOne = StringVar()
        labelTextTwo = StringVar()
        labelTextThree = StringVar()
        fileLabels = [labelTextOne, labelTextTwo, labelTextThree]
        # Config layout
        self.mainframe = ttk.Frame(self.window, padding="16 16 16 16")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        self.mainframe.grid_rowconfigure(4, weight=1)
        self.mainframe.grid_columnconfigure(2, weight=1)
        heading = ttk.Label(self.mainframe, text="Load your dataset", anchor="w").grid(row=0, sticky="nw")
        # Create buttons for file uploads
        for i in range(0, len(fileButtons)): 
            newButton = ButtonUpload(fileButtons[i], fileLabels[i], i, self.mainframe)
            newButton.createButton()
        # Buttons for Cancel and Clean & Save
        footer = ttk.Frame(self.window, padding="16 0 0 0").grid(row=5, column=1)
        cancelButton = Button(self.mainframe, text="Cancel & exit", bg="red").grid(row=4, column=0, sticky="sw")
        saveButton = Button(self.mainframe, text="Save", command=self.handleSave).grid(row=4, column=2,sticky="se")
        
    def handleSave(self):
        self.loadingFrame('Your data is being parsed and loaded into MongoDB...')
        parser = Parser(collection_vendors, fileRoutes)
        parsedData = parser.parseData()
        self.violationsDF = parsedData[2]
        # Clean data - pass data returned from parser
        cleaner = DataCleaner(*parsedData)
        cleanedData = cleaner.clean()
        # Insert to MongoDB - pass data returned from cleaner
        loader = DataLoader(*cleanedData)
        loader.loadToMongo()
        print('done handleSave')
        self.createNotebook()
    
    def loadingFrame(self, text):
        self.mainframe.destroy()
        self.mainframe = ttk.Frame(self.window, padding="16 16 16 16")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        heading = ttk.Label(self.mainframe, text="Please wait:", anchor="w").grid(row=0, sticky="nw")
        subheading = ttk.Label(self.mainframe, text=text, anchor="w").grid(row=1, sticky="nw")
        
    def createNotebook(self):
        print('Creating Notebook (Tabs)')
        self.mainframe.destroy()
        self.mainframe = ttk.Notebook(self.window)
        f1 = ttk.Frame(self.mainframe)  
        f2 = ttk.Frame(self.mainframe)  
        f3 = ttk.Frame(self.mainframe) 
        self.mainframe.add(f1, text='Averages')
        self.mainframe.add(f2, text='Violations per Establishment')
        self.mainframe.add(f3, text='Correlations')
        # ====== Widget for tab 1
        heading_one = ttk.Label(f1, text="Mean, Mode and Median", anchor="w").grid(row=0, sticky="nw")
        # Radio - Type
        radioHeadingOne = ttk.Label(f1, text="Calculate by seating type or zip codes:", anchor="w").grid(row=0, sticky="nw")
        Radiobutton(f1, text="Vendor seating type", padx = 20, variable=self.calcCategory, value='SEATING DETAILS').grid(row=1, column=0, sticky='w')
        Radiobutton(f1, text="Zip Code", padx = 20, variable=self.calcCategory, value='FACILITY ZIP').grid(row=2, column=0, sticky='w')
        # Radio - Years
        radioHeadingTwo = ttk.Label(f1, text="Select Year", anchor="w").grid(row=3, sticky="nw")
        yearsArr = ['2016', '2017', '2018', '2019']
        for i in range(len(yearsArr)):
            Radiobutton(f1, text=yearsArr[i], padx = 20, variable=self.calcYear, value=yearsArr[i]).grid(row=i+4, column=0, sticky='w')
        # Calc button
        calcButton = Button(f1, text="Calculate", command=self.calcAverages).grid(row=8, column=0, sticky="sw")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        
        # ====== Widget for tab 2
        heading_two = ttk.Label(f2, text="Violations per Establishment", anchor="w").grid(row=0, sticky="nw")
        self.createViolationsPlot(f2)
        
        # ====== Widget for tab 3
        heading_two = ttk.Label(f3, text="Correlation between the number of violations commited per vendor and their zip code", anchor="w").grid(row=0, sticky="nw")
        correlationsButton = Button(f3, text="Show correlations plot", command=self.createCorrelationsPlot).grid(row=1, column=0, sticky="sw")
        
    def createViolationsPlot(self, f2):
        # Create dict with violation codes as keys and no. of facilities that commited that violation as values
        vioDict = {}
        # Sort the violation codes for easier reading for user
        violationsList = self.violationsDF['VIOLATION CODE'].unique()
        sortedCodes = sorted(violationsList)
        for v in sortedCodes:
            resultsInspections = collection_vendors.find({'VIOLATIONS.VIOLATION CODE':v}, {'FACILITY NAME':1})
            # Hash map to see if facility has been included - only need ONE instance of violation per facility
            facilityNames = {}
            for r in resultsInspections:
                # if facility name has already been counted, continue to next loop
                if r['FACILITY NAME'] in facilityNames:
                    continue
                # else, facility name has not yet been counted, add appropriately
                else:
                    if v in vioDict:
                        vioDict[v] = vioDict[v] + 1
                    else:
                        vioDict[v] = 1

        
        # Display violations vs no. of establishments
        vioKeys = list(vioDict.keys())
        vioVals = list(vioDict.values())
        # Create 4 subplots using slices of the keys & values lists
        fig,a =  plt.subplots(2,2)
        a[0][0].bar(vioKeys[:round(len(vioKeys)*0.25)], vioVals[:round(len(vioKeys)*0.25)])
        a[0][1].bar(vioKeys[round(len(vioKeys)*0.25):round(len(vioKeys)*0.5)], vioVals[round(len(vioKeys)*0.25):round(len(vioKeys)*0.5)])
        a[1][0].bar(vioKeys[round(len(vioKeys)*0.5):round(len(vioKeys)*0.75)], vioVals[round(len(vioKeys)*0.5):round(len(vioKeys)*0.75)])
        a[1][1].bar(vioKeys[round(len(vioKeys)*0.75):], vioVals[round(len(vioKeys)*0.75):])
        # Show in console as well as window
        plt.show()

        # creating the Tkinter canvas containing the Matplotlib figure 
        canvas = FigureCanvasTkAgg(fig, master = f2)   
        canvas.draw() 

        # grid the canvas on the Tkinter window 
        canvas.get_tk_widget().place(relheight=1, relwidth=1) 
        
    def createCorrelationsPlot(self):
        # Find number of violations per vendor, and their zip code
        insVios = collection_vendors.find({'_id':{'$regex':'INS_'}, 'PROGRAM STATUS': 'ACTIVE'}, {'FACILITY ID':1,'VIOLATIONS':1, 'FACILITY ZIP':1})
        # 
        insViosDict = {}
        for r in insVios:
            if 'VIOLATIONS' in r:

                if r['FACILITY ID'] in insViosDict:
                    insViosDict[r['FACILITY ID']]['quant'] = insViosDict[r['FACILITY ID']]['quant'] + len(r['VIOLATIONS'])
                else:
                    insViosDict[r['FACILITY ID']] = {}
                    insViosDict[r['FACILITY ID']]['quant'] = len(r['VIOLATIONS'])
                    insViosDict[r['FACILITY ID']]['zip'] = r['FACILITY ZIP']

        total = {'quantity':[], 'zip': []}
        for x in insViosDict:
            total['quantity'].append(int(insViosDict[x]['quant']))
            total['zip'].append('. '+insViosDict[x]['zip'])
            type(total['quantity'])

        type(total['quantity'][0]) 
                
        #  Create DataFrame - sorted by zip to make visualisations easier to understand
        insViosDF = pd.DataFrame(total)
        insViosDF.sort_values(by=['quantity'],inplace=True)
        
        # New window
        window = Tk()
        window.title(self.title)
        window.geometry("1200x800")
        window.columnconfigure(0, weight=1)
        window.rowconfigure(0, weight=1)
        
        # Scroll Y
        frame=Frame(window)
        frame.grid(row=0,column=0)
        frame.columnconfigure(0, weight=1)
        frame.rowconfigure(0, weight=1)
        canvas = Canvas(frame)
        canvas.grid(row=0, column=0, sticky=Tkconstants.NSEW)
        yScrollbar = Scrollbar(frame)
        yScrollbar.grid(row=0, column=1, sticky=Tkconstants.NS)
        canvas.config(yscrollcommand=yScrollbar.set)
        yScrollbar.config(command=canvas.yview)
        
        
        # Creating the figure and Seaborn plot
        figure = Figure(figsize=(8, 30))
        ax = figure.subplots()
        sns.barplot(x="quantity", y="zip", data=insViosDF, label="Total", color="b", ax=ax)
        
        # create the Tkinter canvas 
        canvasInner = FigureCanvasTkAgg(figure, master = canvas)   
        canvasInner.draw() 

        # place the canvas on the Tkinter window 
        mplCanvas = canvasInner.get_tk_widget()
        
        cwid = canvas.create_window(0, 0, window=mplCanvas, anchor=Tkconstants.NW)
        canvas.config(scrollregion=canvas.bbox(Tkconstants.ALL),width=800,height=800)
        
#         window.mainloop()
    
    def calcAverages(self):
        calcCatVal = self.calcCategory.get()
        calcYearVal = self.calcYear.get()
        calcAv = AveragesCalculator(calcYearVal, calcCatVal)
        avResults = calcAv.zipScores()
        self.averagesResultsFrame(avResults, calcYearVal, calcCatVal)
        
    def averagesResultsFrame(self, resultsAv, calcYearVal, calcCatVal):
        avResultsWindow = Tk()
        avResultsWindow.title(f'Averages Results for {calcCatVal} in {calcYearVal}')
        avResultsWindow.geometry("600x400")
#         avResultsWindow.columnconfigure(0, weight=1)
#         avResultsWindow.rowconfigure(0, weight=1)
        mainframe = ttk.Frame(avResultsWindow, padding="16 16 16 16")
        mainframe.place(relheight=1, relwidth=1)

        tree = ttk.Treeview(mainframe)
        tree.place(relheight=1, relwidth=1)
        treescrolly = Scrollbar(mainframe, orient='vertical', command=tree.yview)
        treescrollx = Scrollbar(mainframe, orient='horizontal', command=tree.xview)
        tree.configure(xscrollcommand=treescrollx.set, yscrollcommand=treescrolly.set)
        treescrolly.pack(side='right', fill='y')
        treescrollx.pack(side='bottom', fill='x')

        tree["columns"]=("one","two","three")
        tree.column("#0", width=75, minwidth=75)
        tree.column("one", width=75, minwidth=75)
        tree.column("two", width=75, minwidth=75)
        tree.column("three", width=75, minwidth=75)

        tree.heading("#0",text="Seating")
        tree.heading("one", text="Mean")
        tree.heading("two", text="Median")
        tree.heading("three", text="Mode")

        for index, row in resultsAv.iterrows(): 
            tree.insert('','end', text=index, values=[row['mean'],row['median'],row['mode']])
        print(f'This is resultsAv: \n{resultsAv}')

# %%
ui = UserInterface('summative')
ui.createWindow()
# Out:
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv', 'inventory': '', 'violations': ''}
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv', 'inventory': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv', 'violations': ''}
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/violations_md.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections_md.csv', 'inventory': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv', 'violations': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/violations_md.csv'}
# cleaning
# seating deats
# 0      1-1,999 SF
# 1      1-1,999 SF
# 2           31-60
# 3            0-30
# 4            0-30
#           ...
# 994        61-150
# 995          0-30
# 996    1-1,999 SF
# 997          0-30
# 998        61-150
# Name: SEATING DETAILS, Length: 999, dtype: object
# pe desc
# 0       FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 1      FOOD MKT RETAIL (1-1,999 SF) HIGH RISK
# 2          RESTAURANT (31-60) SEATS HIGH RISK
# 3           RESTAURANT (0-30) SEATS HIGH RISK
# 4           RESTAURANT (0-30) SEATS HIGH RISK
#                         ...
# 994       RESTAURANT (61-150) SEATS HIGH RISK
# 995     RESTAURANT (0-30) SEATS MODERATE RISK
# 996     FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 997         RESTAURANT (0-30) SEATS HIGH RISK
# 998        RESTAURANT (61-150) SEATS LOW RISK
# Name: PE DESCRIPTION, Length: 999, dtype: object
# start cleaning violations
# finish cleaning violations
# testing inspections:
# {'_id': 'INS_DA0004KIJ', 'ACTIVITY DATE': '02/07/2019', 'OWNER ID': 'OW0099597', 'OWNER NAME': 'ZARE INVESTMENTS INC', 'FACILITY ID': 'FA0067946', 'FACILITY NAME': 'ONE STOP SHOP MART', 'RECORD ID': 'PR0040362', 'PROGRAM NAME': 'ONE STOP SHOP MART', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1610, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) LOW RISK', 'FACILITY ADDRESS': '314 SANTA&#160;MONICA BLVD', 'FACILITY CITY': 'SANTA&#160;MONICA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90401', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 93.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA0004KIJ', 'EMPLOYEE ID': 'EE0001005', 'Location': 'POINT (-118.495685 34.015986)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 372.0, 'Board Approved Statistical Areas': 93.0, 'Zip Codes': 25426.0, 'SEATING DETAILS': '1-1,999 SF', 'VIOLATIONS': [{'_id': ObjectId('5fddeeb48bb8e37d4441b3df'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': 0}, {'_id': ObjectId('5fddeeb48bb8e37d4441b3e0'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': 1}, {'_id': ObjectId('5fddeeb48bb8e37d4441b3e1'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': 1}, {'_id': ObjectId('5fddeeb48bb8e37d4441b3e2'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F015', 'VIOLATION DESCRIPTION': '# 15. Food obtained from approved source', 'POINTS': 2}, {'_id': ObjectId('5fddeeb48bb8e37d4441b3e3'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# inserted into Mongo
# done handleSave
# Creating Notebook (Tabs)

# %%
test = collection_vendors.find({'_id': {'$regex':'DA'}})
for t in test:
    print(t)
# Out:
# {'_id': 'INS_DA0004KIJ', 'ACTIVITY DATE': '02/07/2019', 'OWNER ID': 'OW0099597', 'OWNER NAME': 'ZARE INVESTMENTS INC', 'FACILITY ID': 'FA0067946', 'FACILITY NAME': 'ONE STOP SHOP MART', 'RECORD ID': 'PR0040362', 'PROGRAM NAME': 'ONE STOP SHOP MART', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1610, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) LOW RISK', 'FACILITY ADDRESS': '314 SANTA&#160;MONICA BLVD', 'FACILITY CITY': 'SANTA&#160;MONICA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90401', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 93.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA0004KIJ', 'EMPLOYEE ID': 'EE0001005', 'Location': 'POINT (-118.495685 34.015986)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 372.0, 'Board Approved Statistical Areas': 93.0, 'Zip Codes': 25426.0, 'SEATING DETAILS': '1-1,999 SF', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4ba'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': 0}, {'_id': ObjectId('5fdd212a3f3b639c0491c4bb'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4bc'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4bd'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F015', 'VIOLATION DESCRIPTION': '# 15. Food obtained from approved source', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c4be'), 'SERIAL NUMBER': 'DA0004KIJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# {'_id': 'INS_DA0004YWJ', 'ACTIVITY DATE': '12/17/2018', 'OWNER ID': 'OW0255399', 'OWNER NAME': 'NRP GLOBAL INC.', 'FACILITY ID': 'FA0264213', 'FACILITY NAME': 'SUPER TIENDA LATINA MEAT MARKET', 'RECORD ID': 'PR0215282', 'PROGRAM NAME': 'SUPER TIENDA LATINA MEAT MARKET', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1612, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) HIGH RISK', 'FACILITY ADDRESS': '10423 S NORMANDIE AVE', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90044', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 91.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA0004YWJ', 'EMPLOYEE ID': 'EE0001108', 'Location': 'POINT (-118.300276 33.941561)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 1070.0, 'Board Approved Statistical Areas': 114.0, 'Zip Codes': 23675.0, 'SEATING DETAILS': '1-1,999 SF', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4bf'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c0'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c1'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c2'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c3'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c4'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c5'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c6'), 'SERIAL NUMBER': 'DA0004YWJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# {'_id': 'INS_DA0007F08', 'ACTIVITY DATE': '07/12/2018', 'OWNER ID': 'OW0018671', 'OWNER NAME': 'KEIU, ANDY', 'FACILITY ID': 'FA0002190', 'FACILITY NAME': 'PHO SO 1', 'RECORD ID': 'PR0008114', 'PROGRAM NAME': 'PHO SO 1', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1635, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS HIGH RISK', 'FACILITY ADDRESS': '6450 SEPULVEDA BLVD STE C-D', 'FACILITY CITY': 'VAN NUYS', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91411', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 90.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA0007F08', 'EMPLOYEE ID': 'EE0000609', 'Location': 'POINT (-118.466185 34.188011)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 39.0, 'Board Approved Statistical Areas': 430.0, 'Zip Codes': 19735.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4c7'), 'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c8'), 'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4c9'), 'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ca'), 'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4cb'), 'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c4cc'), 'SERIAL NUMBER': 'DA0007F08', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': 4}]}
# {'_id': 'INS_DA0007NP7', 'ACTIVITY DATE': '08/16/2017', 'OWNER ID': 'OW0038850', 'OWNER NAME': 'WHOLE FOODS MARKET, INC.', 'FACILITY ID': 'FA0055091', 'FACILITY NAME': 'WHOLE FOODS MARKET #39', 'RECORD ID': 'PR0003009', 'PROGRAM NAME': 'WHOLE FOODS #39-DELI', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '18700 VENTURA BLVD', 'FACILITY CITY': 'TARZANA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91356', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 98.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA0007NP7', 'EMPLOYEE ID': 'EE0000683', 'Location': 'POINT (-118.540361 34.170536)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 342.0, 'Board Approved Statistical Areas': 422.0, 'Zip Codes': 19339.0, 'SEATING DETAILS': '0-30', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4cd'), 'SERIAL NUMBER': 'DA0007NP7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ce'), 'SERIAL NUMBER': 'DA0007NP7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}]}
# {'_id': 'INS_DA0009NS7', 'ACTIVITY DATE': '06/05/2018', 'OWNER ID': 'OW0007608', 'OWNER NAME': 'CHIPOTLE MEXICAN GRILL, INC.', 'FACILITY ID': 'FA0159039', 'FACILITY NAME': 'CHIPOTLE MEXICAN GRILL', 'RECORD ID': 'PR0147108', 'PROGRAM NAME': 'CHIPOTLE MEXICAN GRILL', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '1133 GALLERIA WAY FC12', 'FACILITY CITY': 'GLENDALE', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91210', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 90.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA0009NS7', 'EMPLOYEE ID': 'EE0000235', 'Location': nan, '2011 Supervisorial District Boundaries (Official)': nan, 'Census Tracts 2010': nan, 'Board Approved Statistical Areas': nan, 'Zip Codes': nan, 'SEATING DETAILS': '0-30', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4cf'), 'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d0'), 'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d1'), 'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d2'), 'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d3'), 'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F013', 'VIOLATION DESCRIPTION': '# 13. Food in good condition, safe and unadulterated', 'POINTS': 4}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d4'), 'SERIAL NUMBER': 'DA0009NS7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': 2}]}
# {'_id': 'INS_DA000ADVG', 'ACTIVITY DATE': '10/27/2017', 'OWNER ID': 'OW0017276', 'OWNER NAME': 'JACK IN THE BOX, INC', 'FACILITY ID': 'FA0018414', 'FACILITY NAME': 'JACK IN THE BOX #280', 'RECORD ID': 'PR0046574', 'PROGRAM NAME': 'JACK IN THE BOX #280', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1634, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS MODERATE RISK', 'FACILITY ADDRESS': '10967 SANTA&#160;MONICA BLVD', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90025', 'SERVICE CODE': 401, 'SERVICE DESCRIPTION': 'OWNER INITIATED ROUTINE INSPECT.', 'SCORE': 98.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000ADVG', 'EMPLOYEE ID': 'EE0000375', 'Location': 'POINT (-118.440717 34.048832)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 571.0, 'Board Approved Statistical Areas': 60.0, 'Zip Codes': 23443.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4d5'), 'SERIAL NUMBER': 'DA000ADVG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d6'), 'SERIAL NUMBER': 'DA000ADVG', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}]}
# {'_id': 'INS_DA000AXL0', 'ACTIVITY DATE': '08/02/2017', 'OWNER ID': 'OW0039192', 'OWNER NAME': 'WOOD RANCH ARCADIA LP', 'FACILITY ID': 'FA0041356', 'FACILITY NAME': 'WOOD RANCH BBQ & GRILL', 'RECORD ID': 'PR0037689', 'PROGRAM NAME': 'WOOD RANCH BBQ & GRILL', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1641, 'PE DESCRIPTION': 'RESTAURANT (151 + ) SEATS HIGH RISK', 'FACILITY ADDRESS': '400 S BALDWIN AVE # 905L', 'FACILITY CITY': 'ARCADIA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91007', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 95.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000AXL0', 'EMPLOYEE ID': 'EE0000886', 'Location': 'POINT (-118.05425 34.1341)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 1818.0, 'Board Approved Statistical Areas': 285.0, 'Zip Codes': 2447.0, 'SEATING DETAILS': '151 + ', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4d7'), 'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d8'), 'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4d9'), 'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4da'), 'SERIAL NUMBER': 'DA000AXL0', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': 2}]}
# {'_id': 'INS_DA000H5QF', 'ACTIVITY DATE': '02/06/2019', 'OWNER ID': 'OW0027458', 'OWNER NAME': 'PANDA EXPRESS INC.', 'FACILITY ID': 'FA0043096', 'FACILITY NAME': 'PANDA EXPRESS # 248', 'RECORD ID': 'PR0042506', 'PROGRAM NAME': 'PANDA EXPRESS # 248', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1638, 'PE DESCRIPTION': 'RESTAURANT (61-150) SEATS HIGH RISK', 'FACILITY ADDRESS': '350 S GRAND AVE # # R1A', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90071', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 98.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000H5QF', 'EMPLOYEE ID': 'EE0001110', 'Location': 'POINT (-118.251985 34.052145)', '2011 Supervisorial District Boundaries (Official)': 1.0, 'Census Tracts 2010': 540.0, 'Board Approved Statistical Areas': 343.0, 'Zip Codes': 24035.0, 'SEATING DETAILS': '61-150', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4db'), 'SERIAL NUMBER': 'DA000H5QF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4dc'), 'SERIAL NUMBER': 'DA000H5QF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}]}
# {'_id': 'INS_DA000HN2Y', 'ACTIVITY DATE': '10/23/2017', 'OWNER ID': 'OW0245269', 'OWNER NAME': 'SABA G. MENGESHA', 'FACILITY ID': 'FA0251319', 'FACILITY NAME': 'QUEEN SHEBA ETHIOPIAN RESTAURANT', 'RECORD ID': 'PR0200447', 'PROGRAM NAME': 'QUEEN SHEBA ETHIOPIAN RESTAURANT', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '630 N LA BREA AVE # 106', 'FACILITY CITY': 'INGLEWOOD', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90302', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 90.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000HN2Y', 'EMPLOYEE ID': 'EE0000836', 'Location': 'POINT (-118.357354 33.971127)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 945.0, 'Board Approved Statistical Areas': 13.0, 'Zip Codes': 25422.0, 'SEATING DETAILS': '0-30', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4dd'), 'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': 0}, {'_id': ObjectId('5fdd212a3f3b639c0491c4de'), 'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4df'), 'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F038', 'VIOLATION DESCRIPTION': '# 38. Thermometers provided and accurate', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e0'), 'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F034', 'VIOLATION DESCRIPTION': '# 34. Warewashing facilities: Adequate, maintained, properly use, test strips available', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e1'), 'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F029', 'VIOLATION DESCRIPTION': '# 29. Toxic substances properly identified, stored, used', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e2'), 'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F009', 'VIOLATION DESCRIPTION': '# 09. Proper cooling methods', 'POINTS': 4}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e3'), 'SERIAL NUMBER': 'DA000HN2Y', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# {'_id': 'INS_DA000IIIF', 'ACTIVITY DATE': '09/18/2017', 'OWNER ID': 'OW0017673', 'OWNER NAME': 'JIMENEZ, EFREN SANDOVAL', 'FACILITY ID': 'FA0013745', 'FACILITY NAME': 'CASA JIMENEZ', 'RECORD ID': 'PR0042290', 'PROGRAM NAME': 'CASA JIMENEZ', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '3601 ABBOTT RD', 'FACILITY CITY': 'LYNWOOD', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90262', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 94.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000IIIF', 'EMPLOYEE ID': 'EE0001128', 'Location': 'POINT (-118.207104 33.936237)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 855.0, 'Board Approved Statistical Areas': 70.0, 'Zip Codes': 24691.0, 'SEATING DETAILS': '0-30', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4e4'), 'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e5'), 'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e6'), 'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e7'), 'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4e8'), 'SERIAL NUMBER': 'DA000IIIF', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': 2}]}
# {'_id': 'INS_DA000LME7', 'ACTIVITY DATE': '08/18/2017', 'OWNER ID': 'OW0014813', 'OWNER NAME': 'HAPPY WINGS FACTORY INC.', 'FACILITY ID': 'FA0055364', 'FACILITY NAME': 'WINGSTOP', 'RECORD ID': 'PR0017854', 'PROGRAM NAME': 'WINGSTOP', 'PROGRAM STATUS': 'INACTIVE', 'PROGRAM ELEMENT (PE)': 1631, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS MODERATE RISK', 'FACILITY ADDRESS': '1754 W SLAUSON AVE STE #A', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90047', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 87.0, 'GRADE': 'B', 'SERIAL NUMBER': 'DA000LME7', 'EMPLOYEE ID': 'EE0001093', 'Location': 'POINT (-118.308467 33.989155)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 867.0, 'Board Approved Statistical Areas': 439.0, 'Zip Codes': 23678.0, 'SEATING DETAILS': '0-30', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4e9'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F049', 'VIOLATION DESCRIPTION': '# 50. Impoundment of unsanitary equipment or food', 'POINTS': 0}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ea'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4eb'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F042', 'VIOLATION DESCRIPTION': '# 42. Toilet facilities: properly constructed, supplied, cleaned', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ec'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ed'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ee'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ef'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f0'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F007', 'VIOLATION DESCRIPTION': '# 07. Proper hot and cold holding temperatures', 'POINTS': 4}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f1'), 'SERIAL NUMBER': 'DA000LME7', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# {'_id': 'INS_DA000NWBX', 'ACTIVITY DATE': '09/12/2016', 'OWNER ID': 'OW0004910', 'OWNER NAME': 'BOBA BEAR, LLC', 'FACILITY ID': 'FA0058509', 'FACILITY NAME': 'BOBA BEAR', 'RECORD ID': 'PR0032470', 'PROGRAM NAME': 'BOBA BEAR', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1634, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS MODERATE RISK', 'FACILITY ADDRESS': '414 S WESTERN AVE STE #C', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90020', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 90.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000NWBX', 'EMPLOYEE ID': 'EE0000869', 'Location': 'POINT (-118.309108 34.066607)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 1310.0, 'Board Approved Statistical Areas': 66.0, 'Zip Codes': 23081.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4f2'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F046', 'VIOLATION DESCRIPTION': '# 46. Signs posted; last inspection report available', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f3'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f4'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f5'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f6'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f7'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f8'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c4f9'), 'SERIAL NUMBER': 'DA000NWBX', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# {'_id': 'INS_DA000NZHE', 'ACTIVITY DATE': '10/26/2016', 'OWNER ID': 'OW0029053', 'OWNER NAME': 'PRODROMOS, BEGAKIS M', 'FACILITY ID': 'FA0032856', 'FACILITY NAME': 'SHERMAN OAKS CASTLE PARK', 'RECORD ID': 'PR0041635', 'PROGRAM NAME': 'SHERMAN OAKS CASTLE PARK', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1635, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS HIGH RISK', 'FACILITY ADDRESS': '4989 SEPULVEDA BLVD', 'FACILITY CITY': 'SHERMAN OAKS', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91403', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 94.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000NZHE', 'EMPLOYEE ID': 'EE0000682', 'Location': 'POINT (-118.466164 34.1611)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 450.0, 'Board Approved Statistical Areas': 44.0, 'Zip Codes': 19732.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c4fa'), 'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4fb'), 'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4fc'), 'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4fd'), 'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F036', 'VIOLATION DESCRIPTION': '# 36. Equipment, utensils and linens: storage and use', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4fe'), 'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c4ff'), 'SERIAL NUMBER': 'DA000NZHE', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F029', 'VIOLATION DESCRIPTION': '# 29. Toxic substances properly identified, stored, used', 'POINTS': 1}]}
# {'_id': 'INS_DA000OA5J', 'ACTIVITY DATE': '06/06/2017', 'OWNER ID': 'OW0127910', 'OWNER NAME': 'PIE SQUARED PIZZA LLC', 'FACILITY ID': 'FA0164574', 'FACILITY NAME': 'PIZZA REV', 'RECORD ID': 'PR0152854', 'PROGRAM NAME': 'PIZZA REV', 'PROGRAM STATUS': 'INACTIVE', 'PROGRAM ELEMENT (PE)': 1634, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS MODERATE RISK', 'FACILITY ADDRESS': '3150 WILSHIRE BLVD #114', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90010', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 93.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000OA5J', 'EMPLOYEE ID': 'EE0000946', 'Location': 'POINT (-118.291027 34.061791)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 997.0, 'Board Approved Statistical Areas': 61.0, 'Zip Codes': 22722.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c500'), 'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F043', 'VIOLATION DESCRIPTION': '# 43. Premises; personal/cleaning items; vermin-proofing', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c501'), 'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c502'), 'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c503'), 'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c504'), 'SERIAL NUMBER': 'DA000OA5J', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# {'_id': 'INS_DA000PKSL', 'ACTIVITY DATE': '05/11/2017', 'OWNER ID': 'OW0029176', 'OWNER NAME': 'QADRI, MAHMOOD', 'FACILITY ID': 'FA0064724', 'FACILITY NAME': 'KENTUCKY FRIED CHICKEN', 'RECORD ID': 'PR0038248', 'PROGRAM NAME': 'KENTUCKY FRIED CHICKEN', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1634, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS MODERATE RISK', 'FACILITY ADDRESS': '542 N DIAMOND BAR BLVD', 'FACILITY CITY': 'DIAMOND BAR', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91765', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 97.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000PKSL', 'EMPLOYEE ID': 'EE0000742', 'Location': 'POINT (-117.809984 34.029796)', '2011 Supervisorial District Boundaries (Official)': 4.0, 'Census Tracts 2010': 2313.0, 'Board Approved Statistical Areas': 302.0, 'Zip Codes': 9741.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c505'), 'SERIAL NUMBER': 'DA000PKSL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c506'), 'SERIAL NUMBER': 'DA000PKSL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c507'), 'SERIAL NUMBER': 'DA000PKSL', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}]}
# {'_id': 'INS_DA000RJCK', 'ACTIVITY DATE': '08/10/2018', 'OWNER ID': 'OW0016271', 'OWNER NAME': 'HONG, DENG', 'FACILITY ID': 'FA0065791', 'FACILITY NAME': 'LITTLE BOHEMIA TAVERN', 'RECORD ID': 'PR0029400', 'PROGRAM NAME': 'LITTLE BOHEMIA TAVERN', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1630, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS LOW RISK', 'FACILITY ADDRESS': '9535 LAS TUNAS DR', 'FACILITY CITY': 'TEMPLE CITY', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91780', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 100.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000RJCK', 'EMPLOYEE ID': 'EE0000242', 'Location': 'POINT (-118.062523 34.106466)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 1772.0, 'Board Approved Statistical Areas': 101.0, 'Zip Codes': 10139.0, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA000UBD4', 'ACTIVITY DATE': '04/17/2017', 'OWNER ID': 'OW0005881', 'OWNER NAME': 'CAL-SIN ENTERPRISES INC', 'FACILITY ID': 'FA0021220', 'FACILITY NAME': 'EL POLLO LOCO', 'RECORD ID': 'PR0030551', 'PROGRAM NAME': 'EL POLLO LOCO', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1635, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS HIGH RISK', 'FACILITY ADDRESS': '1906 LINCOLN BLVD', 'FACILITY CITY': 'SANTA&#160;MONICA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90405', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 94.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000UBD4', 'EMPLOYEE ID': 'EE0000506', 'Location': 'POINT (-118.482688 34.01207)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 370.0, 'Board Approved Statistical Areas': 93.0, 'Zip Codes': 25714.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c508'), 'SERIAL NUMBER': 'DA000UBD4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c509'), 'SERIAL NUMBER': 'DA000UBD4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F037', 'VIOLATION DESCRIPTION': '# 37. Adequate ventilation and lighting; designated areas, use', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c50a'), 'SERIAL NUMBER': 'DA000UBD4', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': 4}]}
# {'_id': 'INS_DA000X7NB', 'ACTIVITY DATE': '05/23/2018', 'OWNER ID': 'OW0010119', 'OWNER NAME': 'DISSELHORST WILLIAM J.', 'FACILITY ID': 'FA0023163', 'FACILITY NAME': 'FIORE MARKET CAFE', 'RECORD ID': 'PR0043472', 'PROGRAM NAME': 'FIORE MARKET CAFE', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '1000 FREMONT AVE # #102', 'FACILITY CITY': 'SOUTH PASADENA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91030', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 97.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000X7NB', 'EMPLOYEE ID': 'EE0000162', 'Location': 'POINT (-118.153102 34.114467)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 1859.0, 'Board Approved Statistical Areas': 92.0, 'Zip Codes': 3220.0, 'SEATING DETAILS': '0-30', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c50b'), 'SERIAL NUMBER': 'DA000X7NB', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c50c'), 'SERIAL NUMBER': 'DA000X7NB', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F004', 'VIOLATION DESCRIPTION': '# 04. Proper eating, drinking, or tobacco use', 'POINTS': 2}]}
# {'_id': 'INS_DA000XZTY', 'ACTIVITY DATE': '11/15/2016', 'OWNER ID': 'OW0031677', 'OWNER NAME': 'SANHI, SWARNJIT SINGH', 'FACILITY ID': 'FA0003849', 'FACILITY NAME': '7-ELEVEN #18534-C', 'RECORD ID': 'PR0010528', 'PROGRAM NAME': '7-ELEVEN #18534-C', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1610, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) LOW RISK', 'FACILITY ADDRESS': '5763 HOLLYWOOD BLVD', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90028', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 90.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000XZTY', 'EMPLOYEE ID': 'EE0000697', 'Location': 'POINT (-118.31499 34.101695)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 1576.0, 'Board Approved Statistical Areas': 359.0, 'Zip Codes': 23446.0, 'SEATING DETAILS': '1-1,999 SF', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c50d'), 'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c50e'), 'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F039', 'VIOLATION DESCRIPTION': '# 39. Wiping cloths: properly used and stored', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c50f'), 'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F035', 'VIOLATION DESCRIPTION': '# 35. Equipment/Utensils - approved; installed; clean; good repair, capacity', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c510'), 'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c511'), 'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F023', 'VIOLATION DESCRIPTION': '# 23. No rodents, insects, birds, or animals', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c512'), 'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c513'), 'SERIAL NUMBER': 'DA000XZTY', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# {'_id': 'INS_DA000Z80N', 'ACTIVITY DATE': '04/05/2017', 'OWNER ID': 'OW0235713', 'OWNER NAME': 'HEALTHY ORGANIC POSITIVE EATING, INC', 'FACILITY ID': 'FA0239410', 'FACILITY NAME': 'H.O.P.E.', 'RECORD ID': 'PR0187385', 'PROGRAM NAME': 'H.O.P.E.', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1635, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS HIGH RISK', 'FACILITY ADDRESS': '11943 VENTURA BLVD', 'FACILITY CITY': 'STUDIO CITY', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91604', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 94.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA000Z80N', 'EMPLOYEE ID': 'EE0000797', 'Location': 'POINT (-118.39216 34.143309)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 1669.0, 'Board Approved Statistical Areas': 404.0, 'Zip Codes': 8492.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c514'), 'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c515'), 'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F027', 'VIOLATION DESCRIPTION': '# 27. Food separated and protected', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c516'), 'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F026', 'VIOLATION DESCRIPTION': '# 26. Approved thawing methods used, frozen food maintained frozen', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c517'), 'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F025', 'VIOLATION DESCRIPTION': '# 25. Personal cleanliness and hair restraints', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c518'), 'SERIAL NUMBER': 'DA000Z80N', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F009', 'VIOLATION DESCRIPTION': '# 09. Proper cooling methods', 'POINTS': 2}]}
# {'_id': 'INS_DA001KKC8', 'ACTIVITY DATE': '01/19/2017', 'OWNER ID': 'OW0003909', 'OWNER NAME': 'BAR LUBITSCH, INC.', 'FACILITY ID': 'FA0058005', 'FACILITY NAME': 'BAR LUBITSCH', 'RECORD ID': 'PR0004760', 'PROGRAM NAME': 'BAR LUBITSCH', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1633, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS LOW RISK', 'FACILITY ADDRESS': '7702 SANTA&#160;MONICA BLVD', 'FACILITY CITY': 'WEST HOLLYWOOD', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90046', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 98.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA001KKC8', 'EMPLOYEE ID': 'EE0000873', 'Location': 'POINT (-118.356769 34.090806)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 1342.0, 'Board Approved Statistical Areas': 106.0, 'Zip Codes': 23677.0, 'SEATING DETAILS': '31-60', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c519'), 'SERIAL NUMBER': 'DA001KKC8', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c51a'), 'SERIAL NUMBER': 'DA001KKC8', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F040', 'VIOLATION DESCRIPTION': '# 40. Plumbing: Plumbing in good repair, proper backflow devices', 'POINTS': 1}]}
# {'_id': 'INS_DA001U3SJ', 'ACTIVITY DATE': '03/05/2018', 'OWNER ID': 'OW0002029', 'OWNER NAME': 'ALBERTSONS, LLC', 'FACILITY ID': 'FA0057216', 'FACILITY NAME': "ALBERTSON'S #1322", 'RECORD ID': 'PR0047774', 'PROGRAM NAME': "ALBERTSON'S #1322 - MEAT DEPT", 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1612, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) HIGH RISK', 'FACILITY ADDRESS': '43543 20TH ST W', 'FACILITY CITY': 'LANCASTER', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '93536', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 91.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA001U3SJ', 'EMPLOYEE ID': 'EE0001085', 'Location': 'POINT (-118.165804 34.674272)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 172.0, 'Board Approved Statistical Areas': 18.0, 'Zip Codes': 26967.0, 'SEATING DETAILS': '1-1,999 SF', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c51b'), 'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F053', 'VIOLATION DESCRIPTION': '# 21a. Hot Water Available', 'POINTS': 2}, {'_id': ObjectId('5fdd212a3f3b639c0491c51c'), 'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c51d'), 'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F014', 'VIOLATION DESCRIPTION': '# 14. Food contact surfaces: clean and sanitized', 'POINTS': 4}, {'_id': ObjectId('5fdd212a3f3b639c0491c51e'), 'SERIAL NUMBER': 'DA001U3SJ', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F005', 'VIOLATION DESCRIPTION': '# 05. Hands clean and properly washed; gloves used properly', 'POINTS': 2}]}
# {'_id': 'INS_DA001VEBD', 'ACTIVITY DATE': '03/20/2018', 'OWNER ID': 'OW0124519', 'OWNER NAME': 'ATEF NAEEM', 'FACILITY ID': 'FA0159506', 'FACILITY NAME': 'A & M TOBACCO MARKET', 'RECORD ID': 'PR0147569', 'PROGRAM NAME': 'A & M TOBACCO MARKET', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1610, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) LOW RISK', 'FACILITY ADDRESS': '14114 S NORMANDIE AVE # 104', 'FACILITY CITY': 'GARDENA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90249', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 95.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA001VEBD', 'EMPLOYEE ID': 'EE0001129', 'Location': 'POINT (-118.300394 33.903245)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 743.0, 'Board Approved Statistical Areas': 304.0, 'Zip Codes': 24686.0, 'SEATING DETAILS': '1-1,999 SF', 'VIOLATIONS': [{'_id': ObjectId('5fdd212a3f3b639c0491c51f'), 'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F044', 'VIOLATION DESCRIPTION': '# 44. Floors, walls and ceilings: properly built, maintained in good repair and clean', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c520'), 'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F033', 'VIOLATION DESCRIPTION': '# 33. Nonfood-contact surfaces clean and in good repair', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c521'), 'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F030', 'VIOLATION DESCRIPTION': '# 30. Food properly stored; food storage containers identified', 'POINTS': 1}, {'_id': ObjectId('5fdd212a3f3b639c0491c522'), 'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F021', 'VIOLATION DESCRIPTION': '# 21b. Water available', 'POINTS': 0}, {'_id': ObjectId('5fdd212a3f3b639c0491c523'), 'SERIAL NUMBER': 'DA001VEBD', 'VIOLATION  STATUS': 'OUT OF COMPLIANCE', 'VIOLATION CODE': 'F006', 'VIOLATION DESCRIPTION': '# 06. Adequate handwashing facilities supplied & accessible', 'POINTS': 2}]}
# ...
# {'_id': 'INS_DA04U700X', 'ACTIVITY DATE': '03/12/2019', 'OWNER ID': 'OW0009504', 'OWNER NAME': 'DAVILA, PEDRO', 'FACILITY ID': 'FA0012295', 'FACILITY NAME': 'EL GRAN BURRITO RESTAURANT', 'RECORD ID': 'PR0040389', 'PROGRAM NAME': 'EL GRAN BURRITO RESTAURANT', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '4722 SANTA&#160;MONICA BLVD', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90029', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 95.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04U700X', 'EMPLOYEE ID': 'EE0000893', 'Location': 'POINT (-118.292568 34.090865)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 1431.0, 'Board Approved Statistical Areas': 344.0, 'Zip Codes': 23447.0, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04UN8ZM', 'ACTIVITY DATE': '10/16/2018', 'OWNER ID': 'OW0007253', 'OWNER NAME': 'CHAVEZ SAMUEL', 'FACILITY ID': 'FA0057772', 'FACILITY NAME': 'ASI ES MI TIERRA RESTAURANT', 'RECORD ID': 'PR0023909', 'PROGRAM NAME': 'ASI ES MI TIERRA RESTAURANT', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '17529 SIERRA HWY # 13', 'FACILITY CITY': 'CANYON COUNTRY', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91351', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 94.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04UN8ZM', 'EMPLOYEE ID': 'EE0000735', 'Location': 'POINT (-118.442395 34.431192)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 265.0, 'Board Approved Statistical Areas': 90.0, 'Zip Codes': 19334.0, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04UTASX', 'ACTIVITY DATE': '04/16/2018', 'OWNER ID': 'OW0020022', 'OWNER NAME': 'KSLL NEW WORLD/NEW AGE1 LLC', 'FACILITY ID': 'FA0023952', 'FACILITY NAME': 'THE LA HOTEL DOWNTOWN -  MAIN KITCHEN', 'RECORD ID': 'PR0026290', 'PROGRAM NAME': 'THE LA HOTEL DOWNTOWN -  MAIN KITCHEN', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1641, 'PE DESCRIPTION': 'RESTAURANT (151 + ) SEATS HIGH RISK', 'FACILITY ADDRESS': '333 S FIGUEROA ST # 104', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90071', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 91.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04UTASX', 'EMPLOYEE ID': 'EE0000721', 'Location': 'POINT (-118.254916 34.054664)', '2011 Supervisorial District Boundaries (Official)': 1.0, 'Census Tracts 2010': 540.0, 'Board Approved Statistical Areas': 343.0, 'Zip Codes': 24035.0, 'SEATING DETAILS': '151 + '}
# {'_id': 'INS_DA04UTQ4S', 'ACTIVITY DATE': '03/15/2018', 'OWNER ID': 'OW0006826', 'OWNER NAME': 'CH PARTNERS L.P.', 'FACILITY ID': 'FA0063713', 'FACILITY NAME': 'HOTEL OCEANA KITCHEN', 'RECORD ID': 'PR0011145', 'PROGRAM NAME': 'HOTEL OCEANA KITCHEN', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '849 OCEAN AVE', 'FACILITY CITY': 'SANTA&#160;MONICA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90403', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 96.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04UTQ4S', 'EMPLOYEE ID': 'EE0001013', 'Location': 'POINT (-118.506258 34.021137)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 382.0, 'Board Approved Statistical Areas': 93.0, 'Zip Codes': 25712.0, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04UYKXO', 'ACTIVITY DATE': '06/26/2018', 'OWNER ID': 'OW0251703', 'OWNER NAME': 'RASPADOS & AGUAS FRESCAS EL PICHON INC', 'FACILITY ID': 'FA0259777', 'FACILITY NAME': 'MICHOACANA PEDIR DE BOCA', 'RECORD ID': 'PR0210045', 'PROGRAM NAME': 'MICHOACANA PEDIR DE BOCA', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1631, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS MODERATE RISK', 'FACILITY ADDRESS': '6369 S ALAMEDA ST', 'FACILITY CITY': 'HUNTINGTON PARK', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90255', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 93.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04UYKXO', 'EMPLOYEE ID': 'EE0001027', 'Location': nan, '2011 Supervisorial District Boundaries (Official)': nan, 'Census Tracts 2010': nan, 'Board Approved Statistical Areas': nan, 'Zip Codes': nan, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04UZMSN', 'ACTIVITY DATE': '08/14/2017', 'OWNER ID': 'OW0028766', 'OWNER NAME': 'POIEMA ENTERPRISE, INC.', 'FACILITY ID': 'FA0033462', 'FACILITY NAME': 'LA MEXICANA MEAT MARKET', 'RECORD ID': 'PR0043730', 'PROGRAM NAME': 'LA MEXICANA MEAT MARKET', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1615, 'PE DESCRIPTION': 'FOOD MKT RETAIL (2,000+ SF) HIGH RISK', 'FACILITY ADDRESS': '14309 S ATLANTIC AVE STE 106', 'FACILITY CITY': 'COMPTON', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90221', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 77.0, 'GRADE': 'C', 'SERIAL NUMBER': 'DA04UZMSN', 'EMPLOYEE ID': 'EE0000872', 'Location': 'POINT (-118.193924 33.903118)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 1270.0, 'Board Approved Statistical Areas': 168.0, 'Zip Codes': 24350.0, 'SEATING DETAILS': '2,000+ SF'}
# {'_id': 'INS_DA04VYJKW', 'ACTIVITY DATE': '11/15/2017', 'OWNER ID': 'OW0017644', 'OWNER NAME': 'JIMENEZ ALMA ANGELICA', 'FACILITY ID': 'FA0013597', 'FACILITY NAME': 'CASA JIMENEZ MEXICAN SEAFOOD', 'RECORD ID': 'PR0018389', 'PROGRAM NAME': 'CASA JIMENEZ MEXICAN SEAFOOD', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1635, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS HIGH RISK', 'FACILITY ADDRESS': '1601 S MOUNTAIN AVE # #B', 'FACILITY CITY': 'MONROVIA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91016', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 95.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04VYJKW', 'EMPLOYEE ID': 'EE0000861', 'Location': 'POINT (-117.986351 34.134469)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 1863.0, 'Board Approved Statistical Areas': 73.0, 'Zip Codes': 2838.0, 'SEATING DETAILS': '31-60'}
# {'_id': 'INS_DA04W2SVV', 'ACTIVITY DATE': '12/07/2017', 'OWNER ID': 'OW0010251', 'OWNER NAME': 'DOMINGUEZ, MARTHA', 'FACILITY ID': 'FA0016970', 'FACILITY NAME': 'COSTA AZUL MIX', 'RECORD ID': 'PR0047939', 'PROGRAM NAME': 'COSTA AZUL MIX', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1635, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS HIGH RISK', 'FACILITY ADDRESS': '16441 VANOWEN ST', 'FACILITY CITY': 'VAN NUYS', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91406', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 93.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04W2SVV', 'EMPLOYEE ID': 'EE0000609', 'Location': 'POINT (-118.491675 34.193915)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 417.0, 'Board Approved Statistical Areas': 430.0, 'Zip Codes': 19734.0, 'SEATING DETAILS': '31-60'}
# {'_id': 'INS_DA04W9OPL', 'ACTIVITY DATE': '08/03/2017', 'OWNER ID': 'OW0236115', 'OWNER NAME': 'MAINLAND 2 LP', 'FACILITY ID': 'FA0239923', 'FACILITY NAME': 'MAINLAND POKE', 'RECORD ID': 'PR0187927', 'PROGRAM NAME': 'MAINLAND POKE', 'PROGRAM STATUS': 'INACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '252 S BRAND BLVD # C', 'FACILITY CITY': 'GLENDALE', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91204', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 96.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04W9OPL', 'EMPLOYEE ID': 'EE0000318', 'Location': 'POINT (-118.254933 34.143062)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 1539.0, 'Board Approved Statistical Areas': 305.0, 'Zip Codes': 3632.0, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04WG22P', 'ACTIVITY DATE': '06/01/2017', 'OWNER ID': 'OW0010868', 'OWNER NAME': 'EL POLLO LOCO, INC.', 'FACILITY ID': 'FA0021224', 'FACILITY NAME': 'EL POLLO LOCO #5972', 'RECORD ID': 'PR0028404', 'PROGRAM NAME': 'EL POLLO LOCO #5972', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1638, 'PE DESCRIPTION': 'RESTAURANT (61-150) SEATS HIGH RISK', 'FACILITY ADDRESS': '101 E MANCHESTER AVE', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90003', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 94.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04WG22P', 'EMPLOYEE ID': 'EE0001073', 'Location': 'POINT (-118.273426 33.960151)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 1019.0, 'Board Approved Statistical Areas': 358.0, 'Zip Codes': 22352.0, 'SEATING DETAILS': '61-150'}
# {'_id': 'INS_DA04WK5MZ', 'ACTIVITY DATE': '11/29/2016', 'OWNER ID': 'OW0018266', 'OWNER NAME': 'KAGAN DAVID', 'FACILITY ID': 'FA0025457', 'FACILITY NAME': 'GLATT WESTERN KOSHER', 'RECORD ID': 'PR0019671', 'PROGRAM NAME': 'GLATT WESTERN KOSHER', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1612, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) HIGH RISK', 'FACILITY ADDRESS': '444 N FAIRFAX AVE', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90036', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 98.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04WK5MZ', 'EMPLOYEE ID': 'EE0000726', 'Location': 'POINT (-118.361452 34.079334)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 1514.0, 'Board Approved Statistical Areas': 387.0, 'Zip Codes': 23679.0, 'SEATING DETAILS': '1-1,999 SF'}
# {'_id': 'INS_DA04WRH0O', 'ACTIVITY DATE': '07/05/2017', 'OWNER ID': 'OW0014101', 'OWNER NAME': 'GREENHILLS INC', 'FACILITY ID': 'FA0049257', 'FACILITY NAME': 'SUBWAY #22114', 'RECORD ID': 'PR0029978', 'PROGRAM NAME': 'SUBWAY #22114', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1631, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS MODERATE RISK', 'FACILITY ADDRESS': '711 N MAIN ST', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90012', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 96.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04WRH0O', 'EMPLOYEE ID': 'EE0001058', 'Location': 'POINT (-118.237383 34.058742)', '2011 Supervisorial District Boundaries (Official)': 1.0, 'Census Tracts 2010': 685.0, 'Board Approved Statistical Areas': 339.0, 'Zip Codes': 22728.0, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04WS0EZ', 'ACTIVITY DATE': '01/30/2019', 'OWNER ID': 'OW0124709', 'OWNER NAME': 'TOROS SUSHI, INC', 'FACILITY ID': 'FA0159704', 'FACILITY NAME': 'TOROS RESTAURANT', 'RECORD ID': 'PR0147765', 'PROGRAM NAME': 'TOROS RESTAURANT', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1635, 'PE DESCRIPTION': 'RESTAURANT (31-60) SEATS HIGH RISK', 'FACILITY ADDRESS': '500 W MAIN ST', 'FACILITY CITY': 'ALHAMBRA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91801', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 90.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04WS0EZ', 'EMPLOYEE ID': 'EE0000687', 'Location': 'POINT (-118.132713 34.0924)', '2011 Supervisorial District Boundaries (Official)': 5.0, 'Census Tracts 2010': 1691.0, 'Board Approved Statistical Areas': 2.0, 'Zip Codes': 10151.0, 'SEATING DETAILS': '31-60'}
# {'_id': 'INS_DA04WSQXS', 'ACTIVITY DATE': '01/26/2017', 'OWNER ID': 'OW0227639', 'OWNER NAME': 'TRAN HOLDINGS LLC', 'FACILITY ID': 'FA0222856', 'FACILITY NAME': 'SAIGON EDEN VIETNAMESE RESTAURANT', 'RECORD ID': 'PR0177897', 'PROGRAM NAME': 'SAIGON EDEN VIETNAMESE RESTAURANT', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1638, 'PE DESCRIPTION': 'RESTAURANT (61-150) SEATS HIGH RISK', 'FACILITY ADDRESS': '29 S GARFIELD AVE', 'FACILITY CITY': 'ALHAMBRA', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '91801', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 92.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04WSQXS', 'EMPLOYEE ID': 'EE0000687', 'Location': nan, '2011 Supervisorial District Boundaries (Official)': nan, 'Census Tracts 2010': nan, 'Board Approved Statistical Areas': nan, 'Zip Codes': nan, 'SEATING DETAILS': '61-150'}
# {'_id': 'INS_DA04WX8WQ', 'ACTIVITY DATE': '12/08/2017', 'OWNER ID': 'OW0029458', 'OWNER NAME': 'RALPHS GROCERY COMPANY', 'FACILITY ID': 'FA0069221', 'FACILITY NAME': 'RALPHS MARKET #280', 'RECORD ID': 'PR0009185', 'PROGRAM NAME': "RALPH'S BAKERY #280", 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1631, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS MODERATE RISK', 'FACILITY ADDRESS': '4311 LINCOLN BLVD', 'FACILITY CITY': 'MARINA DEL REY', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90292', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 99.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04WX8WQ', 'EMPLOYEE ID': 'EE0001014', 'Location': nan, '2011 Supervisorial District Boundaries (Official)': nan, 'Census Tracts 2010': nan, 'Board Approved Statistical Areas': nan, 'Zip Codes': nan, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04WZOVC', 'ACTIVITY DATE': '10/19/2017', 'OWNER ID': 'OW0101133', 'OWNER NAME': 'B B BARGAIN INC', 'FACILITY ID': 'FA0137837', 'FACILITY NAME': 'B B BARGAIN', 'RECORD ID': 'PR0122008', 'PROGRAM NAME': 'B B BARGIN', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1610, 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) LOW RISK', 'FACILITY ADDRESS': '1778 W ADAMS BLVD', 'FACILITY CITY': 'LOS ANGELES', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90018', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 98.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04WZOVC', 'EMPLOYEE ID': 'EE0001094', 'Location': 'POINT (-118.302581 34.03271)', '2011 Supervisorial District Boundaries (Official)': 2.0, 'Census Tracts 2010': 729.0, 'Board Approved Statistical Areas': 298.0, 'Zip Codes': 23079.0, 'SEATING DETAILS': '1-1,999 SF'}
# {'_id': 'INS_DA04XAACX', 'ACTIVITY DATE': '08/29/2018', 'OWNER ID': 'OW0244787', 'OWNER NAME': 'THAI FOOD PICK UP, LLC', 'FACILITY ID': 'FA0250724', 'FACILITY NAME': 'THAI FOOD PICK UP', 'RECORD ID': 'PR0199755', 'PROGRAM NAME': 'THAI FOOD PICK UP', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1632, 'PE DESCRIPTION': 'RESTAURANT (0-30) SEATS HIGH RISK', 'FACILITY ADDRESS': '10807 BEVERLY BLVD STE C', 'FACILITY CITY': 'WHITTIER', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90601', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 91.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04XAACX', 'EMPLOYEE ID': 'EE0000182', 'Location': 'POINT (-118.055092 33.99845)', '2011 Supervisorial District Boundaries (Official)': 4.0, 'Census Tracts 2010': 1954.0, 'Board Approved Statistical Areas': 108.0, 'Zip Codes': 25721.0, 'SEATING DETAILS': '0-30'}
# {'_id': 'INS_DA04XR18C', 'ACTIVITY DATE': '10/03/2018', 'OWNER ID': 'OW0028696', 'OWNER NAME': 'PLATA ENTERTAINMENT, LLC', 'FACILITY ID': 'FA0018158', 'FACILITY NAME': 'THE BACK ROOM', 'RECORD ID': 'PR0027696', 'PROGRAM NAME': 'THE BACK ROOM', 'PROGRAM STATUS': 'ACTIVE', 'PROGRAM ELEMENT (PE)': 1636, 'PE DESCRIPTION': 'RESTAURANT (61-150) SEATS LOW RISK', 'FACILITY ADDRESS': '8788 W SUNSET BLVD', 'FACILITY CITY': 'WEST HOLLYWOOD', 'FACILITY STATE': 'CA', 'FACILITY ZIP': '90069', 'SERVICE CODE': 1, 'SERVICE DESCRIPTION': 'ROUTINE INSPECTION', 'SCORE': 98.0, 'GRADE': 'A', 'SERIAL NUMBER': 'DA04XR18C', 'EMPLOYEE ID': 'EE0000838', 'Location': 'POINT (-118.383048 34.090856)', '2011 Supervisorial District Boundaries (Official)': 3.0, 'Census Tracts 2010': 1340.0, 'Board Approved Statistical Areas': 106.0, 'Zip Codes': 24034.0, 'SEATING DETAILS': '61-150'}

# %%
ui = UserInterface('summative')
ui.createCorrelationsPlot()

# %%
window = Tk()
window.title('test')
window.geometry("1200x800")
window.columnconfigure(0, weight=1)
window.rowconfigure(0, weight=1)

mainframe = ttk.Notebook(window) #tree = ttk.Treeview(mainframe)
f1 = ttk.Frame(mainframe)  
f2 = ttk.Frame(mainframe)  
f3 = ttk.Frame(mainframe) 
mainframe.add(f1, text='Averages')
mainframe.add(f2, text='Violations per Establishment')
mainframe.add(f3, text='Correlations')
mainframe.grid(column=0, row=0, sticky=(N, W, E, S))

frame=Frame(f1)
frame.pack(expand=True, fill=BOTH)
canvas=Canvas(frame,bg='#FFFFFF',width=300,height=300,scrollregion=(0,0,500,1300))
canvas.pack()

for i in range(50):
    Label(frame,text="my text"+str(i)).pack()

# frameScrollY = Scrollbar(frame, orient='vertical', command=canvas.yview)
# canvas.configure(yscrollcommand=frameScrollY.set)
# frameScrollY.pack(side="right",fill="y")



# frame=Frame(root,width=300,height=300)
# frame.pack(expand=True, fill=BOTH) #.grid(row=0,column=0)
# canvas=Canvas(frame,bg='#FFFFFF',width=300,height=300,scrollregion=(0,0,500,500))

vbar=Scrollbar(frame,orient=VERTICAL)
vbar.pack(side=RIGHT,fill=Y)
vbar.config(command=canvas.yview)
canvas.config(width=300,height=300)
canvas.config(yscrollcommand=vbar.set)
canvas.pack(side=LEFT,expand=True,fill=BOTH)



window.mainloop()

# %%
# root=Tk()
# frame=Frame(window,width=300,height=300)
# frame.pack(expand=True, fill=BOTH) #.grid(row=0,column=0)
# canvas=Canvas(frame,bg='#FFFFFF',width=300,height=300,scrollregion=(0,0,500,500))

window = Tk()
window.title('test')
window.geometry("1200x800")
window.columnconfigure(0, weight=1)
window.rowconfigure(0, weight=1)

mainframe = ttk.Notebook(window) #tree = ttk.Treeview(mainframe)
f1 = ttk.Frame(mainframe)  
f2 = ttk.Frame(mainframe)  
f3 = ttk.Frame(mainframe) 
mainframe.add(f1, text='Averages')
mainframe.add(f2, text='Violations per Establishment')
mainframe.add(f3, text='Correlations')
mainframe.grid(column=0, row=0, sticky=(N, W, E, S))

frame=Frame(f1,width=300,height=500)
frame.pack(expand=True, fill=BOTH) #.grid(row=0,column=0)
canvas=Canvas(frame,bg='#FFFFFF',width=300,height=500, scrollregion=(0,0,1000,1000))
# canvas.configure(scrollregion=canvas.bbox("all"))

vbar=Scrollbar(frame,orient=VERTICAL)
vbar.pack(side=RIGHT,fill=Y)
vbar.config(command=canvas.yview)
canvas.config(width=300,height=500)
canvas.config(yscrollcommand=vbar.set)
canvas.pack(side=LEFT,expand=True,fill=BOTH)

root.mainloop()

# %%
import pprint
import tkinter.constants as Tkconstants
import math

frame = None
canvas = None

def printBboxes(label=""):
    global canvas, mplCanvas, interior, interior_id, cwid
    print("  "+label,
    "canvas.bbox:", canvas.bbox(Tkconstants.ALL),
    "mplCanvas.bbox:", mplCanvas.bbox(Tkconstants.ALL))

def addScrollingFigure(figure, frame):
    global canvas, mplCanvas, interior, interior_id, cwid
    # set up a canvas with scrollbars
    canvas = Canvas(frame)
    canvas.grid(row=1, column=1, sticky=Tkconstants.NSEW)

    xScrollbar = Scrollbar(frame, orient=Tkconstants.HORIZONTAL)
    yScrollbar = Scrollbar(frame)

    xScrollbar.grid(row=2, column=1, sticky=Tkconstants.EW)
    yScrollbar.grid(row=1, column=2, sticky=Tkconstants.NS)
    
    canvas.config(xscrollcommand=xScrollbar.set)
    xScrollbar.config(command=canvas.xview)
    canvas.config(yscrollcommand=yScrollbar.set)
    yScrollbar.config(command=canvas.yview)

    # plug in the figure
    figAgg = FigureCanvasTkAgg(figure, canvas)
    mplCanvas = figAgg.get_tk_widget()
    #mplCanvas.grid(sticky=Tkconstants.NSEW)

    # and connect figure with scrolling region
    cwid = canvas.create_window(0, 0, window=mplCanvas, anchor=Tkconstants.NW)
    printBboxes("Init")
    canvas.config(scrollregion=canvas.bbox(Tkconstants.ALL),width=200,height=200)

# def changeSize(figure, factor):
#     global canvas, mplCanvas, interior, interior_id, frame, cwid
#     oldSize = figure.get_size_inches()
#     print("old size is", oldSize)
#     figure.set_size_inches([factor * s for s in oldSize])
#     wi,hi = [i*figure.dpi for i in figure.get_size_inches()]
#     print("new size is", figure.get_size_inches())
#     print("new size pixels: ", wi,hi)
#     mplCanvas.config(width=wi, height=hi) ; printBboxes("A")
#     #mplCanvas.grid(sticky=Tkconstants.NSEW)
#     canvas.itemconfigure(cwid, width=wi, height=hi) ; printBboxes("B")
#     canvas.config(scrollregion=canvas.bbox(Tkconstants.ALL),width=200,height=200)
#     figure.canvas.draw() ; printBboxes("C")
#     print()

# if __name__ == "__main__":
root = Tk()
root.rowconfigure(1, weight=1)
root.columnconfigure(1, weight=1)

frame = Frame(root)
frame.grid(column=1, row=1, sticky=Tkconstants.NSEW)
frame.rowconfigure(1, weight=1)
frame.columnconfigure(1, weight=1)

figure = plt.figure(dpi=150, figsize=(4, 4))
plt.plot(range(10), [math.sin(x) for x in range(10)])

addScrollingFigure(figure, frame)

buttonFrame = Frame(root)
buttonFrame.grid(row=1, column=2, sticky=Tkconstants.NS)
biggerButton = Button(buttonFrame, text="larger",
                    command=lambda : changeSize(figure, 1.5))
biggerButton.grid(column=1, row=1)
smallerButton = Button(buttonFrame, text="smaller",
                     command=lambda : changeSize(figure, .5))
smallerButton.grid(column=1, row=2)

root.mainloop()
# Out:
#   Init canvas.bbox: (0, 0, 600, 600) mplCanvas.bbox: (0, 0, 600, 600)
