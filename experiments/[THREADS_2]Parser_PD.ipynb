# %%
from tkinter import *
from tkinter import ttk, filedialog
from tkinter.filedialog import askopenfilename
import csv
from pathlib import Path
import pymongo
import numpy as np
# Use sentinel for missing values
from numpy import nan as NA
import pandas as pd
# For showing plots in tkinter
import matplotlib.pyplot as plt
from matplotlib.figure import Figure 
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,  
NavigationToolbar2Tk) 
import seaborn as sns
import tkinter.constants as Tkconstants
import threading
import _thread
lock = _thread.allocate_lock()
lock = threading.Lock()

# connect to mongodb
client = pymongo.MongoClient("mongodb://localhost:27017")
# create db
db_formative = client["summative"]
# create collection
# collection_vendors = db_formative["test-323"]
collection_vendors = db_formative["test-201"]

# %%
class Parser(object):
    def __init__(self, csvFile):
        self.csvFile = csvFile
        
    def parseData(self):
        # Read CSV files and convert to Pandas DataFrames
        inspectionsDF = pd.read_csv(self.csvFile['inspections'], usecols=['ACTIVITY DATE', 'FACILITY ID', 'FACILITY NAME', 'PROGRAM STATUS', 'PE DESCRIPTION', 'FACILITY ZIP', 'SERIAL NUMBER', 'SCORE'])
        inventoryDF = pd.read_csv(self.csvFile['inventory'])
        violationsDF = pd.read_csv(self.csvFile['violations'], usecols=['SERIAL NUMBER', 'VIOLATION CODE'])
        
        return inspectionsDF, inventoryDF, violationsDF

# %%
class DataCleaner(object):
    def __init__(self, inspections, inventory, violations):
        self.inspectionsDF = inspections
        self.inventoryDF = inventory
        self.violationsDF = violations
        
    def clean(self):
        print('cleaning')
        self.cleanInspections()
        return self.inspectionsDF, self.inventoryDF, self.violationsDF
        
    def cleanInspections(self):
        # Extract info from PE DESC column and create new col for SEATING DETAILS
        self.inspectionsDF['SEATING DETAILS'] = self.inspectionsDF['PE DESCRIPTION'].str.extract(r"\(([\S ]+)\)")
        print(f'seating deats \n{self.inspectionsDF["SEATING DETAILS"]}')
        print(f'pe desc \n{self.inspectionsDF["PE DESCRIPTION"]}')
        # Extract first part of Zip Code (e.g. '90001-1234', becomes '90001')
        self.inspectionsDF['FACILITY ZIP'] = self.inspectionsDF['FACILITY ZIP'].str.extract(r"([0-9]+)") 
        # Add '_id' for MongoDB      
        self.inspectionsDF['_id'] = 'INS_' + self.inspectionsDF['SERIAL NUMBER']

# %%
class DataLoader(object):
    def __init__(self, inspections, inventory, violations):
        self.inspectionsDF = inspections
        self.inventoryDF = inventory
        self.violationsDF = violations
        
    def loadToMongo(self):
        # use to_dict to format correctly for MongoDB
        inspectionsDict = self.inspectionsDF.to_dict(orient='records')
        inventoryDict = self.inventoryDF.to_dict(orient='records')
        violationsDict = self.violationsDF.to_dict(orient='records')
        # Insert into Mongo
        collection_vendors.insert_many(inspectionsDict)
        collection_vendors.insert_many(violationsDict)
        # Test db
        test = collection_vendors.find({'_id':{'$regex':'INS_'}})
        for t in test:
            print(f'testing inspections: \n{t}')
            break
        print('inserted into Mongo')

# %%
class ButtonUpload(object):
    def __init__(self, fileButtons, fileLabels, counter, mainframe, fileRoutes):
        self.fileButtons = fileButtons
        self.fileLabels = fileLabels
        self.counter = counter
        self.mainframe = mainframe
        self.fileRoutes = fileRoutes
        self.filePath = ''
        self.uploadLabel = StringVar()

    def browseFile(self):
        self.filePath = askopenfilename(filetypes=[("CSV files", ".csv")])
        fileName = Path(self.filePath)
        self.uploadLabel.set(fileName.name)
        print(self.filePath)
        self.setFileRoutes()
    
    def setFileRoutes(self):
        self.fileRoutes[self.fileButtons] = self.filePath
        print(self.fileRoutes)
        
    def createButton(self):
        ttk.Label(self.mainframe, text=f"Upload data: {self.fileButtons}", anchor="w").grid(row=self.counter+1, column=0, sticky="w")
        Button(self.mainframe, text="Upload file", command=self.browseFile).grid(row=self.counter+1, column=1, sticky="w")
        ttk.Label(self.mainframe, textvariable=self.uploadLabel).grid(row=self.counter+1, column=2, sticky="w")

# %%
class AveragesCalculator(object):
    def __init__(self, year, category):
        self.year = year
        self.category = category
        
    def zipScores(self):
        print(f'Calculating stats for: \n- Year = {self.year} \n- Category = {self.category}')
        # Find inspection documents - look in ispections (INS_) with year
        resultsInspections = collection_vendors.find({'_id':{'$regex':'INS_'},'ACTIVITY DATE':{'$regex':self.year}, 'PROGRAM STATUS': 'ACTIVE'})

        # Create dict of facility zips with lists of their scores
        zipScoresDict = {}  
        for r in resultsInspections:
            key = r[self.category]
            if key in zipScoresDict:
                zipScoresDict[r[self.category]].append(r['SCORE'])
            else:
                zipScoresDict[key] = [r['SCORE']]
        return self.calcZipStats(zipScoresDict)


    def calcZipStats(self, zipScoresDict):
        zipScoresMean = {}
        zipScoresMean = {self.category:[],'mean':[],'median':[],'mode':[]}
        for x in zipScoresDict:
            # Create Series to calc mean, mode, median
            tempSeries = pd.Series(zipScoresDict[x])
            mean = tempSeries.mean()
            mode = tempSeries.mode().tolist()
            median = tempSeries.median()

            # mean, mode, median as columns
            zipScoresMean[self.category].append(x)
            zipScoresMean['mean'].append(mean)
            zipScoresMean['median'].append(median)
            zipScoresMean['mode'].append(mode)

        # Create DataFrame
        zipScoresDF = pd.DataFrame(zipScoresMean)
        # sort by ascending cat - easier to find for user (esp. zip)
        zipScoresDF.sort_values(by=[self.category],inplace=True)
        # set cat as index
        zipScores_noIndex = zipScoresDF.set_index(self.category)
        
        return zipScores_noIndex

# %%
class ViolationsPlot(object):
    def __init__(self, tab):
        self.tab = tab
        self.uniqueVCodesDF = None
        
    def processData(self, name):
        print(name)
        
        violationsAgg = collection_vendors.aggregate([
            {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'}, 'FACILITY ID': {'$addToSet': '$FACILITY ID'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
        ])
        # Find out what violations were committed by each facility
        # Use a set() to get unique entries 
        # (violations may be committed multiple times by same facility but I only want to count that facility once)
        facilityViolations = {}
#         with lock:
#             print(f'Locked: {name}')
        for item in violationsAgg:
            try:
                if item['PROGRAM STATUS'][0] == 'INACTIVE':
                    continue
            except:
                print(f'No program status: {item}')
            try:
                if item['FACILITY ID'][0] in facilityViolations:
                    facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
                else:
                    facilityViolations[item['FACILITY ID'][0]] = set()
                    facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
            # Possible error - some violations have serial numbers that are not recorded in Inspections data.
            # These are not used in plots because they do not correspond to a facility.
            except Exception as e:
                print(f'Error: "{e}". Cannot add this item to dictionary: {item["_id"]}')
#             print(f'Locked: {name}')

        print(name)
        uniqueVCodes = {}
        for facility in facilityViolations:
            for vCode in facilityViolations[facility]:
                if vCode in uniqueVCodes:
                    uniqueVCodes[vCode] = uniqueVCodes[vCode] + 1
                else:
                    uniqueVCodes[vCode] = 1 
                    
        # Convert data to DataFrame and sort the data descending by value
        data = {'keys':list(uniqueVCodes.keys()), 'values':list(uniqueVCodes.values())}
        uniqueVCodesDF = pd.DataFrame(data)
        uniqueVCodesDF.sort_values(by='values',ascending=False,inplace=True)
        self.uniqueVCodesDF = uniqueVCodesDF
        print(name)
 
    
    def createPlot(self, name):
        print(f'starting plot func {name}')
        # Display violations vs no. of establishments
        vioKeys = self.uniqueVCodesDF['keys']
        vioVals = self.uniqueVCodesDF['values']
        # Create 4 subplots using slices of the keys & values lists
        fig,a =  plt.subplots(2,2)
        print(f'assigning axis {name}')
        a[0][0].bar(vioKeys[:round(len(vioKeys)*0.25)], vioVals[:round(len(vioKeys)*0.25)])
        a[0][1].bar(vioKeys[round(len(vioKeys)*0.25):round(len(vioKeys)*0.5)], vioVals[round(len(vioKeys)*0.25):round(len(vioKeys)*0.5)])
        a[1][0].bar(vioKeys[round(len(vioKeys)*0.5):round(len(vioKeys)*0.75)], vioVals[round(len(vioKeys)*0.5):round(len(vioKeys)*0.75)])
        a[1][1].bar(vioKeys[round(len(vioKeys)*0.75):], vioVals[round(len(vioKeys)*0.75):])
        # Tidy plot - rotate labels & apply layout
        a[0][0].tick_params(axis='x',labelrotation=45)
        a[0][1].tick_params(axis='x',labelrotation=45)
        a[1][0].tick_params(axis='x',labelrotation=45)
        a[1][1].tick_params(axis='x',labelrotation=45)
        plt.tight_layout()
        # Show in console as well as window
        plt.show()
        print(f'plt.show done {name}')
        # creating the Tkinter canvas containing the Matplotlib figure 
        canvas = FigureCanvasTkAgg(fig, master = self.tab)   
        canvas.draw() 
        # grid the canvas on the Tkinter window 
        canvas.get_tk_widget().place(relheight=1, relwidth=1) 
        print(f'plot done {name}')

# %%
class CorrelationsPlot(object):
    def __init__(self, title):
        self.title = title
        self.insViosDF = None
        
    def processData(self, name):
        print(name)
        # find the violations with fac name and zip
        violationsZipAgg = collection_vendors.aggregate([
            {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'},'ZIP': {'$addToSet':'$FACILITY ZIP'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
        ])
        # Create dict with {zip code: [violations no. per facility]}
        vioDict = {}
        for item in violationsZipAgg:
            try:
                if item['PROGRAM STATUS'][0] == 'INACTIVE':
                    continue
            except:
                print(f'No program status: {item}')
            try:
                zipCode = item['ZIP'][0] + ' -'
                if zipCode in vioDict:
                    vioDict[zipCode].append(len(item['VIOLATIONS']))
                else:
                    vioDict[zipCode] = [len(item['VIOLATIONS'])]
            # Possible error - some violations have serial numbers that are not recorded in Inspections data.
            # These are not used in plots because they do not correspond to a facility.
            except Exception as e:
                print(f'Error: "{e}". Cannot add this item to dictionary: {item["_id"]}')
#             print(f'locked: {name}')

        # Calc mean for violation no.
        for v in vioDict:
            tempSeries = pd.Series(vioDict[v])
            mean = tempSeries.mean()
            vioDict[v] = mean
        print(name)
        #  Create DataFrame - sorted by zip to make visualisations easier to understand
        data = {
            'quantity': list(vioDict.values()),
            'zip': list(vioDict.keys())
        }
        insViosDF = pd.DataFrame(data)
        insViosDF.sort_values(by=['quantity'],ascending=False,inplace=True)
        self.insViosDF = insViosDF
        print(name)

    
    def createPlot(self, name):
        # New window
        window = Tk()
        window.title(self.title)
        window.geometry("1200x800")
        window.columnconfigure(0, weight=1)
        window.rowconfigure(0, weight=1)
        print(f'window created {name}')
        # Scroll Y
        frame=Frame(window)
        frame.grid(row=0,column=0)
        frame.columnconfigure(0, weight=1)
        frame.rowconfigure(0, weight=1)
        canvas = Canvas(frame)
        canvas.grid(row=0, column=0)
        yScrollbar = Scrollbar(frame)
        yScrollbar.grid(row=0, column=1, sticky=Tkconstants.NS)
        canvas.config(yscrollcommand=yScrollbar.set)
        yScrollbar.config(command=canvas.yview)
        # Creating the figure and Seaborn plot
        figure = Figure(figsize=(8, 40))
        ax = figure.subplots()
        sns.barplot(x="quantity", y="zip", data=self.insViosDF, label="Total", color="b", ax=ax, ci=None)
        print(f'sns bar plot created {name}')
        # create the Tkinter canvas 
        canvasInner = FigureCanvasTkAgg(figure, master = canvas)   
        canvasInner.draw() 

        # place the canvas on the Tkinter window 
        mplCanvas = canvasInner.get_tk_widget()
        
        cwid = canvas.create_window(0, 0, window=mplCanvas, anchor=Tkconstants.NW)
        canvas.config(scrollregion=canvas.bbox(Tkconstants.ALL),width=800,height=800)
        print(f'plot done {name}')

# %%
class UserInterface(object):
    def __init__(self, title):
        self.title = title
        self.mainframe = None
        self.window = Tk()
        self.window.title(self.title)
        self.window.geometry("1200x800")
        self.window.columnconfigure(0, weight=1)
        self.window.rowconfigure(0, weight=1)
        self.calcCategory = StringVar()
        self.calcYear = StringVar()
        self.cleanedData = None
        self.fileButtons = ["inspections", "inventory", "violations"]
        self.fileRoutes = {self.fileButtons[0]:"", self.fileButtons[1]:"", self.fileButtons[2]:""}
        
    def createWindow(self):
        self.createInitialFrame()
        self.window.mainloop()
        
    def createInitialFrame(self):
         # variables
        labelTextOne = StringVar()
        labelTextTwo = StringVar()
        labelTextThree = StringVar()
        fileLabels = [labelTextOne, labelTextTwo, labelTextThree]
        # Config layout
        self.mainframe = ttk.Frame(self.window, padding="16 16 16 16")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        self.mainframe.grid_rowconfigure(4, weight=1)
        self.mainframe.grid_columnconfigure(2, weight=1)
        heading = ttk.Label(self.mainframe, text="Load your dataset", anchor="w").grid(row=0, sticky="nw")
        # Create buttons for file uploads
        for i in range(0, len(self.fileButtons)): 
            newButton = ButtonUpload(self.fileButtons[i], fileLabels[i], i, self.mainframe, self.fileRoutes)
            newButton.createButton()
        # Buttons for Cancel and Clean & Save
        footer = ttk.Frame(self.window, padding="16 0 0 0").grid(row=5, column=1)
        cancelButton = Button(self.mainframe, text="Cancel & exit", bg="red").grid(row=4, column=0, sticky="sw")
        saveButton = Button(self.mainframe, text="Load & clean dataset", command=self.handleSave).grid(row=4, column=2,sticky="se")
        
    def handleSave(self):
        # parse data
        parser = Parser(self.fileRoutes)
        try:
            parsedData = parser.parseData()
        # Catch errors - data with incorrect columns with throw error
        except ValueError:
            print('Value error - incorrect data entered.')
            messagebox.showerror("Error", f"Value Error, please make sure you are uploading the correct data. \n{sys.exc_info()[0]}")
            return
        except:
            print("Unexpected Error", sys.exc_info()[0])
            messagebox.showerror("Error", f"Unexpected Error, please try again. \n{sys.exc_info()[0]}")
            return
        # Clean data - pass data returned from parser
        cleaner = DataCleaner(*parsedData)
        self.cleanedData = cleaner.clean()
        print('done handleSave')
        self.uploadFrame()
        
    def uploadFrame(self):
        self.mainframe.destroy()
        self.mainframe = ttk.Frame(self.window, padding="16 16 16 16")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        heading = ttk.Label(self.mainframe, text="The data has been prepared and cleaned.", anchor="w").grid(row=0, sticky="nw")
        subheading = ttk.Label(self.mainframe, text="Please press continue to load data to MongoDB and proceed.", anchor="w").grid(row=1, sticky="nw")
        saveButton = Button(self.mainframe, text="Continue", command=self.handleLoadToDB).grid(row=2 ,sticky="nw")
        print('done uploadFrame')
        
    def handleLoadToDB(self):
        # Insert to MongoDB - pass data returned from cleaner
        loader = DataLoader(*self.cleanedData)
        loader.loadToMongo()
        try:
#             loader.loadToMongo()
            print('done handleLoadToDB')
        # Catch errors - if collection already has this data, it will throw a duplicate key error
        except:
            print("Unexpected Error", sys.exc_info()[0])
            self.createInitialFrame()
            messagebox.showerror("Error", f"Unexpected Error, please try again \n{sys.exc_info()[0]}")
            return
        self.createNotebook()
        
    def createNotebook(self):
        print('Creating Notebook (Tabs)')
        self.mainframe.destroy()
        self.mainframe = ttk.Notebook(self.window)
        f1 = ttk.Frame(self.mainframe)  
        f2 = ttk.Frame(self.mainframe)  
        f3 = ttk.Frame(self.mainframe) 
        self.mainframe.add(f1, text='Averages')
        self.mainframe.add(f2, text='Violations per Establishment')
        self.mainframe.add(f3, text='Correlations')
        # ====== Widget for tab 1
        heading_one = ttk.Label(f1, text="Mean, Mode and Median", anchor="w").grid(row=0, sticky="nw")
        # Radio - Type
        radioHeadingOne = ttk.Label(f1, text="Calculate by seating type or zip codes:", anchor="w").grid(row=0, sticky="nw")
        Radiobutton(f1, text="Vendor seating type", padx = 20, variable=self.calcCategory, value='SEATING DETAILS').grid(row=1, column=0, sticky='w')
        Radiobutton(f1, text="Zip Code", padx = 20, variable=self.calcCategory, value='FACILITY ZIP').grid(row=2, column=0, sticky='w')
        # Radio - Years
        radioHeadingTwo = ttk.Label(f1, text="Select Year", anchor="w").grid(row=3, sticky="nw")
        yearsArr = ['2016', '2017', '2018', '2019']
        for i in range(len(yearsArr)):
            Radiobutton(f1, text=yearsArr[i], padx = 20, variable=self.calcYear, value=yearsArr[i]).grid(row=i+4, column=0, sticky='w')
        # Calc button
        calcButton = Button(f1, text="Calculate", command=self.calcAverages).grid(row=8, column=0, sticky="sw")
        self.mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
        
        # ====== Widget for tab 2
        heading_two = ttk.Label(f2, text="Number of establishments that have committed each type of violation.", anchor="w").grid(row=0, sticky="nw")
        vPlot = ViolationsPlot(f2)
        
        # ====== Widget for tab 3
        heading_two = ttk.Label(f3, text="Correlation between the number of violations commited per vendor and their zip code", anchor="w").grid(row=0, sticky="nw")
        title = "Violations commited per vendor and their zip code"
        cPlot = CorrelationsPlot(title)
        
        # THREADS
        t1 = threading.Thread(target=self.runThreads, args=('THREAD ONE',vPlot))
        t2 = threading.Thread(target=self.runThreads, args=('THREAD TWO',cPlot))
        t1.start()
        t2.start()

        t1.join()
        t2.join()  
        
        vPlot.createPlot('ONE')
        cPlot.createPlot('TWO')
 

    def runThreads(self, name, data):
        print('-----------> starting threading')
        data.processData(name)
        print(f'-----------> {name} stopped threading')
    
    def createViolationsPlot(self, f2):
        vPlot = ViolationsPlot(f2)
        vPlot.processData()
        
    def createCorrelationsPlot(self):    
        title = "Violations commited per vendor and their zip code"
        cPlot = CorrelationsPlot(title)
        cPlot.processData()
    
    def calcAverages(self):
        calcCatVal = self.calcCategory.get()
        calcYearVal = self.calcYear.get()
        calcAv = AveragesCalculator(calcYearVal, calcCatVal)
        avResults = calcAv.zipScores()
        self.averagesResultsFrame(avResults, calcYearVal, calcCatVal)
        
    def averagesResultsFrame(self, resultsAv, calcYearVal, calcCatVal):
        avResultsWindow = Tk()
        avResultsWindow.title(f'Averages Results for {calcCatVal} in {calcYearVal}')
        avResultsWindow.geometry("600x400")
        mainframe = ttk.Frame(avResultsWindow, padding="16 16 16 16")
        mainframe.place(relheight=1, relwidth=1)

        tree = ttk.Treeview(mainframe)
        tree.place(relheight=1, relwidth=1)
        treescrolly = Scrollbar(mainframe, orient='vertical', command=tree.yview)
        treescrollx = Scrollbar(mainframe, orient='horizontal', command=tree.xview)
        tree.configure(xscrollcommand=treescrollx.set, yscrollcommand=treescrolly.set)
        treescrolly.pack(side='right', fill='y')
        treescrollx.pack(side='bottom', fill='x')

        tree["columns"]=("one","two","three")
        tree.column("#0", width=75, minwidth=75)
        tree.column("one", width=75, minwidth=75)
        tree.column("two", width=75, minwidth=75)
        tree.column("three", width=75, minwidth=75)

        tree.heading("#0",text="Category")
        tree.heading("one", text="Mean")
        tree.heading("two", text="Median")
        tree.heading("three", text="Mode")

        for index, row in resultsAv.iterrows(): 
            tree.insert('','end', text=index, values=[row['mean'],row['median'],row['mode']])
        print(f'This is resultsAv: \n{resultsAv}')

# %%
ui = UserInterface('summative')
ui.createWindow()
# Out:
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections.csv', 'inventory': '', 'violations': ''}
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections.csv', 'inventory': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv', 'violations': ''}
# /Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/violations.csv
# {'inspections': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inspections.csv', 'inventory': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/Inventory_sm.csv', 'violations': '/Users/ericagoodwin/Documents/york-msc/Module 8 - Advanced Programming/Week 6/training_data/violations.csv'}
# cleaning
# seating deats
# 0          0-30
# 1          0-30
# 2          0-30
# 3          0-30
# 4          0-30
#           ...
# 206456    31-60
# 206457    31-60
# 206458    31-60
# 206459    31-60
# 206460    31-60
# Name: SEATING DETAILS, Length: 206461, dtype: object
# pe desc
# 0         RESTAURANT (0-30) SEATS MODERATE RISK
# 1         RESTAURANT (0-30) SEATS MODERATE RISK
# 2         RESTAURANT (0-30) SEATS MODERATE RISK
# 3         RESTAURANT (0-30) SEATS MODERATE RISK
# 4             RESTAURANT (0-30) SEATS HIGH RISK
#                           ...
# 206456       RESTAURANT (31-60) SEATS HIGH RISK
# 206457       RESTAURANT (31-60) SEATS HIGH RISK
# 206458       RESTAURANT (31-60) SEATS HIGH RISK
# 206459       RESTAURANT (31-60) SEATS HIGH RISK
# 206460       RESTAURANT (31-60) SEATS HIGH RISK
# Name: PE DESCRIPTION, Length: 206461, dtype: object
# done handleSave
# done uploadFrame
# testing inspections:
# {'_id': 'INS_DA0004KIJ', 'ACTIVITY DATE': '02/07/2019', 'FACILITY ID': 'FA0067946', 'FACILITY NAME': 'ONE STOP SHOP MART', 'PROGRAM STATUS': 'ACTIVE', 'PE DESCRIPTION': 'FOOD MKT RETAIL (1-1,999 SF) LOW RISK', 'FACILITY ZIP': '90401', 'SCORE': 93.0, 'SERIAL NUMBER': 'DA0004KIJ', 'SEATING DETAILS': '1-1,999 SF'}
# inserted into Mongo
# done handleLoadToDB
# Creating Notebook (Tabs)
# -----------> starting threading-----------> starting threading
# THREAD ONE
#
# THREAD TWO
# No program status: {'_id': 'DAHA0XGHM', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F035', 'F039', 'F036', 'W025']}
# Error: "list index out of range". Cannot add this item to dictionary: DAHA0XGHM
# No program status: {'_id': 'DAD06UFFZ', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F027', 'F035', 'F033', 'F013', 'F026', 'F037', 'F032']}
# Error: "list index out of range". Cannot add this item to dictionary: DAD06UFFZ
# No program status: {'_id': 'DALNEKLWG', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F027', 'F033', 'F037', 'F044', 'F036', 'F030']}
# Error: "list index out of range". Cannot add this item to dictionary: DALNEKLWG
# No program status: {'_id': 'DAIYOORS7', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F038', 'F042', 'F035', 'F044', 'F043', 'F036', 'F030', 'F037', 'F033', 'F014']}
# Error: "list index out of range". Cannot add this item to dictionary: DAIYOORS7
# No program status: {'_id': 'DATMDBCNS', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F033', 'F035', 'F036', 'F030']}
# Error: "list index out of range". Cannot add this item to dictionary: DATMDBCNS
# No program status: {'_id': 'DAS3HLFQE', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F014']}
# Error: "list index out of range". Cannot add this item to dictionary: DAS3HLFQE
# No program status: {'_id': 'DAKPQR2YW', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F029']}
# Error: "list index out of range". Cannot add this item to dictionary: DAKPQR2YW
# No program status: {'_id': 'DAZ7BQS19', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F048']}
# Error: "list index out of range". Cannot add this item to dictionary: DAZ7BQS19
# No program status: {'_id': 'DANKRSOT0', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F007', 'F008', 'F019', 'F036', 'F048']}
# Error: "list index out of range". Cannot add this item to dictionary: DANKRSOT0
# No program status: {'_id': 'DAGUODRUS', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F040', 'F006']}
# Error: "list index out of range". Cannot add this item to dictionary: DAGUODRUS
# No program status: {'_id': 'DANAQZ8D0', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F023', 'F039', 'F033', 'F035', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DANAQZ8D0
# No program status: {'_id': 'DAO0I2XDT', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F008', 'F030', 'F029', 'F033']}No program status: {'_id': 'DAVSHLLVX', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F044', 'F043']}
# Error: "list index out of range". Cannot add this item to dictionary: DAO0I2XDT
#
# Error: "list index out of range". Cannot add this item to dictionary: DAVSHLLVX
# No program status: {'_id': 'DANKRSOT0', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F019', 'F008', 'F036', 'F007', 'F048']}
# Error: "list index out of range". Cannot add this item to dictionary: DANKRSOT0
# No program status: {'_id': 'DAVSHLLVX', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F044', 'F043']}
# Error: "list index out of range". Cannot add this item to dictionary: DAVSHLLVX
# No program status: {'_id': 'DAGUODRUS', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F040', 'F006']}
# Error: "list index out of range". Cannot add this item to dictionary: DAGUODRUS
# No program status: {'_id': 'DANAQZ8D0', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F033', 'F023', 'F044', 'F039', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DANAQZ8D0
# No program status: {'_id': 'DAO0I2XDT', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F033', 'F008', 'F029', 'F030']}
# Error: "list index out of range". Cannot add this item to dictionary: DAO0I2XDT
# No program status: {'_id': 'DAS3HLFQE', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F014']}
# Error: "list index out of range". Cannot add this item to dictionary: DAS3HLFQE
# No program status: {'_id': 'DAKPQR2YW', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F029']}
# Error: "list index out of range". Cannot add this item to dictionary: DAKPQR2YW
# No program status: {'_id': 'DAZ7BQS19', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F048']}
# Error: "list index out of range". Cannot add this item to dictionary: DAZ7BQS19
# No program status: {'_id': 'DAD06UFFZ', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F033', 'F013', 'F027', 'F035', 'F026', 'F037', 'F032']}
# Error: "list index out of range". Cannot add this item to dictionary: DAD06UFFZ
# No program status: {'_id': 'DALNEKLWG', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F044', 'F036', 'F030', 'F037', 'F027', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DALNEKLWG
# No program status: {'_id': 'DAHA0XGHM', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['W025', 'F036', 'F035', 'F039']}
# Error: "list index out of range". Cannot add this item to dictionary: DAHA0XGHM
# No program status: {'_id': 'DAIYOORS7', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F044', 'F043', 'F036', 'F030', 'F038', 'F042', 'F014', 'F035', 'F033', 'F037']}
# Error: "list index out of range". Cannot add this item to dictionary: DAIYOORS7
# No program status: {'_id': 'DATMDBCNS', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F033', 'F036', 'F030', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DATMDBCNS
# No program status: {'_id': 'DAJ5BAGNF', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F023', 'F009', 'F038', 'F035', 'F049']}
# Error: "list index out of range". Cannot add this item to dictionary: DAJ5BAGNF
# No program status: {'_id': 'DAL9NFPUR', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['W051']}
# Error: "list index out of range". Cannot add this item to dictionary: DAL9NFPUR
# No program status: {'_id': 'DAWDT9U2V', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F038', 'F023', 'F043', 'F006']}
# Error: "list index out of range". Cannot add this item to dictionary: DAWDT9U2V
# No program status: {'_id': 'DATMEFXEQ', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F033', 'F043', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DATMEFXEQ
# No program status: {'_id': 'DAFLD1SG7', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F007', 'F036']}
# Error: "list index out of range". Cannot add this item to dictionary: DAFLD1SG7
# No program status: {'_id': 'DABVE0T8M', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F035', 'F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DABVE0T8M
# No program status: {'_id': 'DA9WMWJLQ', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F044', 'F039', 'F035', 'F027', 'F014']}
# Error: "list index out of range". Cannot add this item to dictionary: DA9WMWJLQ
# No program status: {'_id': 'DAHWFCY0L', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAHWFCY0L
# No program status: {'_id': 'DA4I640TU', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F025']}
# Error: "list index out of range". Cannot add this item to dictionary: DA4I640TU
# No program status: {'_id': 'DA1EBTAS0', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F040', 'F007', 'F039', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DA1EBTAS0
# No program status: {'_id': 'DAAQFPEWP', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F007', 'F035', 'F033', 'F006', 'F039', 'F040']}
# Error: "list index out of range". Cannot add this item to dictionary: DAAQFPEWP
# No program status: {'_id': 'DA5KI7Z8X', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F035', 'F027', 'F033', 'F052', 'F039', 'F029', 'F036', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DA5KI7Z8X
# No program status: {'_id': 'DA83KU3R6', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F037', 'F044', 'F023']}
# Error: "list index out of range". Cannot add this item to dictionary: DA83KU3R6
# No program status: {'_id': 'DAJXNQUUA', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F035', 'F032', 'F030']}
# Error: "list index out of range". Cannot add this item to dictionary: DAJXNQUUA
# No program status: {'_id': 'DAOPGOEYY', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F032', 'F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAOPGOEYY
# No program status: {'_id': 'DABU3EZIK', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F040', 'F038']}
# Error: "list index out of range". Cannot add this item to dictionary: DABU3EZIK
# No program status: {'_id': 'DAAMAVQCR', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DAAMAVQCR
# No program status: {'_id': 'DAFD0KTXG', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F044', 'F036', 'F037', 'F006', 'F035', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DAFD0KTXG
# No program status: {'_id': 'DAKBJP9ML', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DAKBJP9ML
# No program status: {'_id': 'DAOPGOEYY', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F032', 'F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAOPGOEYY
# No program status: {'_id': 'DAJXNQUUA', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F032', 'F030', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DAJXNQUUA
# No program status: {'_id': 'DAAMAVQCR', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DAAMAVQCR
# No program status: {'_id': 'DABU3EZIK', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F040', 'F038']}
# Error: "list index out of range". Cannot add this item to dictionary: DABU3EZIK
# No program status: {'_id': 'DA1EBTAS0', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F040', 'F007', 'F039', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DA1EBTAS0
# No program status: {'_id': 'DA5KI7Z8X', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F035', 'F027', 'F033', 'F052', 'F039', 'F029', 'F036', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DA5KI7Z8X
# No program status: {'_id': 'DAAQFPEWP', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F040', 'F007', 'F039', 'F006', 'F033', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DAAQFPEWP
# No program status: {'_id': 'DA83KU3R6', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F044', 'F023', 'F037']}
# Error: "list index out of range". Cannot add this item to dictionary: DA83KU3R6
# No program status: {'_id': 'DAJ5BAGNF', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F049', 'F009', 'F038', 'F023', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DAJ5BAGNF
# No program status: {'_id': 'DAL9NFPUR', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['W051']}
# Error: "list index out of range". Cannot add this item to dictionary: DAL9NFPUR
# No program status: {'_id': 'DAFLD1SG7', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F036', 'F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAFLD1SG7
# No program status: {'_id': 'DABVE0T8M', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F007', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DABVE0T8M
# No program status: {'_id': 'DAKBJP9ML', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DAKBJP9ML
# No program status: {'_id': 'DAWDT9U2V', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F023', 'F006', 'F038', 'F043']}
# No program status: {'_id': 'DAFD0KTXG', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F033', 'F035', 'F037', 'F044', 'F036', 'F006']}Error: "list index out of range". Cannot add this item to dictionary: DAWDT9U2V
# Error: "list index out of range". Cannot add this item to dictionary: DAFD0KTXG
# THREAD ONE
#
# No program status: {'_id': 'DATMEFXEQ', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F044', 'F043', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DATMEFXEQ
# No program status: {'_id': 'DAHWFCY0L', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAHWFCY0L
# No program status: {'_id': 'DA9WMWJLQ', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F039', 'F027', 'F035', 'F014', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DA9WMWJLQ
# No program status: {'_id': 'DA4I640TU', 'PROGRAM STATUS': [], 'ZIP': [], 'VIOLATIONS': ['F025']}
# Error: "list index out of range". Cannot add this item to dictionary: DA4I640TU
# THREAD ONE
# -----------> THREAD ONE stopped threading
# THREAD TWO
# THREAD TWO
# -----------> THREAD TWO stopped threading
# starting plot func ONE
# assigning axis ONE
# plt.show done ONE
# plot done ONE
# window created TWO
# sns bar plot created TWO
# plot done TWO

# %%
import threading
lock = threading.Lock()

x = [1,2,3, 5, 6, 7, 8, 3,9, 0]

def increment(name):
    global x
    
    for i in range(0,len(x)):
        print('AAAAA', i)
        x[i] = 'AAAA'
    print('o')
#         while x < 30:
#             x = x + 1
#             print(f'thread {name}: {x}')
    


def decrement(name):
    global x
    for i in range(0,len(x)):
        print('b')
        x[i] = 'BBBB'
    print('p')
#         while x > 0:
#             x = x - 1
#             print(f'thread {name}: decrement {x}')
    
# THREADS
print('-----------> starting threading')

t1 = threading.Thread(target=increment, args=('THREAD One',))
t2 = threading.Thread(target=decrement, args=('THREAD Two',))

t1.start()
t2.start()


t1.join()
t2.join()  
print('-----------> stopped threading')
x
# Out:
# -----------> starting threading
# AAAAA 0
# AAAAA b1
#
# AAAAAb
# b
# b
# b
# b
# b
# b
# b
# b
# p
#  2
# AAAAA 3
# AAAAA 4
# AAAAA 5
# AAAAA 6
# AAAAA 7
# AAAAA 8
# AAAAA 9
# o
# -----------> stopped threading
# ['BBBB',
#  'BBBB',
#  'AAAA',
#  'AAAA',
#  'AAAA',
#  'AAAA',
#  'AAAA',
#  'AAAA',
#  'AAAA',
#  'AAAA']

# %%
x
# Out:
# ['BBBB', 'BBBB', 'BBBB']

# %%
collection_vendors.count_documents({})
# Out:
# 1998

# %%
violationsAgg = collection_vendors.aggregate([
    {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'}, 'FACILITY ID': {'$addToSet': '$FACILITY ID'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
])
# Find out what violations were committed by each facility
# Use a set() to get unique entries 
# (violations may be committed multiple times by same facility but I only want to count that facility once)
facilityViolations = {}
#         with lock:
#             print(f'Locked: {name}')



for item in violationsAgg:
    try:
        if item['PROGRAM STATUS'][0] == 'INACTIVE':
            continue
    except:
        print(f'No program status: {item}')
    try:
        if item['FACILITY ID'][0] in facilityViolations:
            facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
        else:
            facilityViolations[item['FACILITY ID'][0]] = set()
            facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
    # Possible error - some violations have serial numbers that are not recorded in Inspections data.
    # These are not used in plots because they do not correspond to a facility.
    except Exception as e:
        print(f'Error: "{e}". Cannot add this item to dictionary: {item["_id"]}')
#             print(f'Locked: {name}')
# Out:
# No program status: {'_id': 'DAGUODRUS', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F006', 'F040']}
# Error: "list index out of range". Cannot add this item to dictionary: DAGUODRUS
# No program status: {'_id': 'DAS3HLFQE', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F014']}
# Error: "list index out of range". Cannot add this item to dictionary: DAS3HLFQE
# No program status: {'_id': 'DAAMAVQCR', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DAAMAVQCR
# No program status: {'_id': 'DANKRSOT0', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F036', 'F007', 'F019', 'F048', 'F008']}
# Error: "list index out of range". Cannot add this item to dictionary: DANKRSOT0
# No program status: {'_id': 'DABU3EZIK', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F040', 'F038']}
# Error: "list index out of range". Cannot add this item to dictionary: DABU3EZIK
# No program status: {'_id': 'DAKBJP9ML', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DAKBJP9ML
# No program status: {'_id': 'DAVSHLLVX', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F043', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DAVSHLLVX
# No program status: {'_id': 'DAZ7BQS19', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F048']}
# Error: "list index out of range". Cannot add this item to dictionary: DAZ7BQS19
# No program status: {'_id': 'DANAQZ8D0', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F035', 'F023', 'F044', 'F039', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DANAQZ8D0
# No program status: {'_id': 'DAOPGOEYY', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F032', 'F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAOPGOEYY
# No program status: {'_id': 'DATMDBCNS', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F030', 'F035', 'F036', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DATMDBCNS
# No program status: {'_id': 'DAHA0XGHM', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F036', 'F035', 'F039', 'W025']}
# Error: "list index out of range". Cannot add this item to dictionary: DAHA0XGHM
# No program status: {'_id': 'DAIYOORS7', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F035', 'F036', 'F043', 'F038', 'F033', 'F030', 'F014', 'F042', 'F037', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DAIYOORS7
# No program status: {'_id': 'DA4I640TU', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F025']}
# Error: "list index out of range". Cannot add this item to dictionary: DA4I640TU
# No program status: {'_id': 'DAFD0KTXG', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F033', 'F036', 'F044', 'F037', 'F035', 'F006']}
# Error: "list index out of range". Cannot add this item to dictionary: DAFD0KTXG
# No program status: {'_id': 'DAJ5BAGNF', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F038', 'F009', 'F049', 'F023', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DAJ5BAGNF
# No program status: {'_id': 'DABVE0T8M', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F007', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DABVE0T8M
# No program status: {'_id': 'DAHWFCY0L', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAHWFCY0L
# No program status: {'_id': 'DATMEFXEQ', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F044', 'F043', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DATMEFXEQ
# No program status: {'_id': 'DA83KU3R6', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F037', 'F023', 'F044']}
# Error: "list index out of range". Cannot add this item to dictionary: DA83KU3R6
# No program status: {'_id': 'DAAQFPEWP', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F040', 'F007', 'F035', 'F006', 'F039', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DAAQFPEWP
# No program status: {'_id': 'DAJXNQUUA', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F035', 'F032', 'F030']}
# Error: "list index out of range". Cannot add this item to dictionary: DAJXNQUUA
# No program status: {'_id': 'DAO0I2XDT', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F008', 'F030', 'F033', 'F029']}
# Error: "list index out of range". Cannot add this item to dictionary: DAO0I2XDT
# No program status: {'_id': 'DA9WMWJLQ', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F014', 'F035', 'F044', 'F039', 'F027']}
# Error: "list index out of range". Cannot add this item to dictionary: DA9WMWJLQ
# No program status: {'_id': 'DAL9NFPUR', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['W051']}
# Error: "list index out of range". Cannot add this item to dictionary: DAL9NFPUR
# No program status: {'_id': 'DA5KI7Z8X', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F036', 'F052', 'F035', 'F044', 'F039', 'F027', 'F029', 'F033']}
# Error: "list index out of range". Cannot add this item to dictionary: DA5KI7Z8X
# No program status: {'_id': 'DAFLD1SG7', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F036', 'F007']}
# Error: "list index out of range". Cannot add this item to dictionary: DAFLD1SG7
# No program status: {'_id': 'DAD06UFFZ', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F032', 'F033', 'F026', 'F027', 'F037', 'F035', 'F013']}
# Error: "list index out of range". Cannot add this item to dictionary: DAD06UFFZ
# No program status: {'_id': 'DA1EBTAS0', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F040', 'F007', 'F039', 'F035']}
# Error: "list index out of range". Cannot add this item to dictionary: DA1EBTAS0
# No program status: {'_id': 'DAWDT9U2V', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F043', 'F038', 'F006', 'F023']}
# Error: "list index out of range". Cannot add this item to dictionary: DAWDT9U2V
# No program status: {'_id': 'DAKPQR2YW', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F029']}
# Error: "list index out of range". Cannot add this item to dictionary: DAKPQR2YW
# No program status: {'_id': 'DALNEKLWG', 'PROGRAM STATUS': [], 'FACILITY ID': [], 'VIOLATIONS': ['F036', 'F033', 'F030', 'F027', 'F044', 'F037']}
# Error: "list index out of range". Cannot add this item to dictionary: DALNEKLWG

# %% [raw]
# from queue import Queue
# q = Queue()
# items = []
# violationsAgg = collection_vendors.aggregate([
#     {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'}, 'FACILITY ID': {'$addToSet': '$FACILITY ID'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
# ])
#
# # for item in violationsAgg:
# #     items.append(item)
#
#
# def producer(name):
#
#     for item in violationsAgg:
#         print(item)
#         q.put(item)
#
# def consumer(name):
#     while not q.empty():
# #         print(name)
#         items.append(q.get())
#
#
# # facilityViolations = {}
# # #         with lock:
# # #             print(f'Locked: {name}')
#
#
#
# # for item in violationsAgg:
# #     try:
# #         if item['PROGRAM STATUS'][0] == 'INACTIVE':
# #             continue
# #     except:
# #         print(f'No program status: {item}')
# #     try:
# #         if item['FACILITY ID'][0] in facilityViolations:
# #             facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
# #         else:
# #             facilityViolations[item['FACILITY ID'][0]] = set()
# #             facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
# #     # Possible error - some violations have serial numbers that are not recorded in Inspections data.
# #     # These are not used in plots because they do not correspond to a facility.
# #     except Exception as e:
# #         print(f'Error: "{e}". Cannot add this item to dictionary: {item["_id"]}')
# # #             print(f'Locked: {name}')
#
#
# print('-----------> starting threading')
#
# t1 = threading.Thread(target=producer, args=('THREAD One',))
# t2 = threading.Thread(target=consumer, args=('THREAD Two',))
#
# t1.start()
# t2.start()
#
#
# # t1.join()
# # t2.join()
# print('-----------> stopped threading')
# # q.join()
# len(items)

# %%
from queue import Queue
q = Queue()

q.put({'x':[1,2,3]})
q.put({'y':[1,2,3]})
q.put({'z':[1,2,3]})

# %%
from queue import Queue
import _thread
import time



items = []
facilityViolations = {}
# qList = []

violationsAgg = collection_vendors.aggregate([
    {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'}, 'FACILITY ID': {'$addToSet': '$FACILITY ID'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
])

count = 0

def producer(name,q):
    produce = 0
    for item in violationsAgg:
        q.put(item)
        # Create lock object
#         a_lock = _thread.allocate_lock()
#         with a_lock:
            # check if locked - returns True
#             print(a_lock.locked())
            # Add to queue
#             qList.append(item)
#         a_lock = _thread.allocate_lock()

#         with a_lock:
#             print("producer is locked while this executes")
# #             q.put(item)
#             qList.append(item)
#             produce = produce + 1
# #         print(q.qsize())
#             print(f'queue size {q.qsize()}')
#     print(f'produce {produce}')
    
        
        
def consumer(name,q):
    consume = 0
    while True:
#         x = q.get()
#         items.append(q.get())
        violationsCalc(q.get())
#         if len(qList) > 0:
#             a_lock = _thread.allocate_lock()
#             with a_lock:
#                 x = qList.pop()
#                 items.append(x)
#                 violationsCalc(x)
#         a_lock = _thread.allocate_lock()

#         with a_lock:
# #             items.append(q.get())
#             if len(qList) > 0:
#                 x = qList[0]
#                 items.append(x)
#                 print("consumer is locked while this executes")
#         a_lock.release()
#         else:
#             return False
#         print(qList)
#         consume = consume + 1
#     print(f'consume {consume}')

    return
    
# facilityViolations = {}
# #         with lock:
# #             print(f'Locked: {name}')


def violationsCalc(item):
    try:
        if item['PROGRAM STATUS'][0] == 'INACTIVE':
            print('x')
    except:
        print(f'No program status: {item}')
    try:
        if item['FACILITY ID'][0] in facilityViolations:
            facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
        else:
            facilityViolations[item['FACILITY ID'][0]] = set()
            facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
    # Possible error - some violations have serial numbers that are not recorded in Inspections data.
    # These are not used in plots because they do not correspond to a facility.
    except Exception as e:
        print(f'Error: "{e}". Cannot add this item to dictionary: {item["_id"]}')
#             print(f'Locked: {name}')

q = Queue()
# _thread.start_new_thread(producer, ('one',))
# _thread.start_new_thread(consumer, ('two',))

t1 = threading.Thread(target=producer, args=('THREAD One',q))
t2 = threading.Thread(target=consumer, args=('THREAD Two',q))

t1.start()
t2.start()

# q.join()
# print(len(items))
# items[0]
# Out:
# dict_values([[1, 2, 3]])
# dict_values([[1, 2, 3]])
# dict_values([[1, 2, 3]])

# %%
items
# Out:
# [{'_id': 'DA030WIS0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242487'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03IRZHH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0035220'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000LME7',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0055364'],
#   'VIOLATIONS': ['F007',
#    'F036',
#    'F049',
#    'F044',
#    'F039',
#    'F035',
#    'F042',
#    'F023',
#    'F006']},
#  {'_id': 'DA00PUCN9',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0040309'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02Q5LZI',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0250424'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03Q5QYX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0068898'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04SNN38',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0251632'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03FYEJS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0054372'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00C0OC6',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0248782'],
#   'VIOLATIONS': ['F007', 'F052']},
#  {'_id': 'DA04O60F4',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0073229'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00F1TUH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0261951'],
#   'VIOLATIONS': ['F033', 'F040', 'F055', 'F044', 'F006', 'F034', 'F014']},
#  {'_id': 'DA03FDEKS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0038760'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KGHW0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0035836'],
#   'VIOLATIONS': ['F014', 'F044']},
#  {'_id': 'DA02IF9E3',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049517'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04FQ02G',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0008089'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01HCXYW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0024436'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00RLEAR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0030717'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01U3C8J',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0040967'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KXGCU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0031212'],
#   'VIOLATIONS': []},
#  {'_id': 'DA030VGBI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0051269'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04E2E0R',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0053926'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00VWW5Y',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025571'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03XHNGE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0038442'],
#   'VIOLATIONS': []},
#  {'_id': 'DA025QTSJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0143609'],
#   'VIOLATIONS': []},
#  {'_id': 'DA008YRQD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0248001'],
#   'VIOLATIONS': ['F009', 'F049', 'F044', 'F035', 'F023']},
#  {'_id': 'DA034B00L',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072728'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00XJQOG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0256133'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00Y0Y8A',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0073743'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KYXNL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025042'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01A41EE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177680'],
#   'VIOLATIONS': []},
#  {'_id': 'DA010Z1HX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0066128'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00LB5BX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163272'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01WO0GE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013168'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03KL0YL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0041331'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04RH0L3',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0143759'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KH0VL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021631'],
#   'VIOLATIONS': ['F043', 'F030', 'F046', 'F045', 'F044']},
#  {'_id': 'DA04GTL6Q',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0019670'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JQJEJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0055146'],
#   'VIOLATIONS': ['F043', 'F029', 'F039']},
#  {'_id': 'DA03XOTIY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0162957'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02A0THR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0036306'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02GB6ZO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0044042'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000AXL0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0041356'],
#   'VIOLATIONS': ['F033', 'F040', 'F007', 'F035']},
#  {'_id': 'DA02LTWWW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0144636'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03UJSG4',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163120'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04A0IU4',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0164697'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03BL2LG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0139089'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01Q3X8E',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0069069'],
#   'VIOLATIONS': []},
#  {'_id': 'DA005TUXX',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0065084'],
#   'VIOLATIONS': ['F044', 'F052', 'F036', 'F026']},
#  {'_id': 'DA00QPPXU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177208'],
#   'VIOLATIONS': []},
#  {'_id': 'DA002ZCBF',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0037210'],
#   'VIOLATIONS': ['F033', 'F037', 'F044', 'F039', 'F035', 'F036', 'F030']},
#  {'_id': 'DA03AOBLC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0003718'],
#   'VIOLATIONS': []},
#  {'_id': 'DA037JIIY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0043107'],
#   'VIOLATIONS': []},
#  {'_id': 'DA023L6V8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0048564'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03BUP4T',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0005139'],
#   'VIOLATIONS': []},
#  {'_id': 'DA040OEHQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0037755'],
#   'VIOLATIONS': []},
#  {'_id': 'DA043B2SA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0174695'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03M9GVZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0026261'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ZMLEG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0024415'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00VLYDF',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021117'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02JF0JT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0040430'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00NOKBH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0053930'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00TS7Z1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0057385'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00BL6B0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0141298'],
#   'VIOLATIONS': ['F042', 'F036']},
#  {'_id': 'DA00F2R0A',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0028333'],
#   'VIOLATIONS': ['F040', 'F026', 'F036', 'F044', 'F037', 'F035']},
#  {'_id': 'DA02QAWR0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0036177'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01TTQ38',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0202750'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00USHS8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0033851'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01XTKVV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0071308'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03SED1N',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0241911'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02JB30P',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242900'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03D0OJG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177458'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000NWBX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058509'],
#   'VIOLATIONS': ['F033',
#    'F040',
#    'F046',
#    'F043',
#    'F044',
#    'F039',
#    'F006',
#    'F014']},
#  {'_id': 'DA02ETNSC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021417'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00M00OL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0239298'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00FMFDG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0222900'],
#   'VIOLATIONS': ['F030', 'F037', 'F035', 'F006']},
#  {'_id': 'DA01EGFMW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072070'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00FINLO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0265784'],
#   'VIOLATIONS': ['F043', 'F041']},
#  {'_id': 'DA01KUP2S',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025145'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00EJH0G',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242673'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03OWM1V',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0226200'],
#   'VIOLATIONS': []},
#  {'_id': 'DA002AQHD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0006621'],
#   'VIOLATIONS': ['F033', 'F035', 'F044', 'F006', 'F043', 'F040']},
#  {'_id': 'DA01QMPRI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0018677'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01RJZ1R',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0037389'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000HN2Y',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0251319'],
#   'VIOLATIONS': ['F038', 'F029', 'F009', 'F049', 'F006', 'F042', 'F034']},
#  {'_id': 'DA037YWPB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0011405'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ASU0D',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0015338'],
#   'VIOLATIONS': ['F041', 'F039', 'F035', 'F006', 'F040']},
#  {'_id': 'DA04DDS9K',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0226433'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AROJY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0055202'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AYYMF',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0226147'],
#   'VIOLATIONS': ['F023', 'F033']},
#  {'_id': 'DA03AG7ZZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0036346'],
#   'VIOLATIONS': []},
#  {'_id': 'DA036SKZO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0040691'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02QQY0M',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072306'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00WJRDR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0250591'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03CY8ZR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0267022'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0063HBR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177875'],
#   'VIOLATIONS': ['F036', 'F033', 'F014', 'F052', 'F037', 'F044']},
#  {'_id': 'DA018VTF8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0239997'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02HGDQJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0165990'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AIKUG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0150038'],
#   'VIOLATIONS': ['F042',
#    'F029',
#    'F014',
#    'F033',
#    'F050',
#    'F043',
#    'F037',
#    'F044',
#    'F039',
#    'F035',
#    'F023',
#    'F034']},
#  {'_id': 'DA00GPPE7',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0268437'],
#   'VIOLATIONS': ['F029', 'F033', 'F040', 'F032', 'F006', 'F044']},
#  {'_id': 'DA012F67O',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0250629'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01PN7KS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0175510'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04JEXBW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021474'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04QSTIZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0024227'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00T5GHY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0252617'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02XLIF1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058142'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01K6B33',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0266621'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00Y03JP',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0138744'],
#   'VIOLATIONS': []},
#  {'_id': 'DA035WFFM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0074328'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04OBUON',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0005237'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01PLNN2',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0252220'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01V1MOM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0241309'],
#   'VIOLATIONS': []},
#  {'_id': 'DA025V1JG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0007174'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02PUWIG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177088'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02ZKZ1B',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0222310'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02WW4CJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049205'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04B08D8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0256301'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01PQOZJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0039012'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03UODDT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0140146'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02EGVOT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0068919'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02MTSZR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0011992'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04CPAUE',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0071161'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02VHKYY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0030910'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HHD9M',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242100'],
#   'VIOLATIONS': ['F029', 'F036', 'F027', 'F039']},
#  {'_id': 'DA03EUITE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0171682'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00OM0KR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0165502'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03PA4KP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0069932'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04XR18C',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0018158'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02WPBZY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0055414'],
#   'VIOLATIONS': []},
#  {'_id': 'DA027S4AE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0030810'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01F4LAQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0062875'],
#   'VIOLATIONS': []},
#  {'_id': 'DA036LT6Y',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0226236'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04FYH0W',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0157945'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02MMMFJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0268182'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04QTUGZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0055825'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00BVYU5',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0007361'],
#   'VIOLATIONS': ['F053', 'F006', 'F023', 'F039', 'F036', 'F004']},
#  {'_id': 'DA00I0OYZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0047100'],
#   'VIOLATIONS': ['F040', 'F033', 'F007', 'F035', 'F044']},
#  {'_id': 'DA00YQBJU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0249870'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04WG22P',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021224'],
#   'VIOLATIONS': []},
#  {'_id': 'DA010AR4X',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0052391'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HV5ZX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0069069'],
#   'VIOLATIONS': ['F033', 'F007', 'F043', 'F049', 'F044']},
#  {'_id': 'DA00DH2AU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0050549'],
#   'VIOLATIONS': ['F033', 'F007', 'F035', 'F044', 'F006', 'F036', 'F030']},
#  {'_id': 'DA03FVNJ3',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0180561'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02TPV1D',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0053270'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04R7KAA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0035223'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03HYYNB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0019121'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00MZVLU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163620'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01WXYDF',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0138611'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01L5TTC',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0221862'],
#   'VIOLATIONS': []},
#  {'_id': 'DA048Y1ND',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0026266'],
#   'VIOLATIONS': []},
#  {'_id': 'DA008WGOM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0143602'],
#   'VIOLATIONS': ['F049', 'F016', 'F008', 'F036', 'F033', 'F029']},
#  {'_id': 'DA02EUIUH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0142220'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03J22PP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0008317'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03NVD1S',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025455'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00TJHWK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0249877'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ZIX52',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0044986'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KCVDM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0008166'],
#   'VIOLATIONS': ['F035', 'F013', 'F034', 'F005', 'F049', 'F044', 'F037']},
#  {'_id': 'DA01DZN1R',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0036823'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00T7KQO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0167857'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KSJOS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0063817'],
#   'VIOLATIONS': []},
#  {'_id': 'DA031ASKC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177656'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02QMS4I',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0244582'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00OYIBJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034405'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JNHRP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0137772'],
#   'VIOLATIONS': ['F036', 'F053', 'F044', 'F037']},
#  {'_id': 'DA00NLV0Y',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0024324'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00SCCET',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0005489'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01LBAK8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0054832'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01VOWQG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034222'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03HX9PZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0224655'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04EAGOK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0255768'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00THOK8',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0159378'],
#   'VIOLATIONS': []},
#  {'_id': 'DA036ZNLP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0248805'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04WK5MZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025457'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02OV3DN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0060742'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03Y0ATH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021893'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00PL005',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0015535'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KQCLX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0175444'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01I2P77',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0260235'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01EYVGW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0039848'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04JPL8K',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0022246'],
#   'VIOLATIONS': []},
#  {'_id': 'DA038GLJI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0178975'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ORGKL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0057385'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00GNB7E',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0012608'],
#   'VIOLATIONS': ['F029', 'F039', 'F037']},
#  {'_id': 'DA01S8YZ0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0022795'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00MUP3C',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0155810'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JPGCS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0257174'],
#   'VIOLATIONS': ['F009',
#    'F030',
#    'F007',
#    'F047',
#    'F036',
#    'F043',
#    'F037',
#    'F035']},
#  {'_id': 'DA034I70O',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0037245'],
#   'VIOLATIONS': []},
#  {'_id': 'DA036XJAG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0070815'],
#   'VIOLATIONS': []},
#  {'_id': 'DA007FH2S',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0178400'],
#   'VIOLATIONS': ['F029', 'F033', 'F007', 'F043', 'F049', 'F039', 'F023']},
#  {'_id': 'DA004ICF7',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0222864'],
#   'VIOLATIONS': ['F033', 'F034', 'F053', 'F039', 'F007']},
#  {'_id': 'DA02F4COS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0171492'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00P0JOT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0018684'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ZMSFA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0045530'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00NSPFM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072691'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01VZ4ZO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0050580'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02AT937',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0026423'],
#   'VIOLATIONS': []},
#  {'_id': 'DA040KI1U',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0046332'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0050AMJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0015806'],
#   'VIOLATIONS': ['F040',
#    'F007',
#    'F035',
#    'F025',
#    'F049',
#    'F043',
#    'F036',
#    'F046']},
#  {'_id': 'DA022SJSP',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0156386'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04LFA6D',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0012769'],
#   'VIOLATIONS': []},
#  {'_id': 'DA009JXDS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0257341'],
#   'VIOLATIONS': ['F055', 'F027', 'F006', 'F042', 'F040', 'F036']},
#  {'_id': 'DA04NPABH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0202737'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00FRUBI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021552'],
#   'VIOLATIONS': ['F007', 'F043', 'F026', 'F044', 'F049', 'F023', 'F035']},
#  {'_id': 'DA03VVRNP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0014656'],
#   'VIOLATIONS': []},
#  {'_id': 'DA040UIVL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0038622'],
#   'VIOLATIONS': []},
#  {'_id': 'DA005Y7GY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0174918'],
#   'VIOLATIONS': ['F035', 'F007', 'F033']},
#  {'_id': 'DA029CWLG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0053911'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00VNJUL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0065211'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000PKSL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0064724'],
#   'VIOLATIONS': ['F033', 'F040', 'F044']},
#  {'_id': 'DA00QAE7R',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0014694'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03BOCN2',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0033331'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00NQJGX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0057421'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01BQQE3',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0258182'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AMSTA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0009651'],
#   'VIOLATIONS': ['F033', 'F037', 'F035', 'F040']},
#  {'_id': 'DA03BXZ4J',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0051651'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00EQWDA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0159098'],
#   'VIOLATIONS': ['F038',
#    'F007',
#    'F009',
#    'F026',
#    'F050',
#    'F036',
#    'F027',
#    'F044',
#    'F039',
#    'F023',
#    'F008',
#    'F014']},
#  {'_id': 'DA02I0DCE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058626'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03A0IYO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0033988'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03XN2KD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163834'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04AWWQE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0071480'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01ZNEUA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0043536'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00RY4GM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025252'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02071WD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0048781'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03FKHBB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0005739'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03HWFGN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0073375'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00J33KQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163033'],
#   'VIOLATIONS': ['F036', 'F037', 'F034']},
#  {'_id': 'DA013EWH9',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0009725'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01VNEU4',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0251980'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00CQ3AP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0260114'],
#   'VIOLATIONS': ['F053', 'F033']},
#  {'_id': 'DA03H5BK0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0048976'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00IS31R',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0042538'],
#   'VIOLATIONS': ['F029', 'F033', 'F052', 'F014', 'F005']},
#  {'_id': 'DA02AXMJD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025889'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KIIPS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0239809'],
#   'VIOLATIONS': ['F043', 'F042', 'F006']},
#  {'_id': 'DA04J2GSE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034184'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0009NS7',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0159039'],
#   'VIOLATIONS': ['F040', 'F007', 'F046', 'F044', 'F034', 'F013']},
#  {'_id': 'DA03WXA5W',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013546'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03CNFTB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0244260'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KZXGR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177487'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01B0PG0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242846'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HWWZV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0241250'],
#   'VIOLATIONS': ['F030', 'F033', 'F004', 'F025', 'F014']},
#  {'_id': 'DA02XGDXN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0059025'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04JHJXS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058411'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03YAONG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0165710'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000NZHE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0032856'],
#   'VIOLATIONS': ['F040', 'F029', 'F043', 'F036', 'F044', 'F035']},
#  {'_id': 'DA00UXN0E',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0042626'],
#   'VIOLATIONS': []},
#  {'_id': 'DA009ZYRV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0065668'],
#   'VIOLATIONS': ['F044',
#    'F037',
#    'F035',
#    'F006',
#    'F014',
#    'F033',
#    'F040',
#    'F030']},
#  {'_id': 'DA03MNIDA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0031082'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00F0GKK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0051496'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00RQLS3',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0045823'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04SJWPF',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0052691'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02EWDGI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0249958'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02RLCVV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034754'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0309TT3',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0002335'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JGZHJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0252592'],
#   'VIOLATIONS': ['F040']},
#  {'_id': 'DA04NIC2V',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0203336'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00DQZNU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0005548'],
#   'VIOLATIONS': ['F033', 'F037', 'F044', 'F043', 'F030']},
#  {'_id': 'DA00MPU4B',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0245733'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0218H85',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034481'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00UNPGN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0165837'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01PDS96',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0138515'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01WQS6Y',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0245792'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03PUWLS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0166729'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0206LOO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0039928'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03HWHEZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0011210'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04027CI',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0072621'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02007AR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0249587'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02YSFEA',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0036519'],
#   'VIOLATIONS': []},
#  {'_id': 'DA030XZHP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0036357'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00BFNM6',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034188'],
#   'VIOLATIONS': ['F046', 'F042', 'F044', 'F040', 'F038']},
#  {'_id': 'DA04BIVD2',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0244440'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00UW70H',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240767'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02EPFLB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049283'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ECWTX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072829'],
#   'VIOLATIONS': ['F006']},
#  {'_id': 'DA00Q5KAW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0202786'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HZM0Y',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034396'],
#   'VIOLATIONS': ['F033', 'F044', 'F039']},
#  {'_id': 'DA020H68W',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0057163'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00GKTUJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049483'],
#   'VIOLATIONS': ['F033', 'F044', 'F042']},
#  {'_id': 'DA04CBG1S',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0063641'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00RVKYN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0019271'],
#   'VIOLATIONS': []},
#  {'_id': 'DA043XMAL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0050503'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04C00HB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0070845'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00C4Q1H',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0160161'],
#   'VIOLATIONS': ['F040', 'F007', 'F008', 'F052', 'F044', 'F026', 'F033']},
#  {'_id': 'DA00XQTDN',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0151431'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04JF1ZG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0029863'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03Q55G2',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0029623'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02LQIHS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0006557'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00UN76N',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0066005'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03OAVWM',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0174414'],
#   'VIOLATIONS': []},
#  {'_id': 'DA047H3XR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0203887'],
#   'VIOLATIONS': []},
#  {'_id': 'DA018ES8P',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0054807'],
#   'VIOLATIONS': []},
#  {'_id': 'DA030YD1L',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049233'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00DNNHV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0173765'],
#   'VIOLATIONS': ['F034']},
#  {'_id': 'DA03NKPWV',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0165044'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03FWPPQ',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0045326'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01KWOU1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0166809'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02300Z1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0047361'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00GSUEM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0047866'],
#   'VIOLATIONS': ['F030', 'F039', 'F035']},
#  {'_id': 'DA0004KIJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0067946'],
#   'VIOLATIONS': ['F049', 'F037', 'F015', 'F042', 'F006']},
#  {'_id': 'DA005YLYE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163988'],
#   'VIOLATIONS': ['F041', 'F044', 'F052', 'F034', 'F033', 'F030', 'F036']},
#  {'_id': 'DA00AKEFB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072809'],
#   'VIOLATIONS': ['F040', 'F029', 'F050', 'F036', 'F023', 'F044', 'F035']},
#  {'_id': 'DA00L0HHR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0069270'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0068XCQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0007514'],
#   'VIOLATIONS': ['F044', 'F033', 'F052']},
#  {'_id': 'DA01P0Q9I',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0221987'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00L4URX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0007684'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00BBSUS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0043731'],
#   'VIOLATIONS': ['F035', 'F036', 'F026']},
#  {'_id': 'DA01D1JHG',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0175723'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00YHQ9E',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0243451'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00U1LNJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242571'],
#   'VIOLATIONS': []},
#  {'_id': 'DA006IMAD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0248490'],
#   'VIOLATIONS': ['F037', 'F033', 'F044']},
#  {'_id': 'DA04WS0EZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0159704'],
#   'VIOLATIONS': []},
#  {'_id': 'DA039VI4D',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0016001'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02N0XDB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0176297'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00TWGHZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013190'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00B0YJU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242514'],
#   'VIOLATIONS': ['F014', 'F044']},
#  {'_id': 'DA00TAIGB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0174523'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0497D0T',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0046199'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03PW8BS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0259289'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00LWCIW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049128'],
#   'VIOLATIONS': []},
#  {'_id': 'DA028BYNC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0074221'],
#   'VIOLATIONS': []},
#  {'_id': 'DA034LYWO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0261843'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HIBAC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177648'],
#   'VIOLATIONS': ['F033', 'F036', 'F023', 'F039']},
#  {'_id': 'DA00VROTJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0158997'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01SSRFX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0015617'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01KWIWE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0138927'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00IRSQ7',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0056960'],
#   'VIOLATIONS': ['F029', 'F007', 'F033', 'F035', 'F044', 'F039', 'F027']},
#  {'_id': 'DA017LDCL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0064172'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00YBCQ7',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0022119'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ZHL0E',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0257351'],
#   'VIOLATIONS': []},
#  {'_id': 'DA043M60V',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0173857'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00YUOFT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163416'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00WM6CQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0259441'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HBPUJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0241963'],
#   'VIOLATIONS': ['F036', 'F035', 'F044', 'F014']},
#  {'_id': 'DA00VMLLI',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0138744'],
#   'VIOLATIONS': []},
#  {'_id': 'DA016DHFD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0150936'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01VBLDD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0241342'],
#   'VIOLATIONS': []},
#  {'_id': 'DA027LJ60',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0243109'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04P6RNQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0023432'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JTMWR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013329'],
#   'VIOLATIONS': ['F033', 'F040', 'F009', 'F023', 'F035']},
#  {'_id': 'DA00HPLK5',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0051546'],
#   'VIOLATIONS': ['F033', 'F043', 'F036', 'F037', 'F035', 'F044', 'F014']},
#  {'_id': 'DA00UIMKZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0011370'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00O7B3E',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013613'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00TZMN1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0045858'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00EIT1A',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0061279'],
#   'VIOLATIONS': ['F040', 'F038', 'F006', 'F042']},
#  {'_id': 'DA02G7ABI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0167728'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01KIVVM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0180038'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04JDNF8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0047624'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04BGDPT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0141780'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00X61GC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0175577'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00RKGVL',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0180027'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JUDXG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0170223'],
#   'VIOLATIONS': ['F025', 'F033', 'F044', 'F037']},
#  {'_id': 'DA00RC8LH',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0013156'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03BGNC0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242873'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0024TXM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0056882'],
#   'VIOLATIONS': ['F033', 'F044', 'F006']},
#  {'_id': 'DA024K3SC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177936'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KCHS1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0052168'],
#   'VIOLATIONS': ['F007', 'F035']},
#  {'_id': 'DA01RC5BH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0265279'],
#   'VIOLATIONS': []},
#  {'_id': 'DA021HKRK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0065603'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03GHT0D',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0016721'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01IPAPN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0043706'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0490OSZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0142968'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00X5LIC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0050091'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KHYTH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0022240'],
#   'VIOLATIONS': ['F006', 'F033']},
#  {'_id': 'DA04S2AIX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0035327'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0007NP7',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0055091'],
#   'VIOLATIONS': ['F033', 'F039']},
#  {'_id': 'DA00FBONI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0026897'],
#   'VIOLATIONS': ['F043', 'F023']},
#  {'_id': 'DA00J95LY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021244'],
#   'VIOLATIONS': ['F040', 'F041', 'F052', 'F023']},
#  {'_id': 'DA04JAGBX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0002774'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000XZTY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0003849'],
#   'VIOLATIONS': ['F033', 'F023', 'F044', 'F039', 'F035', 'F006', 'F014']},
#  {'_id': 'DA02H4A30',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058685'],
#   'VIOLATIONS': []},
#  {'_id': 'DA042CIUT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240488'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04PPJDX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021688'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AJC5P',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0019516'],
#   'VIOLATIONS': ['F014', 'F004', 'F037', 'F035']},
#  {'_id': 'DA00I6P34',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058080'],
#   'VIOLATIONS': ['F042', 'F046', 'F037', 'F044']},
#  {'_id': 'DA04TAJUA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0003877'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00GWPAP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0034651'],
#   'VIOLATIONS': ['F032',
#    'F033',
#    'F030',
#    'F029',
#    'F044',
#    'F049',
#    'F023',
#    'F013']},
#  {'_id': 'DA01YT3RP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0224933'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HBFW6',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0222795'],
#   'VIOLATIONS': ['F029', 'F033', 'F023']},
#  {'_id': 'DA026Z20K',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0018456'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04J0V0O',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0138728'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00T0P2U',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0179997'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00TXN91',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0241959'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01NFXJB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0016588'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02EDLLZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0064764'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00BSLNV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049965'],
#   'VIOLATIONS': ['F035', 'F055', 'F044', 'F046']},
#  {'_id': 'DA00IIDDH',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0143761'],
#   'VIOLATIONS': ['F040', 'F033', 'F044', 'F014']},
#  {'_id': 'DA046BAH1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0225666'],
#   'VIOLATIONS': []},
#  {'_id': 'DA024K8D9',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072380'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04M0X87',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0167268'],
#   'VIOLATIONS': []},
#  {'_id': 'DA000UBD4',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021220'],
#   'VIOLATIONS': ['F044', 'F037', 'F014']},
#  {'_id': 'DA0309LRR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0046071'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04ERBXB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0070815'],
#   'VIOLATIONS': []},
#  {'_id': 'DA001KKC8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058005'],
#   'VIOLATIONS': ['F040', 'F044']},
#  {'_id': 'DA00SM7D4',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0047920'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04SZ09V',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0009122'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03LU7PD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0050281'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00SA0V1',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0071810'],
#   'VIOLATIONS': []},
#  {'_id': 'DA038C2MM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021493'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02A70VQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0165675'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00CMMCI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0064534'],
#   'VIOLATIONS': ['F014', 'F037', 'F023', 'F044', 'F039', 'F046']},
#  {'_id': 'DA00YJLDA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0011473'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00U7DRD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0172015'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01WOTSR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240436'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00RD2JU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0018668'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01AJIXC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240478'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04ENERS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0046020'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ZR5PM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0245216'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03IVAHG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0176944'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00CCCG8',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0054691'],
#   'VIOLATIONS': ['F040', 'F030', 'F053', 'F006', 'F052', 'F044', 'F036']},
#  {'_id': 'DA015HAK4',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021143'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02YDHIA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0222850'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01E8BHG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0029947'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04M0FLV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0053919'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04NUDUE',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0137424'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00D2MX0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0247845'],
#   'VIOLATIONS': ['F033', 'F014', 'F007', 'F037', 'F035', 'F040']},
#  {'_id': 'DA04SSF4J',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0031151'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03IRHWW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0203198'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00R2SS0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0252680'],
# ...
#  {'_id': 'DA00PAD2Y',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240811'],
#   'VIOLATIONS': []},
#  {'_id': 'DA036VCQN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0018059'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00NZICQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0242857'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02PS4VS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0041863'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00KXZPG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0166809'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03ZBMRM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0239124'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00DWCI0',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0164568'],
#   'VIOLATIONS': ['F033',
#    'F014',
#    'F034',
#    'F052',
#    'F006',
#    'F044',
#    'F039',
#    'F036',
#    'F043',
#    'F046',
#    'F040']},
#  {'_id': 'DA00ODLNY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0158479'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04R0XWQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0029908'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00M8JMU',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0021250'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00DRRJC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0248590'],
#   'VIOLATIONS': ['F033', 'F044', 'F039', 'F007']},
#  {'_id': 'DA01ZMHNB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0022883'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03OX3KI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0071649'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00BHPAK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013329'],
#   'VIOLATIONS': ['F030', 'F035', 'F044', 'F039']},
#  {'_id': 'DA00EITVI',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0004261'],
#   'VIOLATIONS': ['F033', 'F040', 'F029', 'F037', 'F035', 'F053']},
#  {'_id': 'DA02H7TWA',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0003862'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03AS04G',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0170221'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00F03OP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0265944'],
#   'VIOLATIONS': ['F040', 'F034', 'F014']},
#  {'_id': 'DA030UA3P',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0263379'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00VVEHZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0066702'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01DXZVT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0032053'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00N0JZV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0044688'],
#   'VIOLATIONS': []},
#  {'_id': 'DA015L2WQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0036725'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01Y8P81',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0179870'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00MYGEB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0035649'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03NI08L',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0036091'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00OMQ7A',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0170519'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04THBPS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0251110'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AH9DF',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0243444'],
#   'VIOLATIONS': ['F043', 'F040', 'F037']},
#  {'_id': 'DA00IWQVA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0011753'],
#   'VIOLATIONS': ['F007', 'F037', 'F035', 'F034']},
#  {'_id': 'DA02YGFGB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0026654'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JMXTJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0070548'],
#   'VIOLATIONS': ['F033', 'F037', 'F044', 'F035', 'F027']},
#  {'_id': 'DA019LQPM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0063820'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00Y03H5',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0249651'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02IM1WT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0045221'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04NK8WY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0024674'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00SRX15',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0061935'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0120YGO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0051661'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02TJLSC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0012731'],
#   'VIOLATIONS': []},
#  {'_id': 'DA031UXN0',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0069265'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00Q4NRJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0049411'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0389F0N',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0050193'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00GVL0P',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0062913'],
#   'VIOLATIONS': ['F014',
#    'F033',
#    'F007',
#    'F036',
#    'F026',
#    'F044',
#    'F049',
#    'F052',
#    'F039',
#    'F054',
#    'F037',
#    'F035']},
#  {'_id': 'DA04210EA',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0029144'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01HPHS6',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0160434'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0031FQQ',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0059237'],
#   'VIOLATIONS': ['F033', 'F006', 'F044']},
#  {'_id': 'DA01SNF7O',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0055193'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01YRSTX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0035660'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02HVR1U',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0024368'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02WR0NT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0203001'],
#   'VIOLATIONS': []},
#  {'_id': 'DA043K0KV',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0020364'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03KWNWD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013325'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03SHSOK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0008357'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00UVGZH',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0022763'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01AZNYP',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072006'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00G0NVR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0006123'],
#   'VIOLATIONS': ['F008']},
#  {'_id': 'DA04UYKXO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0259777'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00MW3UD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0067398'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02TOY6B',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0032177'],
#   'VIOLATIONS': []},
#  {'_id': 'DA012HSSV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0265876'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02PGHVX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0177843'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03NYHLS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0006427'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00C9NLY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0007595'],
#   'VIOLATIONS': ['F033']},
#  {'_id': 'DA000RJCK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0065791'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00XRQOS',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0042668'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03DLB4S',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0058967'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ZRWDZ',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0071088'],
#   'VIOLATIONS': []},
#  {'_id': 'DA007U3KR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0072087'],
#   'VIOLATIONS': ['F033', 'F036', 'F027', 'F044', 'F037']},
#  {'_id': 'DA00XH1XC',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0059017'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04FS0PQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0005962'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02MGENI',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0053156'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00EWS0M',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0008648'],
#   'VIOLATIONS': ['F033',
#    'F040',
#    'F046',
#    'F043',
#    'F037',
#    'F035',
#    'F006',
#    'F005']},
#  {'_id': 'DA004HUWW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0164491'],
#   'VIOLATIONS': ['F007', 'F037', 'F039', 'F035', 'F008', 'F006', 'F030']},
#  {'_id': 'DA01T6ARG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0044198'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00UOE3J',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0158621'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00VG0GR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0138602'],
#   'VIOLATIONS': []},
#  {'_id': 'DA0200SPW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163119'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02Q5T5M',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0258453'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02TPURX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0053844'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04AOD7D',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0175622'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01QFCSB',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0070395'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01L01T2',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0056605'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02LTI80',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0029287'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HXS0R',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0239882'],
#   'VIOLATIONS': ['F008']},
#  {'_id': 'DA012ZMTQ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0266684'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04LYNAJ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0223957'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01H4ETE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0251001'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AEU2C',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0025677'],
#   'VIOLATIONS': ['F044', 'F029', 'F037']},
#  {'_id': 'DA00VIVEA',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0024789'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01DDPGX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0061538'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02PBBXI',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0044668'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00E0XD9',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0032158'],
#   'VIOLATIONS': ['F014', 'F044', 'F039', 'F007']},
#  {'_id': 'DA04JX3ZF',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0049113'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04UTQ4S',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0063713'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03DPBHY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0043532'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HHO0X',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240482'],
#   'VIOLATIONS': ['F029', 'F037']},
#  {'_id': 'DA04HI3ON',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240630'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00PJN0P',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0043095'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01BXVW3',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0051249'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00ROFD8',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0028083'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03DGHAK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0225129'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00HSEM6',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0156500'],
#   'VIOLATIONS': ['F033', 'F035', 'F044']},
#  {'_id': 'DA00R0VOT',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0166197'],
#   'VIOLATIONS': []},
#  {'_id': 'DA020IAWO',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0225297'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02SPHIM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0166446'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04SUIXF',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0002931'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02QPZDX',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0243637'],
#   'VIOLATIONS': []},
#  {'_id': 'DA045RMSE',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0163712'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02BZEJZ',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0009372'],
#   'VIOLATIONS': []},
#  {'_id': 'DA010OIRV',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0027726'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02QZF1D',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0005413'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00JRRML',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0157916'],
#   'VIOLATIONS': ['F036', 'F040', 'F038', 'F007', 'F044']},
#  {'_id': 'DA00HWE5B',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0166244'],
#   'VIOLATIONS': ['F033',
#    'F040',
#    'F030',
#    'F035',
#    'F052',
#    'F027',
#    'F039',
#    'F023']},
#  {'_id': 'DA00JMP5Q',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0037508'],
#   'VIOLATIONS': ['F007', 'F033', 'F006', 'F044', 'F014']},
#  {'_id': 'DA04VYJKW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0013597'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02DR442',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0069663'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00G004I',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0202544'],
#   'VIOLATIONS': ['F038',
#    'F033',
#    'F014',
#    'F046',
#    'F036',
#    'F007',
#    'F022',
#    'F044',
#    'F037',
#    'F035']},
#  {'_id': 'DA01GDTUY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0032786'],
#   'VIOLATIONS': []},
#  {'_id': 'DA04SX0MK',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0245583'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02Z9KVG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0016576'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00CTPWD',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240995'],
#   'VIOLATIONS': ['F037', 'F035', 'F043', 'F033']},
#  {'_id': 'DA00OI0EM',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0057107'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00RRENN',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0255776'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00NBRA7',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0068159'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00941RY',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0225588'],
#   'VIOLATIONS': ['F025', 'F006', 'F039', 'F004']},
#  {'_id': 'DA00Q0KW0',
#   'PROGRAM STATUS': ['INACTIVE'],
#   'FACILITY ID': ['FA0137540'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00VFLJG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0240621'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01CIL8L',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0039512'],
#   'VIOLATIONS': []},
#  {'_id': 'DA01600VW',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0051768'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03FRDB9',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0028038'],
#   'VIOLATIONS': []},
#  {'_id': 'DA03IRF8I',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0014753'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00T6H2K',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0022970'],
#   'VIOLATIONS': []},
#  {'_id': 'DA02TKMV5',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0044663'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00CJI4S',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0241179'],
#   'VIOLATIONS': ['F006', 'F023', 'F043']},
#  {'_id': 'DA00ZPESK',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0033673'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00AOOV6',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0037089'],
#   'VIOLATIONS': ['F033', 'F034', 'F035', 'F055', 'F044', 'F007']},
#  {'_id': 'DA030QKIR',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0165314'],
#   'VIOLATIONS': []},
#  {'_id': 'DA00302GG',
#   'PROGRAM STATUS': ['ACTIVE'],
#   'FACILITY ID': ['FA0035435'],
#   'VIOLATIONS': ['F014', 'F042', 'F006', 'F055', 'F040']}]

# %%
from queue import Queue
import time
q = Queue()
items = []
violationsAgg = collection_vendors.aggregate([
    {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'}, 'FACILITY ID': {'$addToSet': '$FACILITY ID'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
])

# for item in violationsAgg:
#     items.append(item)


def producer(name):
    for item in violationsAgg:
        print(name)
        q.put(item)
        
        
def consumer(name):
    while True:
        items.append(q.get())
#         if not q.empty():
#             print(name)
#             items.append(q.get())
#             print(q.qsize())
        
    
# facilityViolations = {}
# #         with lock:
# #             print(f'Locked: {name}')



# for item in violationsAgg:
#     try:
#         if item['PROGRAM STATUS'][0] == 'INACTIVE':
#             continue
#     except:
#         print(f'No program status: {item}')
#     try:
#         if item['FACILITY ID'][0] in facilityViolations:
#             facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
#         else:
#             facilityViolations[item['FACILITY ID'][0]] = set()
#             facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
#     # Possible error - some violations have serial numbers that are not recorded in Inspections data.
#     # These are not used in plots because they do not correspond to a facility.
#     except Exception as e:
#         print(f'Error: "{e}". Cannot add this item to dictionary: {item["_id"]}')
# #             print(f'Locked: {name}')


print('-----------> starting threading')

t1 = threading.Thread(target=producer, args=('THREAD One',))
t2 = threading.Thread(target=consumer, args=('THREAD Two',))

t1.start()
t2.start()


t1.join()
t2.join()  
print('-----------> stopped threading')
q.join()
print(len(items))
items[0]
# Out:
# -----------> starting threading
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# THREAD One
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-45496ba84c05> in <module>
#      61
#      62 t1.join()
# ---> 63 t2.join()
#      64 print('-----------> stopped threading')
#      65 q.join()
#
# ~/opt/anaconda3/lib/python3.8/threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# ~/opt/anaconda3/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:

# %%
q.qsize()
# Out:
# 0

# %%
len(items)

# %%
from queue import Queue
import threading

items = []
facilityViolations = {}

violationsAgg = collection_vendors.aggregate([
    {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'}, 'FACILITY ID': {'$addToSet': '$FACILITY ID'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
])

def producer(name,q):
    produce = 0
    for item in violationsAgg:
        q.put(item)

def consumer(name,q):
    consume = 0
    while True:
        x = q.get()
        items.append(x)
        violationsCalc(x)
    return


def violationsCalc(item):
    try:
        if item['PROGRAM STATUS'][0] == 'INACTIVE':
            return
    except:
        print(f'No program status: {item}')
    try:
        if item['FACILITY ID'][0] in facilityViolations:
            facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
        else:
            facilityViolations[item['FACILITY ID'][0]] = set()
            facilityViolations[item['FACILITY ID'][0]].update(item['VIOLATIONS'])
    # Possible error - some violtations have serial numbers that are not recorded in Inspections data.
    # These are not used in plots because they do not correspond to a facility.
    except Exception as e:
        print(f'Error: "{e}". Cannot add this item to dictionary: {item["_id"]}')

q = Queue()
t1 = threading.Thread(target=producer, args=('THREAD One',q))
t2 = threading.Thread(target=consumer, args=('THREAD Two',q))

t1.start()
t2.start()
# Out:
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x

# %%
len(items)
# Out:
# 999

# %%
q.qsize()
# Out:
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# 0
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# ...
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes
# consumer is locked while this executes

# %%
consume
# Out:
# 0

# %%
violationsAgg = collection_vendors.aggregate([
    {'$group': {'_id': '$SERIAL NUMBER','PROGRAM STATUS':{'$addToSet':'$PROGRAM STATUS'}, 'FACILITY ID': {'$addToSet': '$FACILITY ID'}, 'VIOLATIONS': {'$addToSet': '$VIOLATION CODE'}}}
])
items=[]
for item in violationsAgg:
    items.append(item)
    
len(items)
# Out:
# 999

# %%
facilityViolations
# Out:
# {'FA0028333': {'F026', 'F035', 'F036', 'F037', 'F040', 'F044'},
#  'FA0008309': {'F013', 'F029', 'F033', 'F034', 'F039', 'F040', 'F043', 'F044'},
#  'FA0006123': {'F008', 'F037', 'F043', 'F048'},
#  'FA0141298': {'F036', 'F042'},
#  'FA0018414': {'F035', 'F036'},
#  'FA0175837': {'F007',
#   'F022',
#   'F023',
#   'F025',
#   'F027',
#   'F033',
#   'F034',
#   'F035',
#   'F036',
#   'F037',
#   'F042',
#   'F044'},
#  'FA0013582': set(),
#  'FA0021688': set(),
#  'FA0242571': set(),
#  'FA0242487': set(),
#  'FA0158258': set(),
#  'FA0036306': set(),
#  'FA0241342': set(),
#  'FA0048317': set(),
#  'FA0072728': set(),
#  'FA0178683': set(),
#  'FA0202737': set(),
#  'FA0259952': set(),
#  'FA0242010': set(),
#  'FA0048411': set(),
#  'FA0019271': {'F007', 'F033', 'F035', 'F036', 'F040', 'F044'},
#  'FA0252657': set(),
#  'FA0244948': set(),
#  'FA0178305': set(),
#  'FA0165233': set(),
#  'FA0043632': set(),
#  'FA0048047': set(),
#  'FA0037210': {'F030', 'F033', 'F035', 'F036', 'F037', 'F039', 'F044'},
#  'FA0057214': set(),
#  'FA0049483': {'F033', 'F042', 'F044'},
#  'FA0005247': {'F009', 'F014', 'F034', 'F043'},
#  'FA0010380': set(),
#  'FA0030996': set(),
#  'FA0053702': set(),
#  'FA0018631': set(),
#  'FA0251193': set(),
#  'FA0248490': {'F033', 'F037', 'F044'},
#  'FA0248001': {'F009', 'F023', 'F035', 'F044', 'F049'},
#  'FA0062047': set(),
#  'FA0034263': set(),
#  'FA0053996': {'F035', 'F036', 'F037', 'F042', 'F044'},
#  'FA0033126': set(),
#  'FA0041356': {'F007', 'F033', 'F035', 'F040'},
#  'FA0245583': set(),
#  'FA0165044': set(),
#  'FA0023111': set(),
#  'FA0151431': set(),
#  'FA0242873': set(),
#  'FA0180027': set(),
#  'FA0158876': {'F009', 'F014', 'F027', 'F030', 'F036', 'F042'},
#  'FA0158058': set(),
#  'FA0262380': set(),
#  'FA0016279': set(),
#  'FA0250724': set(),
#  'FA0177487': set(),
#  'FA0052168': {'F007', 'F035'},
#  'FA0052857': {'F030',
#   'F033',
#   'F035',
#   'F036',
#   'F037',
#   'F042',
#   'F043',
#   'F044',
#   'F046'},
#  'FA0065603': set(),
#  'FA0055247': {'F006',
#   'F007',
#   'F025',
#   'F029',
#   'F033',
#   'F035',
#   'F036',
#   'F037',
#   'F039',
#   'F040',
#   'F042',
#   'F044'},
#  'FA0026525': {'F026', 'F033', 'F035', 'F039', 'F043', 'F052'},
#  'FA0069221': set(),
#  'FA0029909': set(),
#  'FA0042626': set(),
#  'FA0165828': set(),
#  'FA0027650': set(),
#  'FA0175723': set(),
#  'FA0165648': set(),
#  'FA0004073': set(),
#  'FA0163033': {'F034', 'F036', 'F037'},
#  'FA0262028': set(),
#  'FA0053925': set(),
#  'FA0007713': set(),
#  'FA0203336': set(),
#  'FA0051496': set(),
#  'FA0166446': set(),
#  'FA0249870': set(),
#  'FA0043536': set(),
#  'FA0057163': set(),
#  'FA0014753': set(),
#  'FA0044588': set(),
#  'FA0166197': set(),
#  'FA0163834': set(),
#  'FA0058626': set(),
#  'FA0049113': set(),
#  'FA0073163': set(),
#  'FA0244260': set(),
#  'FA0159039': {'F007', 'F013', 'F034', 'F040', 'F044', 'F046'},
#  'FA0036069': set(),
#  'FA0028408': set(),
#  'FA0070395': set(),
#  'FA0142388': {'F035', 'F044'},
#  'FA0014632': {'F014', 'F033', 'F036', 'F040'},
#  'FA0061611': set(),
#  'FA0009372': set(),
#  'FA0142823': set(),
#  'FA0225129': set(),
#  'FA0222856': set(),
#  'FA0064172': set(),
#  'FA0027726': set(),
#  'FA0180883': {'F014', 'F030', 'F035', 'F039', 'F040', 'F043', 'F044'},
#  'FA0067837': set(),
#  'FA0039512': set(),
#  'FA0203887': set(),
#  'FA0005962': set(),
#  'FA0252547': set(),
#  'FA0068466': set(),
#  'FA0072860': {'F007',
#   'F008',
#   'F014',
#   'F027',
#   'F029',
#   'F033',
#   'F035',
#   'F036',
#   'F039',
#   'F043',
#   'F049'},
#  'FA0019165': set(),
#  'FA0174414': set(),
#  'FA0064958': {'F007', 'F026', 'F033', 'F034', 'F036', 'F044', 'F048'},
#  'FA0044256': set(),
#  'FA0049173': set(),
#  'FA0043532': set(),
#  'FA0240488': set(),
#  'FA0166254': set(),
#  'FA0058005': {'F040', 'F044'},
#  'FA0066236': {'F007', 'F027', 'F033', 'F037', 'F044'},
#  'FA0006427': set(),
#  'FA0239124': set(),
#  'FA0072087': {'F027', 'F033', 'F036', 'F037', 'F044'},
#  'FA0258453': set(),
#  'FA0248590': {'F007', 'F033', 'F039', 'F044'},
#  'FA0138483': set(),
#  'FA0008648': {'F005', 'F006', 'F033', 'F035', 'F037', 'F040', 'F043', 'F046'},
#  'FA0005206': set(),
#  'FA0250096': set(),
#  'FA0004812': set(),
#  'FA0013325': set(),
#  'FA0062913': {'F007',
#   'F014',
#   'F026',
#   'F033',
#   'F035',
#   'F036',
#   'F037',
#   'F039',
#   'F044',
#   'F049',
#   'F052',
#   'F054'},
#  'FA0064534': {'F014', 'F023', 'F037', 'F039', 'F044', 'F046'},
#  'FA0071308': set(),
#  'FA0239040': set(),
#  'FA0016984': set(),
#  'FA0239282': set(),
#  'FA0265944': {'F014', 'F034', 'F040'},
#  'FA0179870': set(),
#  'FA0139046': set(),
#  'FA0021220': {'F014', 'F037', 'F044'},
#  'FA0057199': set(),
#  'FA0026654': set(),
#  'FA0070548': {'F027', 'F033', 'F035', 'F037', 'F044'},
#  'FA0036725': set(),
#  'FA0240436': set(),
#  'FA0047920': set(),
#  'FA0045221': set(),
#  'FA0251110': set(),
#  'FA0170519': set(),
#  'FA0069265': set(),
#  'FA0245216': set(),
#  'FA0035649': set(),
#  'FA0172015': set(),
#  'FA0009122': set(),
#  'FA0050193': set(),
#  'FA0024674': set(),
#  'FA0179997': set(),
#  'FA0018668': set(),
#  'FA0069663': set(),
#  'FA0064764': set(),
#  'FA0029144': set(),
#  'FA0225666': set(),
#  'FA0072380': set(),
#  'FA0049411': set(),
#  'FA0008974': set(),
#  'FA0029947': set(),
#  'FA0268437': {'F006', 'F029', 'F032', 'F033', 'F040', 'F044'},
#  'FA0247845': {'F007', 'F014', 'F033', 'F035', 'F037', 'F040'},
#  'FA0020364': set(),
#  'FA0165675': set(),
#  'FA0222850': set(),
#  'FA0061935': set(),
#  'FA0071088': set(),
#  'FA0071161': set(),
#  'FA0222310': set(),
#  'FA0242100': {'F027', 'F029', 'F036', 'F039'},
#  'FA0160501': set(),
#  'FA0005139': set(),
#  'FA0030910': set(),
#  'FA0158479': set(),
#  'FA0070815': set(),
#  'FA0163988': {'F030', 'F033', 'F034', 'F036', 'F041', 'F044', 'F052'},
#  'FA0046199': set(),
#  'FA0180038': set(),
#  'FA0012295': set(),
#  'FA0003877': set(),
#  'FA0058066': set(),
#  'FA0137688': set(),
#  'FA0040903': set(),
#  'FA0159343': set(),
#  'FA0002774': set(),
#  'FA0143761': {'F014', 'F033', 'F040', 'F044'},
#  'FA0142084': set(),
#  'FA0039012': set(),
#  'FA0036091': set(),
#  'FA0034689': set(),
#  'FA0055466': set(),
#  'FA0250109': {'F006', 'F023', 'F033', 'F044', 'F046', 'F052'},
#  'FA0050091': set(),
#  'FA0249587': set(),
#  'FA0034651': {'F013', 'F023', 'F029', 'F030', 'F032', 'F033', 'F044', 'F049'},
#  'FA0041751': {'F006', 'F025', 'F037', 'F039', 'F046'},
#  'FA0028083': set(),
#  'FA0202801': set(),
#  'FA0257351': set(),
#  'FA0241453': set(),
#  'FA0018677': set(),
#  'FA0040691': set(),
#  'FA0013578': set(),
#  'FA0250591': set(),
#  'FA0064431': set(),
#  'FA0055202': set(),
#  'FA0063713': set(),
#  'FA0256442': set(),
#  'FA0003849': {'F006', 'F014', 'F023', 'F033', 'F035', 'F039', 'F044'},
#  'FA0012104': set(),
#  'FA0267022': set(),
#  'FA0021474': set(),
#  'FA0014923': {'F014', 'F023', 'F027', 'F033', 'F035', 'F044'},
#  'FA0054807': set(),
#  'FA0021938': set(),
#  'FA0015189': set(),
#  'FA0046223': set(),
#  'FA0144636': set(),
#  'FA0150936': set(),
#  'FA0242920': set(),
#  'FA0011935': set(),
#  'FA0177875': {'F014', 'F033', 'F036', 'F037', 'F044', 'F052'},
#  'FA0021143': set(),
#  'FA0031151': set(),
#  'FA0049129': {'F035', 'F037', 'F043'},
#  'FA0037755': set(),
#  'FA0158166': set(),
#  'FA0239882': {'F008'},
#  'FA0022970': set(),
#  'FA0249126': {'F035', 'F044'},
#  'FA0245795': {'F001', 'F034', 'F036', 'F039'},
#  'FA0224048': set(),
#  'FA0164574': {'F006', 'F014', 'F033', 'F040', 'F043'},
#  'FA0057385': set(),
#  'FA0172317': set(),
#  'FA0048110': set(),
#  'FA0242515': set(),
#  'FA0026261': set(),
#  'FA0046332': set(),
#  'FA0037089': {'F007', 'F033', 'F034', 'F035', 'F044', 'F055'},
#  'FA0033970': set(),
#  'FA0226147': {'F023', 'F033'},
#  'FA0063960': {'F005', 'F014', 'F023', 'F033', 'F035', 'F037', 'F040'},
#  'FA0027647': set(),
#  'FA0074332': set(),
#  'FA0167627': {'F033', 'F044'},
#  'FA0073229': set(),
#  'FA0067745': set(),
#  'FA0202750': set(),
#  'FA0028498': set(),
#  'FA0033851': set(),
#  'FA0163849': set(),
#  'FA0175622': set(),
#  'FA0013329': {'F009', 'F023', 'F030', 'F033', 'F035', 'F039', 'F040', 'F044'},
#  'FA0255349': set(),
#  'FA0025042': set(),
#  'FA0028038': set(),
#  'FA0062271': set(),
#  'FA0255776': set(),
#  'FA0005237': set(),
#  'FA0054218': set(),
#  'FA0073616': set(),
#  'FA0048643': {'F037'},
#  'FA0263395': {'F009', 'F027', 'F034', 'F035', 'F046', 'F049', 'F052'},
#  'FA0053923': set(),
#  'FA0166244': {'F023', 'F027', 'F030', 'F033', 'F035', 'F039', 'F040', 'F052'},
#  'FA0025571': set(),
#  'FA0035449': set(),
#  'FA0065834': set(),
#  'FA0015806': {'F007', 'F025', 'F035', 'F036', 'F040', 'F043', 'F046', 'F049'},
#  'FA0064861': set(),
#  'FA0009178': set(),
#  'FA0264213': {'F006', 'F030', 'F033', 'F034', 'F035', 'F042', 'F043', 'F044'},
#  'FA0063833': set(),
#  'FA0037508': {'F006', 'F007', 'F014', 'F033', 'F044'},
#  'FA0252220': set(),
#  'FA0056951': set(),
#  'FA0044042': set(),
#  'FA0015666': {'F006', 'F007', 'F029', 'F033', 'F034', 'F049'},
#  'FA0137540': set(),
#  'FA0256133': set(),
#  'FA0242517': {'F009', 'F027', 'F036', 'F039'},
#  'FA0051768': set(),
#  'FA0251992': set(),
#  'FA0007174': set(),
#  'FA0058142': set(),
#  'FA0202977': set(),
#  'FA0041331': set(),
#  'FA0179718': set(),
#  'FA0062174': set(),
#  'FA0053926': set(),
#  'FA0038442': set(),
#  'FA0035846': set(),
#  'FA0011753': {'F007', 'F034', 'F035', 'F037'},
#  'FA0260235': set(),
#  'FA0241950': set(),
#  'FA0071853': set(),
#  'FA0016576': set(),
#  'FA0044090': set(),
#  'FA0050965': set(),
#  'FA0024415': set(),
#  'FA0033673': set(),
#  'FA0163119': set(),
#  'FA0020196': set(),
#  'FA0065791': set(),
#  'FA0044663': set(),
#  'FA0002335': set(),
#  'FA0258335': set(),
#  'FA0158621': set(),
#  'FA0248782': {'F007', 'F052'},
#  'FA0035435': {'F006', 'F014', 'F040', 'F042', 'F055'},
#  'FA0059237': {'F006', 'F033', 'F044'},
#  'FA0171492': set(),
#  'FA0044198': set(),
#  'FA0030810': set(),
#  'FA0241179': {'F006', 'F023', 'F043'},
#  'FA0049277': set(),
#  'FA0012769': set(),
#  'FA0136610': set(),
#  'FA0137426': set(),
#  'FA0010403': set(),
#  'FA0225588': {'F004', 'F006', 'F025', 'F039'},
#  'FA0023163': {'F004', 'F039'},
#  'FA0043107': set(),
#  'FA0053844': set(),
#  'FA0051249': set(),
#  'FA0032158': {'F007', 'F014', 'F039', 'F044'},
#  'FA0156500': {'F033', 'F035', 'F044'},
#  'FA0044668': set(),
#  'FA0042538': {'F005', 'F014', 'F029', 'F033', 'F052'},
#  'FA0054887': set(),
#  'FA0009651': {'F033', 'F035', 'F037', 'F040'},
#  'FA0048976': set(),
#  'FA0157916': {'F007', 'F036', 'F038', 'F040', 'F044'},
#  'FA0020584': set(),
#  'FA0167462': set(),
#  'FA0240387': set(),
#  'FA0047103': set(),
#  'FA0072006': set(),
#  'FA0002931': set(),
#  'FA0065143': set(),
#  'FA0159961': set(),
#  'FA0071480': set(),
#  'FA0025457': set(),
#  'FA0239809': {'F006', 'F042', 'F043'},
#  'FA0163120': set(),
#  'FA0022763': set(),
#  'FA0060045': set(),
#  'FA0061538': set(),
#  'FA0032786': set(),
#  'FA0162957': set(),
#  'FA0003718': set(),
#  'FA0240630': set(),
#  'FA0008271': set(),
#  'FA0068686': set(),
#  'FA0031084': set(),
#  'FA0021552': {'F007', 'F023', 'F026', 'F035', 'F043', 'F044', 'F049'},
#  'FA0255768': set(),
#  'FA0222140': {'F004', 'F007', 'F014', 'F035', 'F037'},
#  'FA0166809': set(),
#  'FA0137837': set(),
#  'FA0022795': set(),
#  'FA0239410': {'F009', 'F025', 'F026', 'F027', 'F030'},
#  'FA0027584': {'F007',
#   'F014',
#   'F023',
#   'F029',
#   'F030',
#   'F033',
#   'F040',
#   'F043',
#   'F054'},
#  'FA0012608': {'F029', 'F037', 'F039'},
#  'FA0178975': set(),
#  'FA0021250': set(),
#  'FA0067640': set(),
#  'FA0016970': set(),
#  'FA0011393': set(),
#  'FA0055414': set(),
#  'FA0025455': set(),
#  'FA0064724': {'F033', 'F040', 'F044'},
#  'FA0268182': set(),
#  'FA0014656': set(),
#  'FA0171497': set(),
#  'FA0178400': {'F007', 'F023', 'F029', 'F033', 'F039', 'F043', 'F049'},
#  'FA0241911': set(),
#  'FA0034301': {'F025', 'F033'},
#  'FA0157945': set(),
#  'FA0043096': {'F035', 'F044'},
#  'FA0038622': set(),
#  'FA0241511': {'F033', 'F035', 'F036', 'F039', 'F044'},
#  'FA0156386': set(),
#  'FA0007361': {'F004', 'F006', 'F023', 'F036', 'F039', 'F053'},
#  'FA0158561': set(),
#  'FA0057216': {'F005', 'F014', 'F044', 'F053'},
#  'FA0049814': set(),
#  'FA0011350': {'F033', 'F043'},
#  'FA0143602': {'F008', 'F016', 'F029', 'F033', 'F036', 'F049'},
#  'FA0263377': {'F052'},
#  'FA0064832': set(),
#  'FA0055825': set(),
#  'FA0023826': set(),
#  'FA0171881': {'F014', 'F042', 'F043', 'F055'},
#  'FA0008166': {'F005', 'F013', 'F034', 'F035', 'F037', 'F044', 'F049'},
#  'FA0036823': set(),
#  'FA0063817': set(),
#  'FA0021984': set(),
#  'FA0008320': set(),
#  'FA0225482': set(),
#  'FA0034222': set(),
#  'FA0150038': {'F014',
#   'F023',
#   'F029',
#   'F033',
#   'F034',
#   'F035',
#   'F037',
#   'F039',
#   'F042',
#   'F043',
#   'F044',
#   'F050'},
#  'FA0062642': set(),
#  'FA0155810': set(),
#  'FA0257174': {'F007', 'F009', 'F030', 'F035', 'F036', 'F037', 'F043', 'F047'},
#  'FA0250406': set(),
#  'FA0170909': set(),
#  'FA0032927': set(),
#  'FA0049266': set(),
#  'FA0005489': set(),
#  'FA0224569': {'F033'},
#  'FA0171328': set(),
#  'FA0136686': set(),
#  'FA0035223': set(),
#  'FA0180561': set(),
#  'FA0249274': set(),
#  'FA0256301': set(),
#  'FA0029908': set(),
#  'FA0164568': {'F006',
#   'F014',
#   'F033',
#   'F034',
#   'F036',
#   'F039',
#   'F040',
#   'F043',
#   'F044',
#   'F046',
#   'F052'},
#  'FA0002190': {'F007', 'F023', 'F034', 'F035', 'F042', 'F043'},
#  'FA0251976': {'F006', 'F040', 'F052'},
#  'FA0158712': set(),
#  'FA0175145': set(),
#  'FA0007934': {'F004', 'F014', 'F029', 'F030', 'F035', 'F037', 'F039', 'F043'},
#  'FA0053930': set(),
#  'FA0240811': set(),
#  'FA0242857': set(),
#  'FA0018059': set(),
#  'FA0012441': set(),
#  'FA0258911': set(),
#  'FA0068192': set(),
#  'FA0261951': {'F006', 'F014', 'F033', 'F034', 'F040', 'F044', 'F055'},
#  'FA0062875': set(),
#  'FA0042023': set(),
#  'FA0176836': set(),
#  'FA0073827': set(),
#  'FA0045857': set(),
#  'FA0263495': set(),
#  'FA0263509': set(),
#  'FA0140146': set(),
#  'FA0041863': set(),
#  'FA0072070': set(),
#  'FA0167508': {'F033', 'F035', 'F044'},
#  'FA0045951': set(),
#  'FA0021314': set(),
#  'FA0242918': {'F008', 'F014', 'F025', 'F033', 'F035', 'F036', 'F044'},
#  'FA0015797': set(),
#  'FA0008302': set(),
#  'FA0224655': set(),
#  'FA0015940': set(),
#  'FA0159378': set(),
#  'FA0160487': set(),
#  'FA0008243': {'F014', 'F025', 'F034', 'F036', 'F038', 'F040', 'F044', 'F052'},
#  'FA0034405': set(),
#  'FA0178354': {'F014', 'F043'},
#  'FA0006621': {'F006', 'F033', 'F035', 'F040', 'F043', 'F044'},
#  'FA0224900': set(),
#  'FA0251319': {'F006', 'F009', 'F029', 'F034', 'F038', 'F042', 'F049'},
#  'FA0250773': set(),
#  'FA0250629': set(),
#  'FA0175487': set(),
#  'FA0030750': set(),
#  'FA0252617': set(),
#  'FA0065946': {'F007', 'F030', 'F036', 'F043'},
#  'FA0179734': set(),
#  'FA0043714': set(),
#  'FA0015338': {'F006', 'F035', 'F039', 'F040', 'F041'},
#  'FA0024227': set(),
#  'FA0138515': set(),
#  'FA0016721': set(),
#  'FA0047866': {'F030', 'F035', 'F039'},
#  'FA0011210': set(),
#  'FA0055091': {'F033', 'F039'},
#  'FA0043706': set(),
#  'FA0062291': set(),
#  'FA0137356': set(),
#  'FA0026897': {'F023', 'F043'},
#  'FA0018684': set(),
#  'FA0013168': set(),
#  'FA0244830': set(),
#  'FA0055146': {'F029', 'F039', 'F043'},
#  'FA0037704': {'F009', 'F030', 'F033', 'F035', 'F036', 'F039'},
#  'FA0049388': set(),
#  'FA0004871': set(),
#  'FA0165314': set(),
#  'FA0072667': set(),
#  'FA0058411': set(),
#  'FA0065211': set(),
#  'FA0039928': set(),
#  'FA0035220': set(),
#  'FA0224041': set(),
#  'FA0159090': set(),
#  'FA0069232': set(),
#  'FA0074221': set(),
#  'FA0267092': set(),
#  'FA0157908': {'F021', 'F025', 'F035', 'F043', 'F044'},
#  'FA0251001': set(),
#  'FA0040430': set(),
#  'FA0007684': set(),
#  'FA0058723': set(),
#  'FA0179092': {'F007', 'F024', 'F029', 'F030', 'F033', 'F049', 'F053'},
#  'FA0143003': set(),
#  'FA0027829': set(),
#  'FA0033188': set(),
#  'FA0068898': set(),
#  'FA0261843': set(),
#  'FA0050503': set(),
#  'FA0240767': set(),
#  'FA0180133': set(),
#  'FA0031212': set(),
#  'FA0167236': set(),
#  'FA0073743': set(),
#  'FA0058579': set(),
#  'FA0249418': set(),
#  'FA0004954': {'F006', 'F014', 'F027', 'F033', 'F035', 'F040', 'F044', 'F046'},
#  'FA0049283': set(),
#  'FA0034188': {'F038', 'F040', 'F042', 'F044', 'F046'},
#  'FA0159952': set(),
#  'FA0013082': set(),
#  'FA0018038': set(),
#  'FA0164697': set(),
#  'FA0224971': {'F006',
#   'F014',
#   'F025',
#   'F026',
#   'F029',
#   'F030',
#   'F033',
#   'F035',
#   'F036',
#   'F043',
#   'F044',
#   'F053'},
#  'FA0243451': set(),
#  'FA0004861': set(),
#  'FA0049233': set(),
#  'FA0141757': set(),
#  'FA0007114': set(),
#  'FA0202544': {'F007',
#   'F014',
#   'F022',
#   'F033',
#   'F035',
#   'F036',
#   'F037',
#   'F038',
#   'F044',
#   'F046'},
#  'FA0163346': set(),
#  'FA0173765': {'F034'},
#  'FA0241192': set(),
#  'FA0053769': {'F030', 'F033', 'F039', 'F044'},
#  'FA0248792': set(),
#  'FA0069270': set(),
#  'FA0251980': set(),
#  'FA0248041': {'F029', 'F030'},
#  'FA0259907': {'F007', 'F014', 'F023', 'F035', 'F040'},
#  'FA0178454': set(),
#  'FA0011015': set(),
#  'FA0177208': set(),
#  'FA0032856': {'F029', 'F035', 'F036', 'F040', 'F043', 'F044'},
#  'FA0049257': set(),
#  'FA0263379': set(),
#  'FA0013745': {'F014', 'F035', 'F039', 'F040', 'F042'},
#  'FA0141514': set(),
#  'FA0223957': set(),
#  'FA0050521': set(),
#  'FA0175111': set(),
#  'FA0052691': set(),
#  'FA0053630': set(),
#  'FA0174380': set(),
#  'FA0164491': {'F006', 'F007', 'F008', 'F030', 'F035', 'F037', 'F039'},
#  'FA0166098': set(),
#  'FA0056605': set(),
#  'FA0266684': set(),
#  'FA0018456': set(),
#  'FA0050580': set(),
#  'FA0071649': set(),
#  'FA0249773': set(),
#  'FA0023196': set(),
#  'FA0029287': set(),
#  'FA0028081': set(),
#  'FA0240410': {'F023', 'F029', 'F034', 'F040'},
#  'FA0025506': set(),
#  'FA0025677': {'F029', 'F037', 'F044'},
#  'FA0014713': set(),
#  'FA0010435': set(),
#  'FA0005413': set(),
#  'FA0024789': set(),
#  'FA0026234': set(),
#  'FA0033988': set(),
#  'FA0225297': set(),
#  'FA0056960': {'F007', 'F027', 'F029', 'F033', 'F035', 'F039', 'F044'},
#  'FA0203853': set(),
#  'FA0064134': {'F030', 'F033', 'F037', 'F040', 'F044'},
#  'FA0072703': set(),
#  'FA0240482': {'F029', 'F037'},
#  'FA0004028': set(),
#  'FA0059343': set(),
#  'FA0030407': set(),
#  'FA0163712': set(),
#  'FA0159098': {'F007',
#   'F008',
#   'F009',
#   'F014',
#   'F023',
#   'F026',
#   'F027',
#   'F036',
#   'F038',
#   'F039',
#   'F044',
#   'F050'},
#  'FA0256822': set(),
#  'FA0047361': set(),
#  'FA0008153': set(),
#  'FA0070845': set(),
#  'FA0037245': set(),
#  'FA0057772': set(),
#  'FA0013597': set(),
#  'FA0025252': set(),
#  'FA0073652': set(),
#  'FA0060742': set(),
#  'FA0034877': set(),
#  'FA0249921': set(),
#  'FA0265441': set(),
#  'FA0070621': set(),
#  'FA0073234': set(),
#  'FA0240995': {'F033', 'F035', 'F037', 'F043'},
#  'FA0171245': set(),
#  'FA0245986': set(),
#  'FA0177458': set(),
#  'FA0058509': {'F006', 'F014', 'F033', 'F039', 'F040', 'F043', 'F044', 'F046'},
#  'FA0003896': set(),
#  'FA0054430': set(),
#  'FA0059017': set(),
#  'FA0007595': {'F033'},
#  'FA0241959': set(),
#  'FA0021244': {'F023', 'F040', 'F041', 'F052'},
#  'FA0225800': {'F006', 'F014', 'F033'},
#  'FA0222795': {'F023', 'F029', 'F033'},
#  'FA0004261': {'F029', 'F033', 'F035', 'F037', 'F040', 'F053'},
#  'FA0071170': set(),
#  'FA0046071': set(),
#  'FA0170221': set(),
#  'FA0034687': set(),
#  'FA0033462': set(),
#  'FA0138602': set(),
#  'FA0177843': set(),
#  'FA0016588': set(),
#  'FA0032053': set(),
#  'FA0022883': set(),
#  'FA0058967': set(),
#  'FA0034762': set(),
#  'FA0242066': set(),
#  'FA0171682': set(),
#  'FA0028344': set(),
#  'FA0243444': {'F037', 'F040', 'F043'},
#  'FA0249651': set(),
#  'FA0046020': set(),
#  'FA0066702': set(),
#  'FA0011473': set(),
#  'FA0057107': set(),
#  'FA0240478': set(),
#  'FA0067398': set(),
#  'FA0259777': set(),
#  'FA0063820': set(),
#  'FA0160434': set(),
#  'FA0051661': set(),
#  'FA0055193': set(),
#  'FA0012731': set(),
#  'FA0176944': set(),
#  'FA0053156': set(),
#  'FA0068159': set(),
#  'FA0035660': set(),
#  'FA0203001': set(),
#  'FA0265876': set(),
#  'FA0008357': set(),
#  'FA0053919': set(),
#  'FA0041320': set(),
#  'FA0137780': set(),
#  'FA0203198': set(),
#  'FA0050281': set(),
#  'FA0071810': set(),
#  'FA0265279': set(),
#  'FA0042668': set(),
#  'FA0024368': set(),
#  'FA0178974': set(),
#  'FA0240621': set(),
#  'FA0020827': {'F023', 'F033', 'F036', 'F043', 'F053'},
#  'FA0240814': set(),
#  'FA0021493': set(),
#  'FA0044688': set(),
#  'FA0245792': set(),
#  'FA0019516': {'F004', 'F014', 'F035', 'F037'},
#  'FA0042575': set(),
#  'FA0044914': set(),
#  'FA0142968': set(),
#  'FA0056882': {'F006', 'F033', 'F044'},
#  'FA0007514': {'F033', 'F044', 'F052'},
#  'FA0037597': set(),
#  'FA0172188': set(),
#  'FA0048270': set(),
#  'FA0165782': set(),
#  'FA0224933': set(),
#  'FA0038658': set(),
#  'FA0239082': {'F026', 'F035', 'F036', 'F043'},
#  'FA0032544': set(),
#  'FA0138728': set(),
#  'FA0072621': set(),
#  'FA0265784': {'F041', 'F043'},
#  'FA0003862': set(),
#  'FA0167268': set(),
#  'FA0242900': set(),
#  'FA0049172': {'F044'},
#  'FA0177648': {'F023', 'F033', 'F036', 'F039'},
#  'FA0065032': set(),
#  'FA0009135': set(),
#  'FA0226200': set(),
#  'FA0162806': set(),
#  'FA0225046': set(),
#  'FA0025804': {'F025', 'F033', 'F035', 'F044'},
#  'FA0043095': set(),
#  'FA0241963': {'F014', 'F035', 'F036', 'F044'},
#  'FA0174716': {'F029'},
#  'FA0054691': {'F006', 'F030', 'F036', 'F040', 'F044', 'F052', 'F053'},
#  'FA0240579': {'F008', 'F014'},
#  'FA0037389': set(),
#  'FA0043143': set(),
#  'FA0265584': set(),
#  'FA0243637': set(),
#  'FA0036346': set(),
#  'FA0159691': set(),
#  'FA0252680': set(),
#  'FA0138744': set(),
#  'FA0025182': set(),
#  'FA0241309': set(),
#  'FA0222724': set(),
#  'FA0178393': set(),
#  'FA0006798': set(),
#  'FA0137424': set(),
#  'FA0019670': set(),
#  'FA0141780': set(),
#  'FA0143759': set(),
#  'FA0013613': set(),
#  'FA0175577': set(),
#  'FA0243129': set(),
#  'FA0020625': set(),
#  'FA0036656': {'F039', 'F046'},
#  'FA0032177': set(),
#  'FA0052942': set(),
#  'FA0004066': set(),
#  'FA0030935': {'F006', 'F033', 'F035', 'F036'},
#  'FA0045326': set(),
#  'FA0174918': {'F007', 'F033', 'F035'},
#  'FA0072809': {'F023', 'F029', 'F035', 'F036', 'F040', 'F044', 'F050'},
#  'FA0045823': set(),
#  'FA0067946': {'F006', 'F015', 'F037', 'F042', 'F049'},
#  'FA0003453': set(),
#  'FA0048564': set(),
#  'FA0070955': set(),
#  'FA0065668': {'F006', 'F014', 'F030', 'F033', 'F035', 'F037', 'F040', 'F044'},
#  'FA0260195': set(),
#  'FA0163272': set(),
#  'FA0011992': set(),
#  'FA0221987': set(),
#  'FA0006557': set(),
#  'FA0165710': set(),
#  'FA0245733': set(),
#  'FA0222577': set(),
#  'FA0068179': set(),
#  'FA0159704': set(),
#  'FA0054689': set(),
#  'FA0038760': set(),
#  'FA0005548': {'F030', 'F033', 'F037', 'F043', 'F044'},
#  'FA0034481': set(),
#  'FA0203690': {'F006', 'F033', 'F035', 'F042', 'F043', 'F046'},
#  'FA0164560': set(),
#  'FA0143594': set(),
#  'FA0015798': set(),
#  'FA0026423': set(),
#  'FA0054372': set(),
#  'FA0025145': set(),
#  'FA0036357': set(),
#  'FA0160919': set(),
#  'FA0062108': {'F026', 'F033', 'F036'},
#  'FA0021117': set(),
#  'FA0256916': set(),
#  'FA0049517': set(),
#  'FA0051651': set(),
#  'FA0202786': set(),
#  'FA0069069': {'F007', 'F033', 'F043', 'F044', 'F049'},
#  'FA0226433': set(),
#  'FA0018909': set(),
#  'FA0248008': set(),
#  'FA0072829': {'F006'},
#  'FA0051269': set(),
#  'FA0166830': set(),
#  'FA0244440': set(),
#  'FA0040967': set(),
#  'FA0021631': {'F030', 'F043', 'F044', 'F045', 'F046'},
#  'FA0010049': set(),
#  'FA0143609': set(),
#  'FA0019181': set(),
#  'FA0138961': {'F006', 'F016', 'F023', 'F035', 'F036'},
#  'FA0063641': set(),
#  'FA0160161': {'F007', 'F008', 'F026', 'F033', 'F040', 'F044', 'F052'},
#  'FA0160876': set(),
#  'FA0066005': set(),
#  'FA0074328': set(),
#  'FA0034396': {'F033', 'F039', 'F044'},
#  'FA0255895': set(),
#  'FA0139089': set(),
#  'FA0030717': set(),
#  'FA0008089': set(),
#  'FA0024436': set(),
#  'FA0137921': set(),
#  'FA0015901': set(),
#  'FA0242781': set(),
#  'FA0029623': set(),
#  'FA0031082': set(),
#  'FA0174695': set(),
#  'FA0175444': set(),
#  'FA0070503': set(),
#  'FA0035836': {'F014', 'F044'},
#  'FA0041218': set(),
#  'FA0174782': set(),
#  'FA0034184': set(),
#  'FA0049965': {'F035', 'F044', 'F046', 'F055'},
#  'FA0051784': {'F033', 'F039', 'F043', 'F044', 'F046'},
#  'FA0014380': set(),
#  'FA0036177': set(),
#  'FA0252592': {'F040'},
#  'FA0015535': set(),
#  'FA0058934': set(),
#  'FA0039643': set(),
#  'FA0263274': set(),
#  'FA0032120': set(),
#  'FA0024180': set(),
#  'FA0033331': set(),
#  'FA0024292': set(),
#  'FA0014694': set(),
#  'FA0252537': set(),
#  'FA0013684': set(),
#  'FA0258562': set(),
#  'FA0251632': set(),
#  'FA0059025': set(),
#  'FA0257341': {'F006', 'F027', 'F036', 'F040', 'F042', 'F055'},
#  'FA0045530': set(),
#  'FA0242550': set(),
#  'FA0055364': {'F006',
#   'F007',
#   'F023',
#   'F035',
#   'F036',
#   'F039',
#   'F042',
#   'F044',
#   'F049'},
#  'FA0250424': set(),
#  'FA0040309': set(),
#  'FA0241841': set(),
#  'FA0018891': set(),
#  'FA0256360': set(),
#  'FA0163437': set(),
#  'FA0021718': set(),
#  'FA0023952': set(),
#  'FA0024379': set(),
#  'FA0048781': set(),
#  'FA0159506': {'F006', 'F021', 'F030', 'F033', 'F044'},
#  'FA0013849': set(),
#  'FA0258182': set(),
#  'FA0011405': set(),
#  'FA0005739': set(),
#  'FA0177620': {'F039', 'F043', 'F055'},
#  'FA0038865': set(),
#  'FA0249958': set(),
#  'FA0203907': set(),
#  'FA0028947': set(),
#  'FA0043629': {'F006', 'F027', 'F033', 'F035', 'F037', 'F039', 'F040', 'F044'},
#  'FA0025889': set(),
#  'FA0073375': set(),
#  'FA0009725': set(),
#  'FA0177680': set(),
#  'FA0070437': {'F033', 'F037', 'F043', 'F044'},
#  'FA0057421': set(),
#  'FA0167857': set(),
#  'FA0013546': set(),
#  'FA0176810': {'F036', 'F043', 'F044'},
#  'FA0008221': set(),
#  'FA0167332': set(),
#  'FA0022246': set(),
#  'FA0021481': set(),
#  'FA0177088': set(),
#  'FA0262312': {'F030', 'F033', 'F036', 'F040'},
#  'FA0252554': set(),
#  'FA0034754': set(),
#  'FA0226236': set(),
#  'FA0175376': set(),
#  'FA0241250': {'F004', 'F014', 'F025', 'F030', 'F033'},
#  'FA0060515': set(),
#  'FA0048944': {'F033'},
#  'FA0016001': set(),
#  'FA0060705': {'F033', 'F035', 'F040', 'F044'},
#  'FA0072691': set(),
#  'FA0023841': set(),
#  'FA0026880': set(),
#  'FA0059428': set(),
#  'FA0022441': {'F026', 'F030', 'F035', 'F044'},
#  'FA0018158': set(),
#  'FA0015617': set(),
#  'FA0051263': set(),
#  'FA0053911': set(),
#  'FA0047100': {'F007', 'F033', 'F035', 'F040', 'F044'},
#  'FA0163620': set(),
#  'FA0021893': set(),
#  'FA0165502': set(),
#  'FA0074004': set(),
#  'FA0174456': {'F030', 'F033', 'F040', 'F044'},
#  'FA0009616': set(),
#  'FA0013156': set(),
#  'FA0257585': set(),
#  'FA0256840': set(),
#  'FA0035209': set(),
#  'FA0221862': set(),
#  'FA0222839': set(),
#  'FA0142220': set(),
#  'FA0008317': set(),
#  'FA0008815': set(),
#  'FA0053270': set(),
#  'FA0026266': set(),
#  'FA0249877': set(),
#  'FA0050549': {'F006', 'F007', 'F030', 'F033', 'F035', 'F036', 'F044'},
#  'FA0138611': set(),
#  'FA0073511': set(),
#  'FA0242846': set(),
#  'FA0044986': set(),
#  'FA0244582': set(),
#  'FA0177656': set(),
#  'FA0058685': set(),
#  'FA0137772': {'F036', 'F037', 'F044', 'F053'},
#  'FA0260114': {'F033', 'F053'},
#  'FA0052391': set(),
#  'FA0243477': set(),
#  'FA0024324': set(),
#  'FA0039848': set(),
#  'FA0013173': set(),
#  'FA0010217': {'F006',
#   'F014',
#   'F023',
#   'F027',
#   'F033',
#   'F035',
#   'F036',
#   'F037',
#   'F040',
#   'F043',
#   'F044'},
#  'FA0019121': set(),
#  'FA0248805': set(),
#  'FA0175510': set(),
#  'FA0072306': set(),
#  'FA0177936': set(),
#  'FA0022240': {'F006', 'F033'},
#  'FA0043731': {'F026', 'F035', 'F036'},
#  'FA0222864': {'F007', 'F033', 'F034', 'F039', 'F053'},
#  'FA0164616': set(),
#  'FA0035327': set(),
#  'FA0051546': {'F014', 'F033', 'F035', 'F036', 'F037', 'F043', 'F044'},
#  'FA0138871': set(),
#  'FA0165990': set(),
#  'FA0239997': set(),
#  'FA0240976': set(),
#  'FA0058080': {'F037', 'F042', 'F044', 'F046'},
#  'FA0242726': set(),
#  'FA0167728': set(),
#  'FA0069932': set(),
#  'FA0242514': {'F014', 'F044'},
#  'FA0061627': set(),
#  'FA0042537': set(),
#  'FA0166729': set(),
#  'FA0239298': set(),
#  'FA0158997': set(),
#  'FA0036519': set(),
#  'FA0259289': set(),
#  'FA0174523': set(),
#  'FA0158095': set(),
#  'FA0165837': set(),
#  'FA0176297': set(),
#  'FA0026151': set(),
#  'FA0068919': set(),
#  'FA0222900': {'F006', 'F030', 'F035', 'F037'},
#  'FA0021224': set(),
#  'FA0242673': set(),
#  'FA0138927': set(),
#  'FA0025276': set(),
#  'FA0049128': set(),
#  'FA0021417': set(),
#  'FA0163416': set(),
#  'FA0002585': set(),
#  'FA0021419': set(),
#  'FA0013190': set(),
#  'FA0259441': set(),
#  'FA0061279': {'F006', 'F038', 'F040', 'F042'},
#  'FA0150502': set(),
#  'FA0068313': {'F006', 'F023', 'F035'},
#  'FA0243109': set(),
#  'FA0023432': set(),
#  'FA0066128': set(),
#  'FA0251903': set(),
#  'FA0173857': set(),
#  'FA0065084': {'F026', 'F036', 'F044', 'F052'},
#  'FA0045858': set(),
#  'FA0266621': set(),
#  'FA0054832': set(),
#  'FA0239923': set(),
#  'FA0022119': set(),
#  'FA0170223': {'F025', 'F033', 'F037', 'F044'},
#  'FA0047624': set(),
#  'FA0011370': set(),
#  'FA0049205': set(),
#  'FA0029863': set(),
#  'FA0239036': set(),
#  'FA0048274': set()}
